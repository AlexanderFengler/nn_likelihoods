# %%
# Load packages
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import os
import pickle
import time
import scipy as scp
import scipy.stats as scps
from scipy.optimize import differential_evolution
from scipy.optimize import minimize
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load my own functions
import dnnregressor_train_eval_keras as dnnk
import make_data_wfpt as mdw
from kde_training_utilities import kde_load_data
import ddm_data_simulation as ddm_sim
import boundary_functions as bf

# %%
# Handle some cuda business

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="2"

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8412095708138727019
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 826017924185342495
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 12048773940
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#   }
# }
# incarnation: 2947751280244046591
# physical_device_desc: "device: 0, name: GeForce GTX TITAN X, pci bus id: 0000:82:00.0, compute capability: 5.2"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 15327284663762362847
# physical_device_desc: "device: XLA_GPU device"
# ]

# %%
# Load Model
model_path = '/media/data_cifs/afengler/data/kde/linear_collapse/keras_models/dnnregressor_ddm_linear_collapse_06_22_19_23_27_28/model_0' 
ckpt_path = '/media/data_cifs/afengler/data/kde/linear_collapse/keras_models/dnnregressor_ddm_linear_collapse_06_22_19_23_27_28/ckpt_0_130'

model = keras.models.load_model(model_path)
model.load_weights(ckpt_path)
# Out:
# WARNING:tensorflow:From /home/afengler/.local/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/afengler/.local/lib/python3.7/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
model.summary()

# %%
# Initializations -----
n_runs = 100
n_samples = 2500
feature_file_path = '/media/data_cifs/afengler/data/kde/linear_collapse/train_test_data/test_features.pickle'
mle_out_path = '/media/data_cifs/afengler/data/kde/linear_collapse/mle_runs'

# NOTE PARAMETERS: WEIBULL: [v, a, w, node, shape, scale]
param_bounds = [(-1, 1), (0.3, 2), (0.3, 0.7), (0.01, 0.01), (0, np.pi / 2.2)]


my_optim_columns = ['v_sim', 'a_sim', 'w_sim', 'node_sim', 'theta_sim',
                    'v_mle', 'a_mle', 'w_mle', 'node_mle', 'theta_mle', 'n_samples']

# Get parameter names in correct ordering:
dat = pickle.load(open(feature_file_path, 
                       'rb'))

parameter_names = list(dat.keys())[:-2] # :-1 to get rid of 'rt' and 'choice' here

# Make columns for optimizer result table
p_sim = []
p_mle = []

for parameter_name in parameter_names:
    p_sim.append(parameter_name + '_sim')
    p_mle.append(parameter_name + '_mle')
    
my_optim_columns = p_sim + p_mle + ['n_samples']

# Initialize the data frame in which to store optimizer results
optim_results = pd.DataFrame(np.zeros((n_runs, len(my_optim_columns))), columns = my_optim_columns)
optim_results.iloc[:, 2 * len(parameter_names)] = n_samples

# define boundary
boundary = bf.linear_collapse
boundary_multiplicative = False

# Define the likelihood function
def log_p(params = [0, 1, 0.9], model = [], data = [], parameter_names = []):
    # Make feature array
    feature_array = np.zeros((data[0].shape[0], len(parameter_names) + 2))
    
    # Store parameters
    cnt = 0
    for i in range(0, len(parameter_names), 1):
        feature_array[:, i] = params[i]
        cnt += 1
    
    # Store rts and choices
    feature_array[:, cnt] = data[0].ravel() # rts
    feature_array[:, cnt + 1] = data[1].ravel() # choices
    
    # Get model predictions
    prediction = model.predict(feature_array)
    
    # Some post-processing of predictions
    prediction[prediction < 1e-29] = 1e-29
    
    return(- np.sum(np.log(prediction)))  

def make_params(param_bounds = []):
    params = np.zeros(len(param_bounds))
    
    for i in range(len(params)):
        params[i] = np.random.uniform(low = param_bounds[i][0], high = param_bounds[i][1])
        
    return params
# ---------------------

# %%
# Main loop ----------- TD: Parallelize
for i in range(0, n_runs, 1): 
    
    # Get start time
    start_time = time.time()
    
    tmp_params = make_params(param_bounds = param_bounds)
    
    # Store in output file
    optim_results.iloc[i, :len(parameter_names)] = tmp_params
    
    # Print some info on run
    print('Parameters for run ' + str(i) + ': ')
    print(tmp_params)
    
    # Define boundary params
    boundary_params = {'node': tmp_params[3],
                       'theta': tmp_params[4]}
    
    # Run model simulations
    ddm_dat_tmp = ddm_sim.ddm_flexbound_simulate(v = tmp_params[0],
                                                 a = tmp_params[1],
                                                 w = tmp_params[2],
                                                 s = 1,
                                                 delta_t = 0.001,
                                                 max_t = 20,
                                                 n_samples = n_samples,
                                                 boundary_fun = boundary, # function of t (and potentially other parameters) that takes in (t, *args)
                                                 boundary_multiplicative = boundary_multiplicative, # CAREFUL: CHECK IF BOUND
                                                 boundary_params = boundary_params)
        
    # Print some info on run
    print('Mean rt for current run: ')
    print(np.mean(ddm_dat_tmp[0]))
    
    # Run optimizer
    out = differential_evolution(log_p, 
                                 bounds = param_bounds, 
                                 args = (model, ddm_dat_tmp, parameter_names), 
                                 popsize = 30,
                                 disp = True)
    
    # Print some info
    print('Solution vector of current run: ')
    print(out.x)
    
    print('The run took: ')
    elapsed_time = time.time() - start_time
    print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
    
    # Store result in output file
    optim_results.iloc[i, len(parameter_names):(2*len(parameter_names))] = out.x
# -----------------------

# Save optimization results to file
optim_results.to_csv(mle_out_path + '/mle_results.csv')
# Out:
# Parameters for run 0:
# [-0.62773651  0.52517652  0.65581062  0.01        0.78495368]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.15347880000000008
# differential_evolution step 1: f(x)= -1297.28
# differential_evolution step 2: f(x)= -1423.12
# differential_evolution step 3: f(x)= -1423.12
# differential_evolution step 4: f(x)= -1424.49
# differential_evolution step 5: f(x)= -1424.49
# differential_evolution step 6: f(x)= -1441.6
# differential_evolution step 7: f(x)= -1493.1
# differential_evolution step 8: f(x)= -1493.1
# differential_evolution step 9: f(x)= -1493.1
# differential_evolution step 10: f(x)= -1494.79
# differential_evolution step 11: f(x)= -1496.4
# differential_evolution step 12: f(x)= -1496.8
# differential_evolution step 13: f(x)= -1502.11
# differential_evolution step 14: f(x)= -1502.11
# differential_evolution step 15: f(x)= -1503.52
# differential_evolution step 16: f(x)= -1503.52
# differential_evolution step 17: f(x)= -1503.52
# differential_evolution step 18: f(x)= -1503.52
# differential_evolution step 19: f(x)= -1503.52
# differential_evolution step 20: f(x)= -1503.92
# differential_evolution step 21: f(x)= -1504.54
# differential_evolution step 22: f(x)= -1504.67
# Solution vector of current run:
# [-0.82622877  0.51780683  0.69928476  0.01        0.91705089]
# The run took:
# 00:04:43
# Parameters for run 1:
# [0.84340105 1.06053173 0.37758004 0.01       1.04736806]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.3176156000000003
# differential_evolution step 1: f(x)= -341.148
# differential_evolution step 2: f(x)= -341.148
# differential_evolution step 3: f(x)= -481.504
# differential_evolution step 4: f(x)= -481.504
# differential_evolution step 5: f(x)= -481.504
# differential_evolution step 6: f(x)= -481.504
# differential_evolution step 7: f(x)= -481.504
# differential_evolution step 8: f(x)= -481.504
# differential_evolution step 9: f(x)= -495.81
# differential_evolution step 10: f(x)= -495.81
# differential_evolution step 11: f(x)= -495.81
# differential_evolution step 12: f(x)= -506.285
# differential_evolution step 13: f(x)= -517.62
# differential_evolution step 14: f(x)= -517.62
# differential_evolution step 15: f(x)= -517.62
# differential_evolution step 16: f(x)= -517.62
# differential_evolution step 17: f(x)= -517.62
# differential_evolution step 18: f(x)= -517.62
# differential_evolution step 19: f(x)= -517.62
# differential_evolution step 20: f(x)= -517.62
# differential_evolution step 21: f(x)= -517.62
# differential_evolution step 22: f(x)= -517.62
# differential_evolution step 23: f(x)= -517.62
# differential_evolution step 24: f(x)= -517.62
# differential_evolution step 25: f(x)= -518.404
# differential_evolution step 26: f(x)= -518.404
# differential_evolution step 27: f(x)= -518.404
# Solution vector of current run:
# [0.86821486 1.09584209 0.37856906 0.01       1.11400039]
# The run took:
# 00:05:51
# Parameters for run 2:
# [-0.04650786  1.35199775  0.67009702  0.01        0.14873141]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.2253159999999523
# differential_evolution step 1: f(x)= 4737.21
# differential_evolution step 2: f(x)= 4585.95
# differential_evolution step 3: f(x)= 4472.84
# differential_evolution step 4: f(x)= 4472.84
# differential_evolution step 5: f(x)= 4472.84
# differential_evolution step 6: f(x)= 4472.84
# differential_evolution step 7: f(x)= 4447.06
# differential_evolution step 8: f(x)= 4447.06
# differential_evolution step 9: f(x)= 4439.4
# differential_evolution step 10: f(x)= 4432.09
# differential_evolution step 11: f(x)= 4432.09
# differential_evolution step 12: f(x)= 4418.49
# differential_evolution step 13: f(x)= 4418.49
# differential_evolution step 14: f(x)= 4418.42
# differential_evolution step 15: f(x)= 4411.19
# differential_evolution step 16: f(x)= 4411.19
# differential_evolution step 17: f(x)= 4407.85
# Solution vector of current run:
# [0.29461698 1.25926886 0.60622344 0.01       0.00956237]
# The run took:
# 00:04:46
# Parameters for run 3:
# [0.56273323 0.91281555 0.69257921 0.01       0.85841659]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.25271680000000013
# differential_evolution step 1: f(x)= -701.206
# differential_evolution step 2: f(x)= -707.02
# differential_evolution step 3: f(x)= -707.02
# differential_evolution step 4: f(x)= -707.02
# differential_evolution step 5: f(x)= -707.02
# differential_evolution step 6: f(x)= -734.336
# differential_evolution step 7: f(x)= -775.569
# differential_evolution step 8: f(x)= -785.034
# differential_evolution step 9: f(x)= -785.034
# differential_evolution step 10: f(x)= -785.034
# differential_evolution step 11: f(x)= -785.034
# differential_evolution step 12: f(x)= -785.034
# differential_evolution step 13: f(x)= -785.034
# differential_evolution step 14: f(x)= -790.912
# differential_evolution step 15: f(x)= -790.912
# differential_evolution step 16: f(x)= -790.912
# differential_evolution step 17: f(x)= -790.912
# differential_evolution step 18: f(x)= -790.912
# differential_evolution step 19: f(x)= -790.912
# differential_evolution step 20: f(x)= -790.912
# differential_evolution step 21: f(x)= -790.912
# differential_evolution step 22: f(x)= -798.273
# differential_evolution step 23: f(x)= -798.273
# differential_evolution step 24: f(x)= -798.273
# differential_evolution step 25: f(x)= -798.273
# differential_evolution step 26: f(x)= -798.273
# differential_evolution step 27: f(x)= -798.273
# differential_evolution step 28: f(x)= -798.273
# differential_evolution step 29: f(x)= -798.273
# differential_evolution step 30: f(x)= -798.273
# differential_evolution step 31: f(x)= -799.444
# differential_evolution step 32: f(x)= -799.444
# differential_evolution step 33: f(x)= -799.444
# differential_evolution step 34: f(x)= -799.444
# differential_evolution step 35: f(x)= -799.74
# differential_evolution step 36: f(x)= -799.74
# differential_evolution step 37: f(x)= -799.74
# differential_evolution step 38: f(x)= -799.74
# differential_evolution step 39: f(x)= -799.74
# differential_evolution step 40: f(x)= -799.835
# Solution vector of current run:
# [0.99198941 0.83526492 0.67245389 0.01       0.85842772]
# The run took:
# 00:07:56
# Parameters for run 4:
# [0.20668566 1.35418478 0.3308794  0.01       0.02895781]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.6044155999999423
# differential_evolution step 1: f(x)= 5562.36
# differential_evolution step 2: f(x)= 5519.77
# differential_evolution step 3: f(x)= 5436.3
# differential_evolution step 4: f(x)= 5430.66
# differential_evolution step 5: f(x)= 5333.88
# differential_evolution step 6: f(x)= 5333.88
# differential_evolution step 7: f(x)= 5333.88
# differential_evolution step 8: f(x)= 5333.88
# differential_evolution step 9: f(x)= 5333.88
# differential_evolution step 10: f(x)= 5333.88
# differential_evolution step 11: f(x)= 5324.69
# differential_evolution step 12: f(x)= 5324.69
# differential_evolution step 13: f(x)= 5315.7
# differential_evolution step 14: f(x)= 5282.7
# differential_evolution step 15: f(x)= 5282.7
# differential_evolution step 16: f(x)= 5273.5
# differential_evolution step 17: f(x)= 5267.11
# differential_evolution step 18: f(x)= 5267.11
# differential_evolution step 19: f(x)= 5254.48
# differential_evolution step 20: f(x)= 5254.48
# differential_evolution step 21: f(x)= 5251
# differential_evolution step 22: f(x)= 5251
# differential_evolution step 23: f(x)= 5251
# differential_evolution step 24: f(x)= 5250.03
# differential_evolution step 25: f(x)= 5250.03
# differential_evolution step 26: f(x)= 5250.03
# differential_evolution step 27: f(x)= 5249.99
# Solution vector of current run:
# [-0.40198079  1.35000872  0.40732313  0.01        0.09187748]
# The run took:
# 00:06:49
# Parameters for run 5:
# [0.24477797 0.97006766 0.51433985 0.01       0.48842664]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.5209467999999995
# differential_evolution step 1: f(x)= 1741.65
# differential_evolution step 2: f(x)= 1741.65
# differential_evolution step 3: f(x)= 1741.65
# differential_evolution step 4: f(x)= 1722.11
# differential_evolution step 5: f(x)= 1685.08
# differential_evolution step 6: f(x)= 1677.66
# differential_evolution step 7: f(x)= 1677.66
# differential_evolution step 8: f(x)= 1677.66
# differential_evolution step 9: f(x)= 1677.66
# differential_evolution step 10: f(x)= 1677.66
# differential_evolution step 11: f(x)= 1668.09
# differential_evolution step 12: f(x)= 1668.09
# differential_evolution step 13: f(x)= 1663.31
# differential_evolution step 14: f(x)= 1663.31
# differential_evolution step 15: f(x)= 1663.31
# differential_evolution step 16: f(x)= 1663.31
# differential_evolution step 17: f(x)= 1663.31
# differential_evolution step 18: f(x)= 1663.31
# differential_evolution step 19: f(x)= 1663.31
# differential_evolution step 20: f(x)= 1663.31
# differential_evolution step 21: f(x)= 1662.67
# differential_evolution step 22: f(x)= 1661.5
# differential_evolution step 23: f(x)= 1661.5
# differential_evolution step 24: f(x)= 1661.5
# differential_evolution step 25: f(x)= 1661.5
# differential_evolution step 26: f(x)= 1661.27
# differential_evolution step 27: f(x)= 1661.27
# differential_evolution step 28: f(x)= 1661.27
# Solution vector of current run:
# [0.4558469  1.03809614 0.50081261 0.01       0.67702384]
# The run took:
# 00:05:57
# Parameters for run 6:
# [0.54595783 0.62464498 0.65470057 0.01       0.25156223]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.27006320000000017
# differential_evolution step 1: f(x)= 306.243
# differential_evolution step 2: f(x)= 217.454
# differential_evolution step 3: f(x)= 129.476
# differential_evolution step 4: f(x)= 43.9409
# differential_evolution step 5: f(x)= -14.9358
# differential_evolution step 6: f(x)= -14.9358
# differential_evolution step 7: f(x)= -14.9358
# differential_evolution step 8: f(x)= -14.9358
# differential_evolution step 9: f(x)= -14.9358
# differential_evolution step 10: f(x)= -14.9358
# differential_evolution step 11: f(x)= -14.9358
# differential_evolution step 12: f(x)= -14.9358
# differential_evolution step 13: f(x)= -14.9358
# differential_evolution step 14: f(x)= -14.9358
# differential_evolution step 15: f(x)= -14.9358
# differential_evolution step 16: f(x)= -14.9358
# differential_evolution step 17: f(x)= -14.9358
# differential_evolution step 18: f(x)= -14.9358
# differential_evolution step 19: f(x)= -14.9358
# differential_evolution step 20: f(x)= -17.9041
# differential_evolution step 21: f(x)= -17.9041
# differential_evolution step 22: f(x)= -17.9041
# differential_evolution step 23: f(x)= -17.9041
# differential_evolution step 24: f(x)= -18.1038
# differential_evolution step 25: f(x)= -20.176
# differential_evolution step 26: f(x)= -20.176
# differential_evolution step 27: f(x)= -20.176
# differential_evolution step 28: f(x)= -20.176
# differential_evolution step 29: f(x)= -20.176
# differential_evolution step 30: f(x)= -20.176
# differential_evolution step 31: f(x)= -20.176
# differential_evolution step 32: f(x)= -20.176
# differential_evolution step 33: f(x)= -20.2035
# differential_evolution step 34: f(x)= -20.2035
# differential_evolution step 35: f(x)= -20.9131
# differential_evolution step 36: f(x)= -20.9131
# differential_evolution step 37: f(x)= -21.0669
# differential_evolution step 38: f(x)= -21.0669
# differential_evolution step 39: f(x)= -21.0669
# differential_evolution step 40: f(x)= -21.0669
# differential_evolution step 41: f(x)= -21.212
# differential_evolution step 42: f(x)= -21.212
# differential_evolution step 43: f(x)= -21.3765
# differential_evolution step 44: f(x)= -21.3765
# differential_evolution step 45: f(x)= -21.3765
# differential_evolution step 46: f(x)= -21.3987
# differential_evolution step 47: f(x)= -21.3987
# differential_evolution step 48: f(x)= -21.5405
# differential_evolution step 49: f(x)= -21.5405
# differential_evolution step 50: f(x)= -21.5405
# differential_evolution step 51: f(x)= -21.5405
# differential_evolution step 52: f(x)= -21.5405
# differential_evolution step 53: f(x)= -21.5491
# differential_evolution step 54: f(x)= -21.5491
# differential_evolution step 55: f(x)= -21.6124
# differential_evolution step 56: f(x)= -21.6124
# differential_evolution step 57: f(x)= -21.6124
# differential_evolution step 58: f(x)= -21.6218
# differential_evolution step 59: f(x)= -21.6218
# differential_evolution step 60: f(x)= -21.6218
# differential_evolution step 61: f(x)= -21.6218
# Solution vector of current run:
# [0.32258725 0.64381601 0.69999655 0.01       0.38185754]
# The run took:
# 00:11:54
# Parameters for run 7:
# [-0.46431808  1.68551527  0.65221816  0.01        0.34942434]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.4145123999999427
# differential_evolution step 1: f(x)= 4403.16
# differential_evolution step 2: f(x)= 4403.16
# differential_evolution step 3: f(x)= 4403.16
# differential_evolution step 4: f(x)= 4349.44
# differential_evolution step 5: f(x)= 4314.86
# differential_evolution step 6: f(x)= 4314.86
# differential_evolution step 7: f(x)= 4314.86
# differential_evolution step 8: f(x)= 4307.23
# differential_evolution step 9: f(x)= 4295.55
# differential_evolution step 10: f(x)= 4295.55
# differential_evolution step 11: f(x)= 4295.55
# differential_evolution step 12: f(x)= 4290.52
# differential_evolution step 13: f(x)= 4288.73
# /home/afengler/miniconda3/envs/pytorch/lib/python3.7/site-packages/scipy/optimize/_differentialevolution.py:901: RuntimeWarning: invalid value encountered in true_divide
#   return (parameters - self.__scale_arg1) / self.__scale_arg2 + 0.5
# Solution vector of current run:
# [-0.61782189  1.4907448   0.63133538  0.01        0.23098198]
# The run took:
# 00:04:04
# Parameters for run 8:
# [-0.51263422  1.48481256  0.5629636   0.01        0.66512788]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.8182147999999937
# differential_evolution step 1: f(x)= 2314.74
# differential_evolution step 2: f(x)= 2250.73
# differential_evolution step 3: f(x)= 2250.73
# differential_evolution step 4: f(x)= 2250.73
# differential_evolution step 5: f(x)= 2235.1
# differential_evolution step 6: f(x)= 2235.1
# differential_evolution step 7: f(x)= 2235.1
# differential_evolution step 8: f(x)= 2230.22
# differential_evolution step 9: f(x)= 2207.8
# differential_evolution step 10: f(x)= 2207.8
# differential_evolution step 11: f(x)= 2207.8
# differential_evolution step 12: f(x)= 2207.8
# differential_evolution step 13: f(x)= 2207.8
# differential_evolution step 14: f(x)= 2207.8
# differential_evolution step 15: f(x)= 2207.8
# differential_evolution step 16: f(x)= 2207.8
# differential_evolution step 17: f(x)= 2206.47
# differential_evolution step 18: f(x)= 2206.09
# differential_evolution step 19: f(x)= 2205.78
# differential_evolution step 20: f(x)= 2203.38
# differential_evolution step 21: f(x)= 2203.12
# differential_evolution step 22: f(x)= 2203.04
# Solution vector of current run:
# [-0.61595093  1.48734249  0.62017989  0.01        0.75082695]
# The run took:
# 00:05:13
# Parameters for run 9:
# [-0.93717975  1.31150082  0.36336314  0.01        0.78258229]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.4494904000000001
# differential_evolution step 1: f(x)= 351.463
# differential_evolution step 2: f(x)= 351.463
# differential_evolution step 3: f(x)= 351.463
# differential_evolution step 4: f(x)= 351.463
# differential_evolution step 5: f(x)= 351.463
# differential_evolution step 6: f(x)= 349.715
# differential_evolution step 7: f(x)= 349.715
# differential_evolution step 8: f(x)= 341.066
# differential_evolution step 9: f(x)= 341.066
# differential_evolution step 10: f(x)= 323.397
# differential_evolution step 11: f(x)= 316.8
# differential_evolution step 12: f(x)= 316.8
# differential_evolution step 13: f(x)= 316.8
# differential_evolution step 14: f(x)= 316.8
# differential_evolution step 15: f(x)= 316.8
# differential_evolution step 16: f(x)= 315.218
# differential_evolution step 17: f(x)= 312.284
# differential_evolution step 18: f(x)= 312.284
# differential_evolution step 19: f(x)= 312.284
# differential_evolution step 20: f(x)= 312.284
# differential_evolution step 21: f(x)= 312.284
# differential_evolution step 22: f(x)= 312.284
# differential_evolution step 23: f(x)= 312.284
# differential_evolution step 24: f(x)= 312.284
# differential_evolution step 25: f(x)= 312.284
# differential_evolution step 26: f(x)= 311.679
# differential_evolution step 27: f(x)= 310.645
# differential_evolution step 28: f(x)= 310.645
# differential_evolution step 29: f(x)= 309.159
# differential_evolution step 30: f(x)= 308.157
# differential_evolution step 31: f(x)= 307.279
# differential_evolution step 32: f(x)= 307.279
# differential_evolution step 33: f(x)= 307.279
# differential_evolution step 34: f(x)= 307.279
# differential_evolution step 35: f(x)= 307.279
# differential_evolution step 36: f(x)= 307.279
# differential_evolution step 37: f(x)= 307.279
# differential_evolution step 38: f(x)= 307.279
# differential_evolution step 39: f(x)= 307.279
# differential_evolution step 40: f(x)= 307.279
# Solution vector of current run:
# [-0.99990494  1.04323451  0.4326318   0.01        0.68057389]
# The run took:
# 00:08:13
# Parameters for run 10:
# [0.71971138 0.80071974 0.41664851 0.01       0.71341543]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.3132928000000002
# differential_evolution step 1: f(x)= 178.079
# differential_evolution step 2: f(x)= 175.136
# differential_evolution step 3: f(x)= 150.14
# differential_evolution step 4: f(x)= 150.14
# differential_evolution step 5: f(x)= 124.543
# differential_evolution step 6: f(x)= 110.314
# differential_evolution step 7: f(x)= 110.314
# differential_evolution step 8: f(x)= 99.3587
# differential_evolution step 9: f(x)= 62.5062
# differential_evolution step 10: f(x)= 62.5062
# differential_evolution step 11: f(x)= 56.6724
# differential_evolution step 12: f(x)= 56.6724
# differential_evolution step 13: f(x)= 56.6724
# differential_evolution step 14: f(x)= 56.268
# differential_evolution step 15: f(x)= 48.6845
# differential_evolution step 16: f(x)= 48.6845
# differential_evolution step 17: f(x)= 48.6845
# differential_evolution step 18: f(x)= 48.6845
# differential_evolution step 19: f(x)= 48.6845
# differential_evolution step 20: f(x)= 48.6845
# differential_evolution step 21: f(x)= 47.6233
# differential_evolution step 22: f(x)= 46.7088
# differential_evolution step 23: f(x)= 46.6003
# differential_evolution step 24: f(x)= 46.3308
# differential_evolution step 25: f(x)= 46.3308
# differential_evolution step 26: f(x)= 46.3308
# differential_evolution step 27: f(x)= 46.2364
# differential_evolution step 28: f(x)= 46.2364
# differential_evolution step 29: f(x)= 46.2364
# differential_evolution step 30: f(x)= 46.0991
# differential_evolution step 31: f(x)= 46.0991
# differential_evolution step 32: f(x)= 46.0918
# differential_evolution step 33: f(x)= 46.0197
# differential_evolution step 34: f(x)= 46.0197
# Solution vector of current run:
# [0.99993006 0.81265735 0.37510756 0.01       0.86015836]
# The run took:
# 00:06:52
# Parameters for run 11:
# [-0.67042665  0.94626505  0.59601366  0.01        0.44712894]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.5190275999999995
# differential_evolution step 1: f(x)= 1678.99
# differential_evolution step 2: f(x)= 1678.99
# differential_evolution step 3: f(x)= 1559.2
# differential_evolution step 4: f(x)= 1559.2
# differential_evolution step 5: f(x)= 1547.87
# differential_evolution step 6: f(x)= 1547.87
# differential_evolution step 7: f(x)= 1547.87
# differential_evolution step 8: f(x)= 1544.87
# differential_evolution step 9: f(x)= 1542.25
# differential_evolution step 10: f(x)= 1542.25
# differential_evolution step 11: f(x)= 1537.96
# differential_evolution step 12: f(x)= 1529.33
# differential_evolution step 13: f(x)= 1527.67
# differential_evolution step 14: f(x)= 1520.77
# differential_evolution step 15: f(x)= 1518.75
# differential_evolution step 16: f(x)= 1518.39
# differential_evolution step 17: f(x)= 1518
# differential_evolution step 18: f(x)= 1518
# differential_evolution step 19: f(x)= 1518
# differential_evolution step 20: f(x)= 1516.87
# differential_evolution step 21: f(x)= 1516.87
# differential_evolution step 22: f(x)= 1516.87
# differential_evolution step 23: f(x)= 1516.87
# differential_evolution step 24: f(x)= 1516.87
# differential_evolution step 25: f(x)= 1516.83
# Solution vector of current run:
# [-0.98081497  0.96581776  0.68667892  0.01        0.66335679]
# The run took:
# 00:05:25
# Parameters for run 12:
# [0.50080156 1.10931429 0.38817201 0.01       0.79904528]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.45984600000000025
# differential_evolution step 1: f(x)= 985.295
# differential_evolution step 2: f(x)= 985.295
# differential_evolution step 3: f(x)= 985.295
# differential_evolution step 4: f(x)= 976.703
# differential_evolution step 5: f(x)= 961.133
# differential_evolution step 6: f(x)= 952.484
# differential_evolution step 7: f(x)= 952.484
# differential_evolution step 8: f(x)= 926.896
# differential_evolution step 9: f(x)= 926.896
# differential_evolution step 10: f(x)= 926.896
# differential_evolution step 11: f(x)= 925.31
# differential_evolution step 12: f(x)= 925.31
# differential_evolution step 13: f(x)= 925.31
# differential_evolution step 14: f(x)= 924.347
# differential_evolution step 15: f(x)= 924.347
# differential_evolution step 16: f(x)= 913.389
# differential_evolution step 17: f(x)= 908.547
# differential_evolution step 18: f(x)= 907.049
# differential_evolution step 19: f(x)= 907.049
# differential_evolution step 20: f(x)= 902.753
# differential_evolution step 21: f(x)= 901.233
# differential_evolution step 22: f(x)= 899.643
# differential_evolution step 23: f(x)= 899.643
# differential_evolution step 24: f(x)= 899.643
# differential_evolution step 25: f(x)= 898.943
# differential_evolution step 26: f(x)= 898.943
# differential_evolution step 27: f(x)= 898.943
# differential_evolution step 28: f(x)= 898.943
# Solution vector of current run:
# [0.44030456 1.05814617 0.40279837 0.01       0.8150938 ]
# The run took:
# 00:05:59
# Parameters for run 13:
# [0.01374545 1.36481727 0.62014355 0.01       0.63642748]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.7143111999999961
# differential_evolution step 1: f(x)= 2262.49
# differential_evolution step 2: f(x)= 1988.46
# differential_evolution step 3: f(x)= 1988.46
# differential_evolution step 4: f(x)= 1988.46
# differential_evolution step 5: f(x)= 1976.26
# differential_evolution step 6: f(x)= 1975.8
# differential_evolution step 7: f(x)= 1975.8
# differential_evolution step 8: f(x)= 1975.8
# differential_evolution step 9: f(x)= 1958.79
# differential_evolution step 10: f(x)= 1958.79
# differential_evolution step 11: f(x)= 1958.79
# differential_evolution step 12: f(x)= 1958.79
# differential_evolution step 13: f(x)= 1958.79
# differential_evolution step 14: f(x)= 1958.79
# differential_evolution step 15: f(x)= 1958.79
# differential_evolution step 16: f(x)= 1958.32
# differential_evolution step 17: f(x)= 1957.83
# differential_evolution step 18: f(x)= 1957.62
# differential_evolution step 19: f(x)= 1956.46
# differential_evolution step 20: f(x)= 1956.46
# differential_evolution step 21: f(x)= 1956.46
# Solution vector of current run:
# [-0.24681026  1.58208645  0.65644257  0.01        0.88124752]
# The run took:
# 00:04:51
# Parameters for run 14:
# [-0.27557605  1.37059152  0.35689067  0.01        0.14555515]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.1905935999999548
# differential_evolution step 1: f(x)= 3601.91
# differential_evolution step 2: f(x)= 3572.27
# differential_evolution step 3: f(x)= 3548.01
# differential_evolution step 4: f(x)= 3526.59
# differential_evolution step 5: f(x)= 3526.59
# differential_evolution step 6: f(x)= 3519.54
# differential_evolution step 7: f(x)= 3519.54
# differential_evolution step 8: f(x)= 3518.56
# differential_evolution step 9: f(x)= 3497.83
# differential_evolution step 10: f(x)= 3495.16
# differential_evolution step 11: f(x)= 3495.16
# differential_evolution step 12: f(x)= 3492.61
# differential_evolution step 13: f(x)= 3492.61
# differential_evolution step 14: f(x)= 3492.61
# differential_evolution step 15: f(x)= 3492.61
# differential_evolution step 16: f(x)= 3492.51
# differential_evolution step 17: f(x)= 3489.48
# Solution vector of current run:
# [-0.12551575  1.57898143  0.30098168  0.01        0.38066616]
# The run took:
# 00:04:36
# Parameters for run 15:
# [0.2344751  1.20078168 0.40299555 0.01       0.79985013]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.5185140000000003
# differential_evolution step 1: f(x)= 1318.68
# differential_evolution step 2: f(x)= 1274.98
# differential_evolution step 3: f(x)= 1270.59
# differential_evolution step 4: f(x)= 1270.59
# differential_evolution step 5: f(x)= 1234.11
# differential_evolution step 6: f(x)= 1234.11
# differential_evolution step 7: f(x)= 1213.6
# differential_evolution step 8: f(x)= 1213.6
# differential_evolution step 9: f(x)= 1213.6
# differential_evolution step 10: f(x)= 1206.22
# differential_evolution step 11: f(x)= 1206.22
# differential_evolution step 12: f(x)= 1206.22
# differential_evolution step 13: f(x)= 1206.22
# differential_evolution step 14: f(x)= 1199.62
# differential_evolution step 15: f(x)= 1199.62
# differential_evolution step 16: f(x)= 1199.62
# differential_evolution step 17: f(x)= 1195.08
# differential_evolution step 18: f(x)= 1195.08
# differential_evolution step 19: f(x)= 1194.6
# differential_evolution step 20: f(x)= 1194.6
# differential_evolution step 21: f(x)= 1194.43
# differential_evolution step 22: f(x)= 1194.43
# differential_evolution step 23: f(x)= 1194.43
# differential_evolution step 24: f(x)= 1194.1
# Solution vector of current run:
# [0.07315676 1.09337573 0.43940792 0.01       0.77537557]
# The run took:
# 00:05:20
# Parameters for run 16:
# [-0.68667142  1.42138675  0.64301785  0.01        0.06216941]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.5395271999999376
# differential_evolution step 1: f(x)= 4354.43
# differential_evolution step 2: f(x)= 4291.51
# differential_evolution step 3: f(x)= 4263.69
# differential_evolution step 4: f(x)= 4263.69
# differential_evolution step 5: f(x)= 4263.69
# differential_evolution step 6: f(x)= 4239.67
# differential_evolution step 7: f(x)= 4230.08
# differential_evolution step 8: f(x)= 4230.08
# differential_evolution step 9: f(x)= 4230.08
# differential_evolution step 10: f(x)= 4230.08
# differential_evolution step 11: f(x)= 4230.08
# differential_evolution step 12: f(x)= 4230.08
# differential_evolution step 13: f(x)= 4230.08
# differential_evolution step 14: f(x)= 4230.08
# Solution vector of current run:
# [-0.88875987  1.47582603  0.6305277   0.01        0.21813463]
# The run took:
# 00:04:24
# Parameters for run 17:
# [0.7995042  0.54690468 0.33363865 0.01       1.1908234 ]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.10247640000000008
# differential_evolution step 1: f(x)= -2798.05
# differential_evolution step 2: f(x)= -2798.05
# differential_evolution step 3: f(x)= -2804.41
# differential_evolution step 4: f(x)= -2804.41
# differential_evolution step 5: f(x)= -2836.25
# differential_evolution step 6: f(x)= -2876.77
# differential_evolution step 7: f(x)= -2876.77
# differential_evolution step 8: f(x)= -2896.17
# differential_evolution step 9: f(x)= -2896.17
# differential_evolution step 10: f(x)= -2912.56
# differential_evolution step 11: f(x)= -2912.56
# differential_evolution step 12: f(x)= -2918.52
# differential_evolution step 13: f(x)= -2918.52
# differential_evolution step 14: f(x)= -2918.52
# differential_evolution step 15: f(x)= -2918.52
# differential_evolution step 16: f(x)= -2918.52
# differential_evolution step 17: f(x)= -2918.52
# differential_evolution step 18: f(x)= -2918.52
# differential_evolution step 19: f(x)= -2918.52
# differential_evolution step 20: f(x)= -2918.52
# differential_evolution step 21: f(x)= -2918.52
# Solution vector of current run:
# [0.26644082 0.51502362 0.37000352 0.01       1.22187632]
# The run took:
# 00:04:18
# Parameters for run 18:
# [-0.79005693  0.74408803  0.3854987   0.01        1.24477499]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.1309828000000001
# differential_evolution step 1: f(x)= -2459.07
# differential_evolution step 2: f(x)= -2684.8
# differential_evolution step 3: f(x)= -2777.83
# differential_evolution step 4: f(x)= -2777.83
# differential_evolution step 5: f(x)= -2843.72
# differential_evolution step 6: f(x)= -2843.72
# differential_evolution step 7: f(x)= -2843.72
# differential_evolution step 8: f(x)= -2846.29
# differential_evolution step 9: f(x)= -2846.29
# differential_evolution step 10: f(x)= -2854.69
# differential_evolution step 11: f(x)= -2868.37
# differential_evolution step 12: f(x)= -2868.37
# differential_evolution step 13: f(x)= -2868.37
# differential_evolution step 14: f(x)= -2873.25
# differential_evolution step 15: f(x)= -2873.25
# differential_evolution step 16: f(x)= -2877.46
# differential_evolution step 17: f(x)= -2877.46
# differential_evolution step 18: f(x)= -2877.46
# differential_evolution step 19: f(x)= -2877.46
# Solution vector of current run:
# [-0.60341939  0.65659147  0.40057841  0.01        1.216365  ]
# The run took:
# 00:03:54
# Parameters for run 19:
# [0.20880701 1.02091752 0.5248894  0.01       0.29237006]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.7057451999999925
# differential_evolution step 1: f(x)= 2804.01
# differential_evolution step 2: f(x)= 2664.08
# differential_evolution step 3: f(x)= 2664.08
# differential_evolution step 4: f(x)= 2633.93
# differential_evolution step 5: f(x)= 2633.93
# differential_evolution step 6: f(x)= 2633.93
# differential_evolution step 7: f(x)= 2633.93
# differential_evolution step 8: f(x)= 2607.82
# differential_evolution step 9: f(x)= 2607.82
# differential_evolution step 10: f(x)= 2607.82
# differential_evolution step 11: f(x)= 2607.82
# differential_evolution step 12: f(x)= 2602.35
# differential_evolution step 13: f(x)= 2602.35
# differential_evolution step 14: f(x)= 2601.91
# differential_evolution step 15: f(x)= 2600.03
# differential_evolution step 16: f(x)= 2600.03
# differential_evolution step 17: f(x)= 2598.13
# differential_evolution step 18: f(x)= 2598.13
# differential_evolution step 19: f(x)= 2597.61
# Solution vector of current run:
# [0.02342231 1.02007479 0.57900834 0.01       0.43795282]
# The run took:
# 00:04:34
# Parameters for run 20:
# [-0.05024534  1.07887587  0.69653311  0.01        1.38215939]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.12381120000000008
# differential_evolution step 1: f(x)= -3521.91
# differential_evolution step 2: f(x)= -3534.4
# differential_evolution step 3: f(x)= -3534.4
# differential_evolution step 4: f(x)= -3631.54
# differential_evolution step 5: f(x)= -3631.54
# differential_evolution step 6: f(x)= -3708.57
# differential_evolution step 7: f(x)= -3708.57
# differential_evolution step 8: f(x)= -3708.57
# differential_evolution step 9: f(x)= -3708.57
# differential_evolution step 10: f(x)= -3724.26
# differential_evolution step 11: f(x)= -3724.93
# differential_evolution step 12: f(x)= -3724.93
# differential_evolution step 13: f(x)= -3750.98
# differential_evolution step 14: f(x)= -3750.98
# differential_evolution step 15: f(x)= -3750.98
# differential_evolution step 16: f(x)= -3754.83
# differential_evolution step 17: f(x)= -3754.83
# differential_evolution step 18: f(x)= -3754.83
# differential_evolution step 19: f(x)= -3754.83
# differential_evolution step 20: f(x)= -3754.83
# differential_evolution step 21: f(x)= -3754.96
# Solution vector of current run:
# [0.17982509 0.98578085 0.68728333 0.01       1.37275126]
# The run took:
# 00:04:33
# Parameters for run 21:
# [0.82185661 0.84238462 0.58465647 0.01       0.44840776]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.3792264000000002
# differential_evolution step 1: f(x)= 649.169
# differential_evolution step 2: f(x)= 649.169
# differential_evolution step 3: f(x)= 649.169
# differential_evolution step 4: f(x)= 649.169
# differential_evolution step 5: f(x)= 638.584
# differential_evolution step 6: f(x)= 633.534
# differential_evolution step 7: f(x)= 615.259
# differential_evolution step 8: f(x)= 615.259
# differential_evolution step 9: f(x)= 615.259
# differential_evolution step 10: f(x)= 615.259
# differential_evolution step 11: f(x)= 612.336
# differential_evolution step 12: f(x)= 612.336
# differential_evolution step 13: f(x)= 609.179
# differential_evolution step 14: f(x)= 606.11
# differential_evolution step 15: f(x)= 602.282
# differential_evolution step 16: f(x)= 602.282
# differential_evolution step 17: f(x)= 602.282
# differential_evolution step 18: f(x)= 602.282
# differential_evolution step 19: f(x)= 602.282
# differential_evolution step 20: f(x)= 599.416
# differential_evolution step 21: f(x)= 599.416
# differential_evolution step 22: f(x)= 599.416
# differential_evolution step 23: f(x)= 599.416
# differential_evolution step 24: f(x)= 599.416
# differential_evolution step 25: f(x)= 599.271
# differential_evolution step 26: f(x)= 599.271
# differential_evolution step 27: f(x)= 599.271
# differential_evolution step 28: f(x)= 599.271
# differential_evolution step 29: f(x)= 599.011
# Solution vector of current run:
# [0.7397649  0.88371004 0.6024198  0.01       0.663833  ]
# The run took:
# 00:06:02
# Parameters for run 22:
# [-0.63509136  0.89861248  0.39822812  0.01        0.35684026]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.4453355999999993
# differential_evolution step 1: f(x)= 1145.95
# differential_evolution step 2: f(x)= 1087.9
# differential_evolution step 3: f(x)= 1059.4
# differential_evolution step 4: f(x)= 1052.38
# differential_evolution step 5: f(x)= 962.084
# differential_evolution step 6: f(x)= 958.806
# differential_evolution step 7: f(x)= 958.806
# differential_evolution step 8: f(x)= 958.806
# differential_evolution step 9: f(x)= 958.806
# differential_evolution step 10: f(x)= 958.806
# differential_evolution step 11: f(x)= 958.806
# differential_evolution step 12: f(x)= 958.806
# differential_evolution step 13: f(x)= 958.806
# differential_evolution step 14: f(x)= 956.141
# differential_evolution step 15: f(x)= 956.141
# differential_evolution step 16: f(x)= 956.018
# differential_evolution step 17: f(x)= 954.926
# differential_evolution step 18: f(x)= 954.926
# differential_evolution step 19: f(x)= 954.926
# differential_evolution step 20: f(x)= 954.517
# Solution vector of current run:
# [-0.56966842  0.85629422  0.38560464  0.01        0.5430383 ]
# The run took:
# 00:04:25
# Parameters for run 23:
# [0.22360331 1.8712689  0.53701776 0.01       0.05475788]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 2.7636191999999453
# differential_evolution step 1: f(x)= 7523.05
# differential_evolution step 2: f(x)= 7077.55
# differential_evolution step 3: f(x)= 6792.54
# differential_evolution step 4: f(x)= 6664.99
# differential_evolution step 5: f(x)= 6641.27
# differential_evolution step 6: f(x)= 6639.8
# differential_evolution step 7: f(x)= 6619.99
# differential_evolution step 8: f(x)= 6554.16
# differential_evolution step 9: f(x)= 6476.86
# differential_evolution step 10: f(x)= 6476.86
# differential_evolution step 11: f(x)= 6476.86
# differential_evolution step 12: f(x)= 6476.86
# differential_evolution step 13: f(x)= 6476.86
# differential_evolution step 14: f(x)= 6476.86
# differential_evolution step 15: f(x)= 6476.86
# differential_evolution step 16: f(x)= 6476.86
# differential_evolution step 17: f(x)= 6476.86
# differential_evolution step 18: f(x)= 6476.86
# differential_evolution step 19: f(x)= 6472.5
# differential_evolution step 20: f(x)= 6471.8
# differential_evolution step 21: f(x)= 6471.8
# differential_evolution step 22: f(x)= 6471.8
# differential_evolution step 23: f(x)= 6471.8
# differential_evolution step 24: f(x)= 6468
# differential_evolution step 25: f(x)= 6468
# differential_evolution step 26: f(x)= 6468
# differential_evolution step 27: f(x)= 6468
# Solution vector of current run:
# [0.04964693 1.99941142 0.53077931 0.01       0.28242005]
# The run took:
# 00:08:04
# Parameters for run 24:
# [0.28218884 1.99519141 0.64339725 0.01       0.15894184]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 2.1121307999999264
# differential_evolution step 1: f(x)= 5339.04
# differential_evolution step 2: f(x)= 5250.91
# differential_evolution step 3: f(x)= 5250.91
# differential_evolution step 4: f(x)= 5250.91
# differential_evolution step 5: f(x)= 5250.91
# differential_evolution step 6: f(x)= 5170.23
# differential_evolution step 7: f(x)= 5170.23
# differential_evolution step 8: f(x)= 5170.23
# differential_evolution step 9: f(x)= 5170.23
# differential_evolution step 10: f(x)= 5170.23
# differential_evolution step 11: f(x)= 5170.23
# differential_evolution step 12: f(x)= 5134.01
# differential_evolution step 13: f(x)= 5134.01
# differential_evolution step 14: f(x)= 5134.01
# differential_evolution step 15: f(x)= 5134.01
# differential_evolution step 16: f(x)= 5134.01
# differential_evolution step 17: f(x)= 5134.01
# differential_evolution step 18: f(x)= 5118.31
# differential_evolution step 19: f(x)= 5085.25
# differential_evolution step 20: f(x)= 5017.17
# differential_evolution step 21: f(x)= 5017.17
# differential_evolution step 22: f(x)= 5017.17
# differential_evolution step 23: f(x)= 5017.17
# differential_evolution step 24: f(x)= 5017.17
# differential_evolution step 25: f(x)= 5017.17
# differential_evolution step 26: f(x)= 5017.17
# differential_evolution step 27: f(x)= 5017.17
# differential_evolution step 28: f(x)= 5017.17
# differential_evolution step 29: f(x)= 4985.63
# differential_evolution step 30: f(x)= 4985.63
# differential_evolution step 31: f(x)= 4985.63
# differential_evolution step 32: f(x)= 4985.63
# differential_evolution step 33: f(x)= 4985.63
# differential_evolution step 34: f(x)= 4985.63
# differential_evolution step 35: f(x)= 4982.62
# differential_evolution step 36: f(x)= 4974.24
# differential_evolution step 37: f(x)= 4973.55
# differential_evolution step 38: f(x)= 4973.55
# differential_evolution step 39: f(x)= 4973.55
# differential_evolution step 40: f(x)= 4973.55
# Solution vector of current run:
# [0.32307233 1.999716   0.61193619 0.01       0.27650848]
# The run took:
# 00:10:16
# Parameters for run 25:
# [-0.02171092  0.66287941  0.44319007  0.01        0.56628873]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.2697220000000002
# differential_evolution step 1: f(x)= 150.011
# differential_evolution step 2: f(x)= 150.011
# differential_evolution step 3: f(x)= 150.011
# differential_evolution step 4: f(x)= 134.642
# differential_evolution step 5: f(x)= 134.642
# differential_evolution step 6: f(x)= 134.642
# differential_evolution step 7: f(x)= 134.642
# differential_evolution step 8: f(x)= 134.642
# differential_evolution step 9: f(x)= 129.077
# differential_evolution step 10: f(x)= 128.949
# differential_evolution step 11: f(x)= 128.949
# differential_evolution step 12: f(x)= 124.782
# differential_evolution step 13: f(x)= 124.782
# differential_evolution step 14: f(x)= 124.782
# differential_evolution step 15: f(x)= 124.782
# differential_evolution step 16: f(x)= 122.711
# differential_evolution step 17: f(x)= 122.711
# differential_evolution step 18: f(x)= 122.711
# differential_evolution step 19: f(x)= 122.167
# differential_evolution step 20: f(x)= 120.963
# differential_evolution step 21: f(x)= 120.283
# differential_evolution step 22: f(x)= 120.283
# differential_evolution step 23: f(x)= 120.078
# differential_evolution step 24: f(x)= 119.943
# differential_evolution step 25: f(x)= 119.907
# differential_evolution step 26: f(x)= 119.907
# differential_evolution step 27: f(x)= 119.879
# differential_evolution step 28: f(x)= 119.778
# differential_evolution step 29: f(x)= 119.721
# differential_evolution step 30: f(x)= 119.689
# Solution vector of current run:
# [0.48392444 0.68284891 0.37441709 0.01       0.77969306]
# The run took:
# 00:06:10
# Parameters for run 26:
# [0.20418951 1.76221027 0.43241013 0.01       1.20567511]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.4544932000000003
# differential_evolution step 1: f(x)= -253.135
# differential_evolution step 2: f(x)= -253.135
# differential_evolution step 3: f(x)= -459.674
# differential_evolution step 4: f(x)= -459.674
# differential_evolution step 5: f(x)= -459.674
# differential_evolution step 6: f(x)= -459.674
# differential_evolution step 7: f(x)= -459.674
# differential_evolution step 8: f(x)= -470.892
# differential_evolution step 9: f(x)= -470.892
# differential_evolution step 10: f(x)= -470.892
# differential_evolution step 11: f(x)= -478.038
# differential_evolution step 12: f(x)= -478.038
# differential_evolution step 13: f(x)= -478.038
# differential_evolution step 14: f(x)= -478.038
# differential_evolution step 15: f(x)= -478.038
# differential_evolution step 16: f(x)= -478.038
# differential_evolution step 17: f(x)= -480.673
# differential_evolution step 18: f(x)= -482.852
# differential_evolution step 19: f(x)= -482.852
# differential_evolution step 20: f(x)= -482.852
# differential_evolution step 21: f(x)= -483.328
# differential_evolution step 22: f(x)= -486.528
# differential_evolution step 23: f(x)= -488.441
# differential_evolution step 24: f(x)= -488.441
# differential_evolution step 25: f(x)= -488.441
# differential_evolution step 26: f(x)= -488.441
# differential_evolution step 27: f(x)= -488.441
# differential_evolution step 28: f(x)= -488.646
# differential_evolution step 29: f(x)= -488.646
# Solution vector of current run:
# [0.18253168 1.89811933 0.45438792 0.01       1.26388089]
# The run took:
# 00:06:09
# Parameters for run 27:
# [0.47649762 0.35565638 0.34728892 0.01       0.96976037]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.07454920000000005
# differential_evolution step 1: f(x)= -2371.92
# differential_evolution step 2: f(x)= -2881.08
# differential_evolution step 3: f(x)= -2966.77
# differential_evolution step 4: f(x)= -2966.77
# differential_evolution step 5: f(x)= -2966.77
# differential_evolution step 6: f(x)= -2966.77
# differential_evolution step 7: f(x)= -3014.86
# differential_evolution step 8: f(x)= -3014.86
# differential_evolution step 9: f(x)= -3065.96
# differential_evolution step 10: f(x)= -3065.96
# differential_evolution step 11: f(x)= -3065.96
# differential_evolution step 12: f(x)= -3065.96
# differential_evolution step 13: f(x)= -3065.96
# differential_evolution step 14: f(x)= -3065.96
# differential_evolution step 15: f(x)= -3080.66
# differential_evolution step 16: f(x)= -3080.66
# differential_evolution step 17: f(x)= -3102.39
# differential_evolution step 18: f(x)= -3102.39
# differential_evolution step 19: f(x)= -3103.75
# differential_evolution step 20: f(x)= -3103.75
# differential_evolution step 21: f(x)= -3103.75
# differential_evolution step 22: f(x)= -3103.75
# differential_evolution step 23: f(x)= -3103.75
# differential_evolution step 24: f(x)= -3103.75
# Solution vector of current run:
# [-0.31250552  0.30027988  0.34714344  0.01        1.20067214]
# The run took:
# 00:04:47
# Parameters for run 28:
# [-0.58195825  0.39356398  0.47842328  0.01        0.02234873]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.16496640000000012
# differential_evolution step 1: f(x)= -260.183
# differential_evolution step 2: f(x)= -1036.74
# differential_evolution step 3: f(x)= -1036.74
# differential_evolution step 4: f(x)= -1036.74
# differential_evolution step 5: f(x)= -1036.74
# differential_evolution step 6: f(x)= -1036.74
# differential_evolution step 7: f(x)= -1036.74
# differential_evolution step 8: f(x)= -1036.74
# differential_evolution step 9: f(x)= -1036.74
# differential_evolution step 10: f(x)= -1036.74
# differential_evolution step 11: f(x)= -1036.74
# differential_evolution step 12: f(x)= -1057.25
# differential_evolution step 13: f(x)= -1057.25
# differential_evolution step 14: f(x)= -1057.25
# differential_evolution step 15: f(x)= -1060.4
# differential_evolution step 16: f(x)= -1060.4
# differential_evolution step 17: f(x)= -1060.4
# differential_evolution step 18: f(x)= -1060.4
# differential_evolution step 19: f(x)= -1060.4
# differential_evolution step 20: f(x)= -1060.49
# differential_evolution step 21: f(x)= -1060.71
# differential_evolution step 22: f(x)= -1060.71
# differential_evolution step 23: f(x)= -1063.43
# differential_evolution step 24: f(x)= -1063.43
# differential_evolution step 25: f(x)= -1067.22
# differential_evolution step 26: f(x)= -1067.22
# differential_evolution step 27: f(x)= -1067.22
# differential_evolution step 28: f(x)= -1067.22
# differential_evolution step 29: f(x)= -1067.22
# differential_evolution step 30: f(x)= -1067.22
# differential_evolution step 31: f(x)= -1068.44
# differential_evolution step 32: f(x)= -1068.44
# differential_evolution step 33: f(x)= -1068.44
# differential_evolution step 34: f(x)= -1069.33
# differential_evolution step 35: f(x)= -1069.33
# differential_evolution step 36: f(x)= -1069.6
# differential_evolution step 37: f(x)= -1069.6
# Solution vector of current run:
# [-0.9995607   0.30332143  0.47224638  0.01        0.14768829]
# The run took:
# 00:07:21
# Parameters for run 29:
# [-0.07338276  1.50779589  0.59473953  0.01        0.64841842]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.8357395999999914
# differential_evolution step 1: f(x)= 2491.24
# differential_evolution step 2: f(x)= 2460.25
# differential_evolution step 3: f(x)= 2405.33
# differential_evolution step 4: f(x)= 2363.32
# differential_evolution step 5: f(x)= 2360.33
# differential_evolution step 6: f(x)= 2360.33
# differential_evolution step 7: f(x)= 2350.12
# differential_evolution step 8: f(x)= 2350.12
# differential_evolution step 9: f(x)= 2350.12
# differential_evolution step 10: f(x)= 2344.51
# differential_evolution step 11: f(x)= 2344.25
# differential_evolution step 12: f(x)= 2344.25
# differential_evolution step 13: f(x)= 2343.41
# differential_evolution step 14: f(x)= 2342.61
# differential_evolution step 15: f(x)= 2342.61
# differential_evolution step 16: f(x)= 2342.61
# Solution vector of current run:
# [-0.19374758  1.5314631   0.61786993  0.01        0.74253464]
# The run took:
# 00:04:03
# Parameters for run 30:
# [-0.8836793   0.99876529  0.49237994  0.01        0.26471163]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.6107507999999955
# differential_evolution step 1: f(x)= 1840.13
# differential_evolution step 2: f(x)= 1694.28
# differential_evolution step 3: f(x)= 1664.01
# differential_evolution step 4: f(x)= 1664.01
# differential_evolution step 5: f(x)= 1664.01
# differential_evolution step 6: f(x)= 1659.96
# differential_evolution step 7: f(x)= 1659.96
# differential_evolution step 8: f(x)= 1656.75
# differential_evolution step 9: f(x)= 1656.36
# differential_evolution step 10: f(x)= 1656.36
# differential_evolution step 11: f(x)= 1655.34
# differential_evolution step 12: f(x)= 1655.34
# differential_evolution step 13: f(x)= 1655.16
# differential_evolution step 14: f(x)= 1654.93
# Solution vector of current run:
# [-0.92728002  1.0119373   0.50715787  0.01        0.53181599]
# The run took:
# 00:03:26
# Parameters for run 31:
# [0.56160774 1.40027892 0.68233048 0.01       0.08946894]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.088115999999962
# differential_evolution step 1: f(x)= 4965.86
# differential_evolution step 2: f(x)= 4965.86
# differential_evolution step 3: f(x)= 4965.86
# differential_evolution step 4: f(x)= 4891.11
# differential_evolution step 5: f(x)= 4891.11
# differential_evolution step 6: f(x)= 4891.11
# differential_evolution step 7: f(x)= 4891.11
# differential_evolution step 8: f(x)= 4891.11
# differential_evolution step 9: f(x)= 4891.11
# differential_evolution step 10: f(x)= 3993.55
# differential_evolution step 11: f(x)= 3993.55
# differential_evolution step 12: f(x)= 3993.55
# differential_evolution step 13: f(x)= 3993.55
# differential_evolution step 14: f(x)= 3949.31
# differential_evolution step 15: f(x)= 3946.98
# differential_evolution step 16: f(x)= 3946.98
# differential_evolution step 17: f(x)= 3871.8
# ...
# differential_evolution step 7: f(x)= -1998.96
# differential_evolution step 8: f(x)= -1998.96
# differential_evolution step 9: f(x)= -1998.96
# differential_evolution step 10: f(x)= -1999.63
# differential_evolution step 11: f(x)= -1999.63
# differential_evolution step 12: f(x)= -2004.17
# differential_evolution step 13: f(x)= -2007.39
# differential_evolution step 14: f(x)= -2008.63
# differential_evolution step 15: f(x)= -2009.52
# differential_evolution step 16: f(x)= -2009.79
# differential_evolution step 17: f(x)= -2009.79
# differential_evolution step 18: f(x)= -2009.79
# differential_evolution step 19: f(x)= -2009.79
# differential_evolution step 20: f(x)= -2010.76
# differential_evolution step 21: f(x)= -2013.73
# Solution vector of current run:
# [-0.32816559  0.43620342  0.69981902  0.01        0.88468127]
# The run took:
# 00:04:14
# Parameters for run 90:
# [0.45619766 1.65186377 0.38828441 0.01       0.06886572]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 2.1246947999999226
# differential_evolution step 1: f(x)= 5638.05
# differential_evolution step 2: f(x)= 5638.05
# differential_evolution step 3: f(x)= 5638.05
# differential_evolution step 4: f(x)= 5553.54
# differential_evolution step 5: f(x)= 5535.55
# differential_evolution step 6: f(x)= 5535.55
# differential_evolution step 7: f(x)= 5389.66
# differential_evolution step 8: f(x)= 5389.66
# differential_evolution step 9: f(x)= 5389.66
# differential_evolution step 10: f(x)= 5389.66
# differential_evolution step 11: f(x)= 5389.66
# differential_evolution step 12: f(x)= 5389.66
# differential_evolution step 13: f(x)= 5389.66
# differential_evolution step 14: f(x)= 5389.66
# differential_evolution step 15: f(x)= 5389.66
# differential_evolution step 16: f(x)= 5389.66
# differential_evolution step 17: f(x)= 5389.66
# differential_evolution step 18: f(x)= 5389.66
# differential_evolution step 19: f(x)= 5389.66
# differential_evolution step 20: f(x)= 5370.15
# differential_evolution step 21: f(x)= 5368.16
# differential_evolution step 22: f(x)= 5348.11
# differential_evolution step 23: f(x)= 5348.11
# differential_evolution step 24: f(x)= 5343.99
# differential_evolution step 25: f(x)= 5343.99
# differential_evolution step 26: f(x)= 5343.99
# differential_evolution step 27: f(x)= 5343.99
# Solution vector of current run:
# [0.52956061 1.83169519 0.30311217 0.01       0.25195109]
# The run took:
# 00:07:27
# Parameters for run 91:
# [0.11414562 1.4751789  0.41702143 0.01       0.66610763]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.789726399999994
# differential_evolution step 1: f(x)= 2264
# differential_evolution step 2: f(x)= 2216.69
# differential_evolution step 3: f(x)= 2210.2
# differential_evolution step 4: f(x)= 2210.2
# differential_evolution step 5: f(x)= 2196.52
# differential_evolution step 6: f(x)= 2196.52
# differential_evolution step 7: f(x)= 2196.52
# differential_evolution step 8: f(x)= 2196.52
# differential_evolution step 9: f(x)= 2185.43
# differential_evolution step 10: f(x)= 2185.43
# differential_evolution step 11: f(x)= 2185.43
# differential_evolution step 12: f(x)= 2174.09
# differential_evolution step 13: f(x)= 2174.09
# differential_evolution step 14: f(x)= 2174.09
# differential_evolution step 15: f(x)= 2174.09
# differential_evolution step 16: f(x)= 2173.82
# differential_evolution step 17: f(x)= 2173.74
# differential_evolution step 18: f(x)= 2172.8
# differential_evolution step 19: f(x)= 2171.83
# differential_evolution step 20: f(x)= 2171.83
# differential_evolution step 21: f(x)= 2167.81
# differential_evolution step 22: f(x)= 2167.81
# differential_evolution step 23: f(x)= 2167.81
# differential_evolution step 24: f(x)= 2143.7
# differential_evolution step 25: f(x)= 2134.08
# Solution vector of current run:
# [0.40715593 1.94663061 0.39202741 0.01       1.06679671]
# The run took:
# 00:05:41
# Parameters for run 92:
# [-0.8614965   1.01557516  0.41231151  0.01        0.32628183]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.5219143999999976
# differential_evolution step 1: f(x)= 1168.97
# differential_evolution step 2: f(x)= 1168.97
# differential_evolution step 3: f(x)= 1168.97
# differential_evolution step 4: f(x)= 1166.1
# differential_evolution step 5: f(x)= 1166.1
# differential_evolution step 6: f(x)= 1139.98
# differential_evolution step 7: f(x)= 1138.69
# differential_evolution step 8: f(x)= 1138.5
# differential_evolution step 9: f(x)= 1138.5
# differential_evolution step 10: f(x)= 1138.5
# differential_evolution step 11: f(x)= 1135.73
# differential_evolution step 12: f(x)= 1135.37
# differential_evolution step 13: f(x)= 1135.37
# differential_evolution step 14: f(x)= 1135.37
# differential_evolution step 15: f(x)= 1133.6
# differential_evolution step 16: f(x)= 1133.6
# Solution vector of current run:
# [-0.75353415  0.96678402  0.41136648  0.01        0.53774758]
# The run took:
# 00:03:44
# Parameters for run 93:
# [-0.94771385  1.96269941  0.40933261  0.01        0.14995792]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.4193627999999459
# differential_evolution step 1: f(x)= 2904.03
# differential_evolution step 2: f(x)= 2875.02
# differential_evolution step 3: f(x)= 2875.02
# differential_evolution step 4: f(x)= 2861.01
# differential_evolution step 5: f(x)= 2861.01
# differential_evolution step 6: f(x)= 2774.81
# differential_evolution step 7: f(x)= 2774.81
# differential_evolution step 8: f(x)= 2762.78
# differential_evolution step 9: f(x)= 2752.79
# differential_evolution step 10: f(x)= 2752.79
# differential_evolution step 11: f(x)= 2752.79
# differential_evolution step 12: f(x)= 2752.79
# differential_evolution step 13: f(x)= 2752.79
# differential_evolution step 14: f(x)= 2751.09
# differential_evolution step 15: f(x)= 2748.99
# differential_evolution step 16: f(x)= 2748.99
# differential_evolution step 17: f(x)= 2748.99
# differential_evolution step 18: f(x)= 2748.99
# differential_evolution step 19: f(x)= 2748.99
# differential_evolution step 20: f(x)= 2748.99
# differential_evolution step 21: f(x)= 2748.69
# differential_evolution step 22: f(x)= 2748.69
# differential_evolution step 23: f(x)= 2748.69
# differential_evolution step 24: f(x)= 2748.69
# differential_evolution step 25: f(x)= 2748.56
# differential_evolution step 26: f(x)= 2748.56
# differential_evolution step 27: f(x)= 2748.56
# differential_evolution step 28: f(x)= 2748.56
# Solution vector of current run:
# [-0.92354533  1.99424817  0.43813301  0.01        0.45744275]
# The run took:
# 00:07:02
# Parameters for run 94:
# [-0.7852135   0.30094616  0.6785083   0.01        0.19422216]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.08463160000000006
# differential_evolution step 1: f(x)= -1695.95
# differential_evolution step 2: f(x)= -1913.14
# differential_evolution step 3: f(x)= -1913.14
# differential_evolution step 4: f(x)= -1913.14
# differential_evolution step 5: f(x)= -1954.96
# differential_evolution step 6: f(x)= -1954.96
# differential_evolution step 7: f(x)= -1982.34
# differential_evolution step 8: f(x)= -1982.34
# differential_evolution step 9: f(x)= -1982.34
# differential_evolution step 10: f(x)= -2013.2
# differential_evolution step 11: f(x)= -2023.75
# differential_evolution step 12: f(x)= -2023.75
# differential_evolution step 13: f(x)= -2023.75
# differential_evolution step 14: f(x)= -2038.31
# differential_evolution step 15: f(x)= -2038.31
# differential_evolution step 16: f(x)= -2038.31
# differential_evolution step 17: f(x)= -2038.31
# differential_evolution step 18: f(x)= -2038.31
# differential_evolution step 19: f(x)= -2048.14
# differential_evolution step 20: f(x)= -2048.14
# differential_evolution step 21: f(x)= -2048.14
# differential_evolution step 22: f(x)= -2048.14
# differential_evolution step 23: f(x)= -2048.14
# differential_evolution step 24: f(x)= -2053.15
# differential_evolution step 25: f(x)= -2053.15
# differential_evolution step 26: f(x)= -2053.15
# differential_evolution step 27: f(x)= -2053.15
# differential_evolution step 28: f(x)= -2053.15
# differential_evolution step 29: f(x)= -2053.15
# differential_evolution step 30: f(x)= -2054.84
# differential_evolution step 31: f(x)= -2054.84
# differential_evolution step 32: f(x)= -2054.84
# differential_evolution step 33: f(x)= -2054.84
# differential_evolution step 34: f(x)= -2054.84
# differential_evolution step 35: f(x)= -2054.84
# Solution vector of current run:
# [-0.13125538  0.309538    0.65255219  0.01        0.65288084]
# The run took:
# 00:06:51
# Parameters for run 95:
# [0.50043053 0.60444812 0.56859892 0.01       0.96457029]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.1618756000000001
# differential_evolution step 1: f(x)= -1484.42
# differential_evolution step 2: f(x)= -1538.14
# differential_evolution step 3: f(x)= -1617.03
# differential_evolution step 4: f(x)= -1661.11
# differential_evolution step 5: f(x)= -1661.11
# differential_evolution step 6: f(x)= -1661.11
# differential_evolution step 7: f(x)= -1704.65
# differential_evolution step 8: f(x)= -1716.89
# differential_evolution step 9: f(x)= -1725.99
# differential_evolution step 10: f(x)= -1731.04
# differential_evolution step 11: f(x)= -1731.04
# differential_evolution step 12: f(x)= -1731.04
# differential_evolution step 13: f(x)= -1731.77
# differential_evolution step 14: f(x)= -1731.77
# differential_evolution step 15: f(x)= -1731.77
# differential_evolution step 16: f(x)= -1733.83
# differential_evolution step 17: f(x)= -1733.83
# differential_evolution step 18: f(x)= -1737.95
# differential_evolution step 19: f(x)= -1737.95
# differential_evolution step 20: f(x)= -1739.77
# differential_evolution step 21: f(x)= -1739.77
# differential_evolution step 22: f(x)= -1739.77
# differential_evolution step 23: f(x)= -1739.77
# differential_evolution step 24: f(x)= -1740.97
# differential_evolution step 25: f(x)= -1740.97
# differential_evolution step 26: f(x)= -1740.97
# differential_evolution step 27: f(x)= -1740.97
# Solution vector of current run:
# [-0.29473008  0.64589368  0.65576708  0.01        1.10480299]
# The run took:
# 00:05:38
# Parameters for run 96:
# [0.35069859 0.65057992 0.43495633 0.01       0.44011033]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.28934240000000017
# differential_evolution step 1: f(x)= 529.956
# differential_evolution step 2: f(x)= 490.582
# differential_evolution step 3: f(x)= 490.582
# differential_evolution step 4: f(x)= 490.582
# differential_evolution step 5: f(x)= 490.582
# differential_evolution step 6: f(x)= 490.582
# differential_evolution step 7: f(x)= 490.582
# differential_evolution step 8: f(x)= 471.067
# differential_evolution step 9: f(x)= 471.067
# differential_evolution step 10: f(x)= 468.943
# differential_evolution step 11: f(x)= 468.943
# differential_evolution step 12: f(x)= 468.943
# differential_evolution step 13: f(x)= 468.943
# differential_evolution step 14: f(x)= 468.943
# differential_evolution step 15: f(x)= 468.943
# differential_evolution step 16: f(x)= 468.405
# differential_evolution step 17: f(x)= 468.041
# differential_evolution step 18: f(x)= 467.562
# differential_evolution step 19: f(x)= 467.562
# differential_evolution step 20: f(x)= 467.562
# differential_evolution step 21: f(x)= 467.562
# Solution vector of current run:
# [0.68840269 0.68633676 0.34789966 0.01       0.7555023 ]
# The run took:
# 00:04:45
# Parameters for run 97:
# [-0.27635447  0.79056528  0.41751443  0.01        1.37011417]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.10827440000000008
# differential_evolution step 1: f(x)= -3865.74
# differential_evolution step 2: f(x)= -3865.74
# differential_evolution step 3: f(x)= -3990.91
# differential_evolution step 4: f(x)= -3990.91
# differential_evolution step 5: f(x)= -3990.91
# differential_evolution step 6: f(x)= -3990.91
# differential_evolution step 7: f(x)= -3990.91
# differential_evolution step 8: f(x)= -3990.91
# differential_evolution step 9: f(x)= -3990.91
# differential_evolution step 10: f(x)= -4030.33
# differential_evolution step 11: f(x)= -4116.29
# differential_evolution step 12: f(x)= -4119.74
# differential_evolution step 13: f(x)= -4130.02
# differential_evolution step 14: f(x)= -4130.02
# differential_evolution step 15: f(x)= -4130.02
# differential_evolution step 16: f(x)= -4132.52
# differential_evolution step 17: f(x)= -4132.52
# differential_evolution step 18: f(x)= -4132.52
# differential_evolution step 19: f(x)= -4132.52
# differential_evolution step 20: f(x)= -4132.52
# differential_evolution step 21: f(x)= -4132.57
# differential_evolution step 22: f(x)= -4163.62
# differential_evolution step 23: f(x)= -4163.62
# differential_evolution step 24: f(x)= -4178.19
# differential_evolution step 25: f(x)= -4178.19
# differential_evolution step 26: f(x)= -4178.19
# differential_evolution step 27: f(x)= -4178.19
# differential_evolution step 28: f(x)= -4178.19
# differential_evolution step 29: f(x)= -4180.47
# differential_evolution step 30: f(x)= -4183.62
# differential_evolution step 31: f(x)= -4183.62
# differential_evolution step 32: f(x)= -4183.67
# differential_evolution step 33: f(x)= -4184.11
# differential_evolution step 34: f(x)= -4189.28
# differential_evolution step 35: f(x)= -4189.28
# differential_evolution step 36: f(x)= -4189.28
# Solution vector of current run:
# [0.85675778 0.88412955 0.37382731 0.01       1.42786635]
# The run took:
# 00:07:24
# Parameters for run 98:
# [-0.2284566   1.29038317  0.35213001  0.01        0.6285919 ]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.6137027999999978
# differential_evolution step 1: f(x)= 1683.3
# differential_evolution step 2: f(x)= 1683.3
# differential_evolution step 3: f(x)= 1584.1
# differential_evolution step 4: f(x)= 1579.54
# differential_evolution step 5: f(x)= 1579.54
# differential_evolution step 6: f(x)= 1567.49
# differential_evolution step 7: f(x)= 1563.12
# differential_evolution step 8: f(x)= 1549.18
# differential_evolution step 9: f(x)= 1547.95
# differential_evolution step 10: f(x)= 1547.95
# differential_evolution step 11: f(x)= 1536.25
# differential_evolution step 12: f(x)= 1534.42
# differential_evolution step 13: f(x)= 1533.29
# differential_evolution step 14: f(x)= 1533.29
# differential_evolution step 15: f(x)= 1532.85
# differential_evolution step 16: f(x)= 1532.53
# differential_evolution step 17: f(x)= 1530.26
# differential_evolution step 18: f(x)= 1529.7
# differential_evolution step 19: f(x)= 1529.7
# differential_evolution step 20: f(x)= 1529.7
# Solution vector of current run:
# [-0.04103673  1.25608665  0.30188407  0.01        0.70420149]
# The run took:
# 00:04:46
# Parameters for run 99:
# [0.9345391  0.95439847 0.34189449 0.01       0.32847378]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.5727671999999978
# differential_evolution step 1: f(x)= 2006.77
# differential_evolution step 2: f(x)= 2006.77
# differential_evolution step 3: f(x)= 1932.16
# differential_evolution step 4: f(x)= 1932.16
# differential_evolution step 5: f(x)= 1924.68
# differential_evolution step 6: f(x)= 1924.68
# differential_evolution step 7: f(x)= 1924.68
# differential_evolution step 8: f(x)= 1924.68
# differential_evolution step 9: f(x)= 1924.68
# differential_evolution step 10: f(x)= 1924.68
# differential_evolution step 11: f(x)= 1924.68
# differential_evolution step 12: f(x)= 1924.68
# differential_evolution step 13: f(x)= 1924.68
# differential_evolution step 14: f(x)= 1924.68
# differential_evolution step 15: f(x)= 1924.68
# differential_evolution step 16: f(x)= 1924.68
# differential_evolution step 17: f(x)= 1924.68
# differential_evolution step 18: f(x)= 1923.9
# differential_evolution step 19: f(x)= 1923.9
# differential_evolution step 20: f(x)= 1916.93
# differential_evolution step 21: f(x)= 1916.84
# differential_evolution step 22: f(x)= 1916.84
# differential_evolution step 23: f(x)= 1916.51
# differential_evolution step 24: f(x)= 1913.34
# differential_evolution step 25: f(x)= 1913.34
# differential_evolution step 26: f(x)= 1913.34
# Solution vector of current run:
# [0.91749621 0.8759046  0.31114191 0.01       0.14798809]
# The run took:
# 00:06:02

# %%
# Read in results
optim_results = pd.read_csv(mle_out_path + '/mle_results.csv')

# %%
plt.scatter(optim_results['v_sim'], optim_results['v_mle'], c = optim_results['theta_mle'])

# %%
# Regression for v
reg = LinearRegression().fit(np.expand_dims(optim_results['v_mle'], 1), np.expand_dims(optim_results['v_sim'], 1))
reg.score(np.expand_dims(optim_results['v_mle'], 1), np.expand_dims(optim_results['v_sim'], 1))
# Out:
# 0.617887802768772

# %%
plt.scatter(optim_results['a_sim'], optim_results['a_mle'], c = optim_results['theta_mle'])

# %%
# Regression for a
reg = LinearRegression().fit(np.expand_dims(optim_results['a_mle'], 1), np.expand_dims(optim_results['a_sim'], 1))
reg.score(np.expand_dims(optim_results['a_mle'], 1), np.expand_dims(optim_results['a_sim'], 1))
# Out:
# 0.9278981038056895

# %%
plt.scatter(optim_results['w_sim'], optim_results['w_mle'])

# %%
# Regression for w
reg = LinearRegression().fit(np.expand_dims(optim_results['w_mle'], 1), np.expand_dims(optim_results['w_sim'], 1))
reg.score(np.expand_dims(optim_results['w_mle'], 1), np.expand_dims(optim_results['w_sim'], 1))
# Out:
# 0.8762772986396704

# %%
plt.scatter(optim_results['theta_sim'], optim_results['theta_mle'])

# %%
# Regression for c1
reg = LinearRegression().fit(np.expand_dims(optim_results['theta_mle'], 1), np.expand_dims(optim_results['theta_sim'], 1))
reg.score(np.expand_dims(optim_results['theta_mle'], 1), np.expand_dims(optim_results['theta_sim'], 1))
# Out:
# 0.8890366364460973

# %%
plt.scatter(optim_results['c2_sim'], optim_results['c2_mle'], c = optim_results['a_mle'])

# %%
# Regression for w
reg = LinearRegression().fit(np.expand_dims(optim_results['c2_mle'], 1), np.expand_dims(optim_results['c2_sim'], 1))
reg.score(np.expand_dims(optim_results['c2_mle'], 1), np.expand_dims(optim_results['c2_sim'], 1))
