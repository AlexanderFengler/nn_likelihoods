# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import load_model
import numpy as np
import os
import pandas as pd
import time
import psutil
import argparse
from datetime import datetime
import pickle
import yaml
from copy import deepcopy

# %%
# Plotting
import matplotlib.pyplot as plt
plt.style.use('default')
# %matplotlib inline

# %%
# Toy problem
def create_book_example(n = 1000):
    X = np.random.uniform(0., 1., size = (n, 1)).astype(np.float32)
    y = X + (0.3 * np.sin(4 * np.pi * X)) + np.random.uniform(- 0.1, 0.1, size = (n, 1)).astype(np.float32)
    
    # test data
    x_test = np.linspace(0, 1, n).reshape(-1, 1).astype(np.float32)
    return X, y, x_test

# %%
def create_spiral(n = 1000, a = 2, noise_range = 0.1, z_range = (0, 1)):
    z1 = np.random.uniform(z_range[0], z_range[1], size = (n, 1)).astype(np.float32)
    x1 = a * np.cos(1 * np.pi * z1) + (noise_range / 2) * np.random.uniform(- 1, 1, size = (n, 1)).astype(np.float32)
    y1 = a * np.sin(1 * np.pi * z1) + (noise_range / 2) * np.random.uniform(- 1, 1, size = (n, 1)).astype(np.float32)
    z2 = np.random.uniform(z_range[0], z_range[1], size = (n, 1)).astype(np.float32)
    x2 = (a / 2)  * np.cos(1 * np.pi * z2) + (noise_range / 2) * np.random.uniform(- 1, 1, size = (n, 1)).astype(np.float32)
    y2 = (a / 2)  * np.sin(1 * np.pi * z2) + (noise_range / 2) * np.random.uniform(- 1, 1, size = (n, 1)).astype(np.float32)
    
    x = np.concatenate([x1, x2])
    y = np.concatenate([y1, y2])
    z = np.concatenate([z1, z2])
    
    noise_range_out = np.array([noise_range]*(n * 2))
    z_test = np.linspace(z_range[0], z_range[1], n * 2).reshape(-1, 1).astype(np.float32)
    return (x, y, z, z_test) #, noise_range_out)

# %%
from mpl_toolkits import mplot3d

# %%
ax = plt.axes(projection='3d')
x, y, z, z_test = create_spiral(n = 10000, noise_range = 0.3)

#x, y, z, n = create_spiral(n = 3000, noise_range = 0.2)

# Data for three-dimensional scattered points
#zdata = 15 * np.random.random(100)
#xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
#ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(z, x, y, c = z[:, 0], alpha = 0.2) #cmap = 'Greens', alpha = 0.2);

# %%
train_labels = np.concatenate([x,y], axis = 1)

# %%
train_labels.shape
# Out:
# (20000, 2)

# %%
# Plot data (x and y)
X, y, x_test = create_book_example(n = 10000)
plt.plot(X, y,'ro', alpha = 0.04)
plt.show()

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
tf.executing_eagerly()
# Out:
# True

# %%
def get_model(h = 16, lr = 0.001):
    
    input = tf.keras.layers.Input(shape = (1, ))
    x = tf.keras.layers.Dense(h, activation = 'tanh')(input)
    x = tf.keras.layers.Dense(1, activation = None)(x)
    
    model = tf.keras.models.Model(input, x)
    
    model.compile(optimizer = tf.keras.optimizers.Adam(lr = lr), loss = 'mse', metrics = ['acc'])
    return model

# %%
# Load and train the network

model = get_model(h = 50)
epochs = 1000

# %%
history = model.fit(X, y, epochs = epochs, verbose = 0)

# Plot the loss history
plt.plot(range(epochs), history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training')
plt.show()

# %%
# Predict the target values for test data and
# plot along with training data
y_test = model.predict(x_test)
plt.plot(X, y, 'ro', alpha=0.05, label='train')
plt.plot(x_test, y_test, 'bo', alpha=0.3, label='test')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Plot train and test data')
plt.show()

# %%
# print data shape
print(X.shape, y.shape)

# Deepcopy is not required in this case
# (its more of a habit for me)
flipped_x = deepcopy(y)
flipped_y = deepcopy(X)

# load and train the model
#model = get_model(lr=0.09)

# Train the model for large number of epochs
epochs = 1500

#history = model.fit(flipped_x, flipped_y, epochs = epochs, verbose = 0)

# print(history.history['loss'][-1])
# plt.plot(range(epochs), history.history['loss'])
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.title('Training')
# plt.show()
# Out:
# (10000, 1) (10000, 1)

# %%
# epochs 500
x_test_inv = np.linspace(0., 1., 4000).reshape(-1, 1)
y_test_inv = model.predict(x_test_inv)

plt.plot(y, X, 'ro', alpha=0.05)
plt.plot(x_test_inv, y_test_inv, 'b.', alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-489c7e85510d> in <module>
#       1 # epochs 500
#       2 x_test_inv = np.linspace(0., 1., 4000).reshape(-1, 1)
# ----> 3 y_test_inv = model.predict(x_test_inv)
#       4
#       5 plt.plot(y, X, 'ro', alpha=0.05)
#
# NameError: name 'model' is not defined

# %%
# In our toy example, we have single input feature
l = 1

# Number of dimensions in output
dim_out = 2

# Number of gaussians to represent the multimodal distribution
k = 5

# Network
def get_mdn_1d():  # this is the one we need for ddm anyways..
    input = tf.keras.Input(shape = (l,))
    layer = tf.keras.layers.Dense(100, activation = 'tanh', name = 'baselayer')(input)
    #layer = tf.keras.layers.Dense(100, activation = 'tanh', name = 'baselayer2')(layer)
    mu = tf.keras.layers.Dense((l * k), activation = None, name = 'mean_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = - 1, maxval = 1, seed = None))(layer)
    # variance (should be greater than 0 so we exponentiate it)
    var = tf.keras.layers.Dense(k, activation = 'exponential', name = 'dense_var_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = - 10, maxval = 10, seed = None))(layer)
    #var = tf.keras.layers.Lambda(lambda x: tf.math.exp(x), output_shape = (k, ), name = 'variance_layer')(var)
    # mixing coefficient should sum to 1.0
    pi = tf.keras.layers.Dense(k, activation = 'softmax', name = 'pi_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = 0, maxval = 1, seed = None))(layer)
    model = tf.keras.models.Model(input, [pi, mu, var])
    optimizer = tf.keras.optimizers.Adam()
    return (model, optimizer)

# %%
def get_mdn_full_cov():
    input = tf.keras.Input(shape = (l, ))
    layer = tf.keras.layers.Dense(50, activation = 'tanh', name = 'baselayer')(input)
    layer = tf.keras.layers.Dense(100, activation = 'tanh', name = 'baselayer')(layer)
    mu = tf.keras.layers.Dense((l * k), activation = None, name = 'mean_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = -1, maxval = 1, seed = None))(layer)
    pi = tf.keras.layers.Dense(k, acitvation = 'softmax', name = 'pi_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = 0, maxvar = 1, seed = None))(layer)
    model = tf.keras.models.Model(input, [pi, mu, var ])

# %%
def get_mdn_iso():
    input = tf.keras.Input(shape = (l, ))
    layer = tf.keras.layers.Dense(50, activation = 'tanh', name = 'baselayer')(input)
    #layer = tf.keras.layers.Dense(100, activation = 'tanh', name = 'baselayer2')(layer)
    mu = tf.keras.layers.Dense((dim_out * k), activation = None, name = 'mean_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = -1, maxval = 1, seed = None))(layer)
    mu = tf.keras.layers.Reshape((k, dim_out), name = 'mean_layer_reshaped')(mu)
    pi = tf.keras.layers.Dense(k, activation = 'softmax', name = 'pi_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = -1, maxval = 1, seed = None))(layer)
    var = tf.keras.layers.Dense((dim_out * k), activation = 'softplus', name = 'dense_var_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = 5, maxval = 10, seed = None))(layer)
    var = tf.keras.layers.Reshape((k, dim_out), name = 'var_layer_reshaped')(var)
    model = tf.keras.models.Model(input, [pi, mu, var])
    optimizer = tf.keras.optimizers.Adam()
    return (model, optimizer)

# %%
def calc_pdf_iso(y, mu, var):
    """Calculate Component Density"""
    var = var
    inv_var = tf.linalg.diag(1 / var)
    #print(inv_var.shape)
    inv_var_det = tf.sqrt(tf.linalg.det(inv_var))
    #print(inv_var_det.shape)
    y_proper = tf.expand_dims(y, 1)
    diff = tf.expand_dims(tf.subtract(y_proper, mu), - 1)
    #print(diff.shape)
    diff_transp = tf.transpose(diff, perm = [0, 1, 3, 2])
    #print(diff_transp.shape)
    exponent = (- 1 / 2) * tf.matmul(tf.matmul(diff_transp, inv_var), diff)
    #print(exponent.shape)
    denominator = 1 / tf.sqrt(tf.pow(np.pi, dim_out))
    #determinantf = tf.sqrt(tf.linalg.det(inv_var))
    #value = tf.multiply(tf.exp(exponent), inv_var_det)                     
    value = denominator * tf.multiply(tf.exp(exponent), inv_var_det)
    #value = tf.exp(tf.divide(tf.square(tf.subtract(y, mu)), 2 * var)) # Gaussian exp
    #value = (1 / 2 * np.pi * var)) * tf.exp( (- value) / (2 * var))
    
    
    return value

def mdn_loss_iso(y_true, pi, mu, var, omega = 0.001):
    """MDN Loss Function"""
    out = calc_pdf_iso(y_true, mu, var)
    out = tf.multiply(out, pi)
    # print(out)
    out = tf.reduce_sum(out, 1, keepdims = True)
    inv_var_red = tf.reduce_sum(1 / var, (1, 2), keepdims = True)
    out = - tf.math.log(out + 1e-10) + (omega * inv_var_red)
    return tf.reduce_mean(out)

# %%
mdn_iso, optimizer = get_mdn_iso()

# %%
ma = np.ones((6000, 50, 2))
mb = np.ones((6000, 2))

# %%
mc = mb.reshape((6000, 1, 2))

# %%
(mc - ma).shape
# Out:
# (6000, 50, 2)

# %%
mdn, optimizer = get_mdn()

# %%
mdn_iso.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# baselayer (Dense)               (None, 50)           100         input_3[0][0]
# __________________________________________________________________________________________________
# mean_layer (Dense)              (None, 10)           510         baselayer[0][0]
# __________________________________________________________________________________________________
# dense_var_layer (Dense)         (None, 10)           510         baselayer[0][0]
# __________________________________________________________________________________________________
# pi_layer (Dense)                (None, 5)            255         baselayer[0][0]
# __________________________________________________________________________________________________
# mean_layer_reshaped (Reshape)   (None, 5, 2)         0           mean_layer[0][0]
# __________________________________________________________________________________________________
# var_layer_reshaped (Reshape)    (None, 5, 2)         0           dense_var_layer[0][0]
# ==================================================================================================
# Total params: 1,375
# Trainable params: 1,375
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def calc_pdf(y, mu, var):
    """Calculate Component Density"""
    value = tf.square(tf.subtract(y, mu)) 
    value = (1 / tf.sqrt(2 * np.pi * var)) * tf.exp( (- value) / (2 * var))
    return value

def mdn_loss(y_true, pi, mu, var):
    """MDN Loss Function"""
    out = calc_pdf(y_true, mu, var)
    out = tf.multiply(out, pi)
    # print(out)
    out = tf.reduce_sum(out, 1, keepdims = True)
    out = - tf.math.log(out + 1e-10)
    return tf.reduce_mean(out)

# %%
mdn_loss(np.array([3.0]), np.array([0.3, 0.3, 0.3]), np.array([0.0, 0.1, 0.2]), np.array([1.0, 2.2, 3.3])).numpy()
# Out:
# tf.Tensor([0.00132955 0.01193233 0.02008562], shape=(3,), dtype=float64)
# 4.986388754226722

# %%
# Use Dataset API to load numpy data (load, shuffle, set batch size)
N = flipped_x.shape[0]
dataset = tf.data.Dataset \
    .from_tensor_slices((flipped_x, flipped_y)) \
    .shuffle(N).batch(N)

# %%
# USE DATASET API TO LOAD NUMPY DATA (SPIRAL)
N = train_labels.shape[0]
dataset = tf.data.Dataset \
          .from_tensor_slices((z, train_labels)) \
          .shuffle(N).batch(256)

# %%
# Train step ISO
@tf.function
def train_step(model, optimizer, train_x, train_y):
    # GradientTape: Trace operations to compute gradients
    with tf.GradientTape() as tape:
        pi_, mu_, var_ = model(train_x, training = True)
        # calculate loss
        loss = mdn_loss_iso(train_y, pi_, mu_, var_)
    # compute and apply gradients
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss

# %%
# Train iso
losses = []
EPOCHS = 10
print_every = 1 #int(EPOCHS)

# Define model and optimizer
#model = tf.keras.models.Model(input, [pi, mu, var])
#optimizer = tf.keras.optimizers.Adam()
#model, optimizer = get_mdn()

# Start training
print('Print every {} epochs'.format(print_every))
for i in range(EPOCHS):
    for train_x, train_y in dataset:
        loss = train_step(mdn_iso, optimizer, train_x, train_y)
        losses.append(loss)
    if i % print_every == 0:
        print('Epoch {}/{}: loss {}'.format(i, EPOCHS, losses[-1]))
# Out:
# Print every 1 epochs
# Epoch 0/10: loss 3.108503818511963
# Epoch 1/10: loss 2.531630039215088
# Epoch 2/10: loss 1.551066517829895
# Epoch 3/10: loss 1.4870150089263916
# Epoch 4/10: loss 1.2553894519805908
# Epoch 5/10: loss 1.0686042308807373
# Epoch 6/10: loss 1.0680667161941528
# Epoch 7/10: loss 1.014343500137329
# Epoch 8/10: loss 1.0442781448364258
# Epoch 9/10: loss 1.013906717300415

# %%
# ISO PREDICTIONS
# def approx_conditional_mode(pi, var, mu):
#     """Approx conditional mode
#     Because the conditional mode for MDN does not have simple analytical
#     solution, an alternative is to take mean of most probable component 
#     at each value of x (PRML, page 277)
#     """
#     n, k = pi.shape
#     out = np.zeros((n, l))
#     # Get the index of max pi value for each row
#     max_component = tf.argmax(pi, axis=1)
#     for i in range(n):
#         # The mean value for this index will be used
#         mc = max_component[i].numpy()
#         for j in range(l):
#             out[i, j] = mu[i, mc * (l + j)]
#     return out


# Get predictions
pi_vals, mu_vals, var_vals = mdn_iso.predict(z_test)
print(pi_vals.shape, mu_vals.shape, var_vals.shape)

# Get mean of max(mixing coefficient) of each row
#preds = approx_conditional_mode(pi_vals, var_vals, mu_vals)

# Plot along with training data
# fig = plt.figure(figsize = (8, 8))
# plt.plot(flipped_x, flipped_y, 'ro')
# plt.plot(x_test, preds, 'g.')
# # plt.plot(flipped_x, preds2, 'b.')
# plt.show()
# Out:
# (20000, 5) (20000, 5, 2) (20000, 5, 2)

# %%
pi_vals[2000, :]
# Out:
# array([0.19985025, 0.19960189, 0.20084637, 0.19934   , 0.20036153],
#       dtype=float32)

# %%
mu_vals[2000, :]
# Out:
# array([[1.9068712 , 1.3690759 ],
#        [1.8976997 , 1.6555158 ],
#        [0.9753718 , 0.52907866],
#        [1.6755805 , 0.6993543 ],
#        [1.1472218 , 0.7156348 ]], dtype=float32)

# %%
var_vals[1900:2000, :]
# Out:
# array([[[0.17964932, 0.4335612 ],
#         [0.17374316, 0.61006504],
#         [0.1387005 , 0.19809234],
#         [0.31175423, 0.35008892],
#         [0.24377514, 0.33576548]],
#
#        [[0.17964445, 0.43355334],
#         [0.17373826, 0.610028  ],
#         [0.13869749, 0.1980856 ],
#         [0.3117278 , 0.3500764 ],
#         [0.24376112, 0.3357377 ]],
#
#        [[0.17963918, 0.4335456 ],
#         [0.17373395, 0.6099934 ],
#         [0.13869458, 0.19807886],
#         [0.31170154, 0.35006392],
#         [0.24374563, 0.3357095 ]],
#
#        [[0.1796338 , 0.43353757],
#         [0.17372954, 0.60995686],
#         [0.13869168, 0.1980722 ],
#         [0.31167567, 0.35005164],
#         [0.2437304 , 0.33568096]],
#
#        [[0.17962901, 0.43352982],
#         [0.17372532, 0.60992086],
#         [0.13868867, 0.19806576],
#         [0.3116494 , 0.3500392 ],
#         [0.24371591, 0.3356529 ]],
#
#        [[0.17962362, 0.4335221 ],
#         [0.17372063, 0.60988545],
#         [0.13868567, 0.19805871],
#         [0.3116233 , 0.350026  ],
#         [0.24370068, 0.33562487]],
#
#        [[0.17961864, 0.43351454],
#         [0.17371622, 0.6098495 ],
#         [0.13868286, 0.19805206],
#         [0.31159702, 0.35001376],
#         [0.24368602, 0.33559692]],
#
#        [[0.17961347, 0.43350634],
#         [0.17371179, 0.6098138 ],
#         [0.13867985, 0.19804561],
#         [0.31157073, 0.35000148],
#         [0.24367078, 0.33556837]],
#
#        [[0.17960839, 0.43349844],
#         [0.1737074 , 0.6097779 ],
#         [0.13867673, 0.19803905],
#         [0.31154448, 0.34998852],
#         [0.24365592, 0.33554068]],
#
#        [[0.1796035 , 0.43349072],
#         [0.17370299, 0.6097426 ],
#         [0.13867383, 0.1980321 ],
#         [0.3115182 , 0.34997585],
#         [0.24364069, 0.33551288]],
#
#        [[0.17959803, 0.43348286],
#         [0.17369868, 0.6097067 ],
#         [0.13867094, 0.19802575],
#         [0.31149238, 0.34996375],
#         [0.24362603, 0.33548492]],
#
#        [[0.17959306, 0.43347582],
#         [0.17369387, 0.6096708 ],
#         [0.1386678 , 0.19801891],
#         [0.31146634, 0.34995133],
#         [0.2436108 , 0.33545664]],
#
#        [[0.17958757, 0.4334678 ],
#         [0.17368956, 0.60963464],
#         [0.13866492, 0.19801225],
#         [0.3114398 , 0.3499383 ],
#         [0.24359548, 0.33542866]],
#
#        [[0.1795826 , 0.43346006],
#         [0.17368484, 0.6095998 ],
#         [0.13866189, 0.19800569],
#         [0.31141344, 0.34992602],
#         [0.2435809 , 0.3354004 ]],
#
#        [[0.17957751, 0.43345216],
#         [0.17368044, 0.60956323],
#         [0.1386589 , 0.19799896],
#         [0.3113875 , 0.34991354],
#         [0.24356604, 0.3353721 ]],
#
#        [[0.17957233, 0.43344468],
#         [0.17367594, 0.60952777],
#         [0.1386561 , 0.1979926 ],
#         [0.31136122, 0.3499011 ],
#         [0.2435512 , 0.33534464]],
#
#        [[0.17956735, 0.4334364 ],
#         [0.17367183, 0.60949236],
#         [0.13865297, 0.19798546],
#         [0.31133503, 0.3498883 ],
#         [0.24353614, 0.33531615]],
#
#        [[0.17956218, 0.4334291 ],
#         [0.17366691, 0.6094562 ],
#         [0.13864997, 0.19797881],
#         [0.31130865, 0.34987605],
#         [0.24352072, 0.3352882 ]],
#
#        [[0.17955689, 0.4334212 ],
#         [0.173663  , 0.6094203 ],
#         [0.13864715, 0.19797206],
#         [0.31128278, 0.34986353],
#         [0.24350578, 0.33526024]],
#
#        [[0.17955181, 0.4334136 ],
#         [0.1736584 , 0.60938466],
#         [0.13864416, 0.19796541],
#         [0.31125662, 0.349851  ],
#         [0.243491  , 0.3352322 ]],
#
#        [[0.17954683, 0.43340588],
#         [0.17365429, 0.60934937],
#         [0.13864113, 0.19795896],
#         [0.3112306 , 0.34983873],
#         [0.24347615, 0.3352042 ]],
#
#        [[0.17954165, 0.43339768],
#         [0.17364947, 0.60931283],
#         [0.13863814, 0.1979521 ],
#         [0.31120422, 0.34982565],
#         [0.24346149, 0.33517602]],
#
#        [[0.17953648, 0.4333898 ],
#         [0.17364487, 0.60927737],
#         [0.13863523, 0.19794565],
#         [0.31117785, 0.3498131 ],
#         [0.24344672, 0.33514804]],
#
#        [[0.17953159, 0.4333827 ],
#         [0.17364067, 0.60924256],
#         [0.13863221, 0.19793901],
#         [0.31115192, 0.34980077],
#         [0.2434312 , 0.33511972]],
#
#        [[0.1795261 , 0.43337464],
#         [0.17363624, 0.60920596],
#         [0.1386294 , 0.19793226],
#         [0.3111258 , 0.3497882 ],
#         [0.24341682, 0.33509177]],
#
#        [[0.17952122, 0.43336716],
#         [0.17363164, 0.6091703 ],
#         [0.13862652, 0.19792531],
#         [0.31109995, 0.34977573],
#         [0.24340157, 0.33506438]],
#
#        [[0.17951575, 0.43335927],
#         [0.17362744, 0.6091346 ],
#         [0.13862339, 0.19791895],
#         [0.31107357, 0.34976304],
#         [0.24338615, 0.33503616]],
#
#        [[0.17951076, 0.43335193],
#         [0.17362311, 0.6090994 ],
#         [0.1386205 , 0.1979123 ],
#         [0.31104708, 0.3497508 ],
#         [0.24337186, 0.3350076 ]],
#
#        [[0.17950578, 0.43334422],
#         [0.17361861, 0.6090627 ],
#         [0.13861747, 0.19790556],
#         [0.31102118, 0.34973842],
#         [0.24335644, 0.33497968]],
#
#        [[0.1795007 , 0.43333593],
#         [0.1736142 , 0.6090272 ],
#         [0.13861467, 0.19789921],
#         [0.31099486, 0.34972548],
#         [0.24334186, 0.33495224]],
#
#        [[0.17949553, 0.4333283 ],
#         [0.1736098 , 0.6089919 ],
#         [0.13861167, 0.19789244],
#         [0.31096902, 0.3497128 ],
#         [0.24332653, 0.33492428]],
#
#        [[0.17949055, 0.43332055],
#         [0.1736054 , 0.6089561 ],
#         [0.13860875, 0.1978856 ],
#         [0.31094262, 0.34970078],
#         [0.24331158, 0.33489552]],
#
#        [[0.17948526, 0.43331298],
#         [0.17360097, 0.60892   ],
#         [0.13860576, 0.19787905],
#         [0.31091636, 0.34968802],
#         [0.2432969 , 0.33486757]],
#
#        [[0.17948018, 0.4333051 ],
#         [0.17359656, 0.60888493],
#         [0.13860273, 0.1978724 ],
#         [0.31089064, 0.34967548],
#         [0.24328166, 0.33484018]],
#
#        [[0.1794749 , 0.43329754],
#         [0.17359185, 0.60884863],
#         [0.13859983, 0.19786556],
#         [0.31086445, 0.34966332],
#         [0.2432669 , 0.33481196]],
#
#        [[0.17947023, 0.43328947],
#         [0.17358744, 0.6088136 ],
#         [0.13859683, 0.197859  ],
#         [0.3108384 , 0.34965086],
#         [0.2432527 , 0.33478397]],
#
#        [[0.17946504, 0.43328175],
#         [0.17358305, 0.6087773 ],
#         [0.13859391, 0.19785254],
#         [0.31081203, 0.34963766],
#         [0.24323717, 0.33475608]],
#
#        [[0.17945956, 0.43327403],
#         [0.17357893, 0.6087419 ],
#         [0.13859102, 0.1978459 ],
#         [0.31078592, 0.34962583],
#         [0.24322213, 0.33472863]],
#
#        [[0.17945439, 0.43326637],
#         [0.17357461, 0.608706  ],
#         [0.13858812, 0.19783923],
#         [0.31076014, 0.34961322],
#         [0.24320735, 0.33469936]],
#
#        [[0.1794495 , 0.4332589 ],
#         [0.17357011, 0.6086701 ],
#         [0.1385852 , 0.1978326 ],
#         [0.31073365, 0.34960052],
#         [0.2431925 , 0.33467197]],
#
#        [[0.17944431, 0.433251  ],
#         [0.1735659 , 0.6086347 ],
#         [0.1385821 , 0.19782574],
#         [0.310707  , 0.3495882 ],
#         [0.24317773, 0.33464402]],
#
#        [[0.17943934, 0.4332431 ],
#         [0.17356119, 0.60859925],
#         [0.1385793 , 0.19781949],
#         [0.31068158, 0.34957606],
#         [0.2431624 , 0.33461663]],
#
#        [[0.17943436, 0.43323556],
#         [0.1735569 , 0.608563  ],
#         [0.13857637, 0.19781263],
#         [0.31065512, 0.34956315],
#         [0.24314763, 0.33458814]],
#
#        [[0.17942898, 0.43322766],
#         [0.17355238, 0.60852826],
#         [0.13857338, 0.19780599],
#         [0.31062925, 0.34955087],
#         [0.24313286, 0.33456022]],
#
#        [[0.17942399, 0.43321976],
#         [0.17354795, 0.6084921 ],
#         [0.13857047, 0.19779924],
#         [0.3106032 , 0.34953833],
#         [0.24311799, 0.33453274]],
#
#        [[0.17941882, 0.4332122 ],
#         [0.17354356, 0.6084565 ],
#         [0.13856755, 0.19779278],
#         [0.31057715, 0.34952548],
#         [0.24310276, 0.3345041 ]],
#
#        [[0.17941384, 0.43320447],
#         [0.17353924, 0.6084208 ],
#         [0.13856445, 0.19778602],
#         [0.31055123, 0.3495132 ],
#         [0.24308752, 0.3344767 ]],
#
#        [[0.17940864, 0.4331971 ],
#         [0.17353472, 0.6083854 ],
#         [0.13856153, 0.19777948],
#         [0.310525  , 0.34950027],
#         [0.24307358, 0.33444846]],
#
#        [[0.17940347, 0.43318906],
#         [0.17353033, 0.6083499 ],
#         [0.13855854, 0.19777283],
#         [0.3104989 , 0.34948817],
#         [0.24305855, 0.3344206 ]],
#
#        [[0.17939858, 0.4331809 ],
#         [0.17352572, 0.6083135 ],
#         [0.13855584, 0.19776618],
#         [0.31047258, 0.34947556],
#         [0.24304293, 0.3343929 ]],
#
#        [[0.1793933 , 0.4331737 ],
#         [0.17352171, 0.6082783 ],
#         [0.13855281, 0.19775963],
#         [0.3104466 , 0.34946314],
#         [0.24302852, 0.3343645 ]],
#
#        [[0.17938812, 0.43316597],
#         [0.1735171 , 0.60824263],
#         [0.13854982, 0.19775288],
#         [0.31042066, 0.34945044],
#         [0.24301367, 0.33433688]],
#
#        [[0.17938295, 0.4331584 ],
#         [0.17351268, 0.60820657],
#         [0.13854681, 0.19774622],
#         [0.31039435, 0.34943858],
#         [0.24299861, 0.33430886]],
#
#        [[0.17937797, 0.43315065],
#         [0.17350848, 0.6081714 ],
#         [0.13854411, 0.19773985],
#         [0.3103683 , 0.34942555],
#         [0.24298365, 0.3342807 ]],
#
#        [[0.17937258, 0.43314278],
#         [0.17350365, 0.60813504],
#         [0.138541  , 0.19773291],
#         [0.31034252, 0.34941334],
#         [0.24296926, 0.3342534 ]],
#
#        [[0.179368  , 0.43313512],
#         [0.17349966, 0.6080994 ],
#         [0.13853787, 0.19772656],
#         [0.3103163 , 0.3494009 ],
#         [0.24295355, 0.33422542]],
#
#        [[0.17936273, 0.43312755],
#         [0.17349505, 0.6080644 ],
#         [0.13853517, 0.1977199 ],
#         [0.31029025, 0.34938815],
#         [0.24293916, 0.33419698]],
#
#        [[0.17935754, 0.4331195 ],
#         [0.17349064, 0.6080288 ],
#         [0.13853227, 0.19771317],
#         [0.3102641 , 0.34937587],
#         [0.2429242 , 0.33416933]],
#
#        [[0.17935255, 0.433112  ],
#         [0.17348643, 0.6079934 ],
#         [0.13852938, 0.1977064 ],
#         [0.3102381 , 0.3493635 ],
#         [0.24290875, 0.33414143]],
#
#        [[0.17934757, 0.43310443],
#         [0.17348182, 0.607958  ],
#         [0.13852625, 0.19769986],
#         [0.31021178, 0.34935096],
#         [0.24289435, 0.33411413]],
#
#        [[0.17934239, 0.43309653],
#         [0.173478  , 0.60792124],
#         [0.13852355, 0.1976933 ],
#         [0.31018582, 0.34933853],
#         [0.2428795 , 0.3340856 ]],
#
#        [[0.1793372 , 0.433089  ],
#         [0.173473  , 0.6078857 ],
#         [0.13852043, 0.19768684],
#         [0.31015992, 0.3493257 ],
#         [0.24286434, 0.33405742]],
#
#        [[0.17933233, 0.43308148],
#         [0.17346899, 0.6078496 ],
#         [0.13851753, 0.19768019],
#         [0.31013405, 0.34931365],
#         [0.24284975, 0.33402961]],
#
#        [[0.17932715, 0.43307328],
#         [0.17346437, 0.6078153 ],
#         [0.13851473, 0.19767372],
#         [0.3101077 , 0.34930155],
#         [0.2428347 , 0.334002  ]],
#
#        [[0.17932197, 0.4330661 ],
#         [0.17346017, 0.6077795 ],
#         [0.13851184, 0.19766688],
#         [0.31008196, 0.3492888 ],
#         [0.24281994, 0.3339738 ]],
#
#        [[0.17931698, 0.4330582 ],
#         [0.17345545, 0.60774434],
#         [0.13850881, 0.19766033],
#         [0.31005588, 0.34927583],
#         [0.24280535, 0.33394623]],
#
#        [[0.17931151, 0.4330503 ],
#         [0.17345135, 0.6077089 ],
#         [0.13850582, 0.19765368],
#         [0.3100299 , 0.34926355],
#         [0.24278992, 0.33391804]],
#
#        [[0.17930683, 0.4330426 ],
#         [0.17344633, 0.6076724 ],
#         [0.13850302, 0.19764704],
#         [0.3100036 , 0.34925136],
#         [0.24277571, 0.33389065]],
#
#        [[0.17930184, 0.43303502],
#         [0.17344262, 0.60763663],
#         [0.1385001 , 0.19764036],
#         [0.3099778 , 0.34923884],
#         [0.24276073, 0.33386254]],
#
#        [[0.17929636, 0.43302697],
#         [0.17343782, 0.60760206],
#         [0.13849708, 0.19763371],
#         [0.3099514 , 0.3492265 ],
#         [0.24274595, 0.33383465]],
#
#        [[0.17929138, 0.43301964],
#         [0.1734339 , 0.607566  ],
#         [0.13849407, 0.19762707],
#         [0.30992535, 0.34921414],
#         [0.24273072, 0.3338068 ]],
#
#        [[0.1792863 , 0.4330116 ],
#         [0.1734293 , 0.6075302 ],
#         [0.13849117, 0.19762051],
#         [0.30989927, 0.34920117],
#         [0.24271585, 0.33377865]],
#
#        [[0.17928132, 0.43300453],
#         [0.17342508, 0.60749483],
#         [0.13848826, 0.19761395],
#         [0.30987322, 0.34918925],
#         [0.24270108, 0.33375078]],
#
#        [[0.17927612, 0.4329965 ],
#         [0.17342047, 0.607459  ],
#         [0.13848546, 0.19760741],
#         [0.30984744, 0.34917682],
#         [0.2426863 , 0.3337229 ]],
#
#        [[0.17927136, 0.4329891 ],
#         [0.17341608, 0.6074234 ],
#         [0.13848245, 0.19760065],
#         [0.30982128, 0.3491642 ],
#         [0.24267113, 0.3336958 ]],
#
#        [[0.17926627, 0.43298143],
#         [0.17341167, 0.60738826],
#         [0.13847955, 0.1975943 ],
#         [0.3097955 , 0.34915173],
#         [0.24265692, 0.33366713]],
#
#        [[0.1792612 , 0.43297356],
#         [0.17340755, 0.6073524 ],
#         [0.13847665, 0.19758753],
#         [0.30976945, 0.3491393 ],
#         [0.24264131, 0.33363956]],
#
#        [[0.1792563 , 0.43296567],
#         [0.17340285, 0.6073168 ],
#         [0.13847353, 0.1975807 ],
#         [0.30974334, 0.34912655],
#         [0.24262671, 0.33361197]],
#
#        [[0.17925082, 0.432958  ],
#         [0.17339842, 0.607281  ],
#         [0.13847083, 0.19757433],
#         [0.3097173 , 0.3491146 ],
#         [0.24261166, 0.33358377]],
#
#        [[0.17924593, 0.4329506 ],
#         [0.17339441, 0.6072463 ],
#         [0.13846782, 0.1975675 ],
#         [0.3096913 , 0.34910178],
#         [0.2425967 , 0.3335563 ]],
#
#        [[0.17924047, 0.4329427 ],
#         [0.1733901 , 0.6072103 ],
#         [0.13846481, 0.19756103],
#         [0.30966517, 0.34908944],
#         [0.24258211, 0.3335281 ]],
#
#        [[0.17923568, 0.43293512],
#         [0.17338559, 0.6071747 ],
#         [0.1384619 , 0.19755438],
#         [0.30963945, 0.34907722],
#         [0.24256751, 0.3335005 ]],
#
#        [[0.1792308 , 0.4329273 ],
#         [0.17338099, 0.6071391 ],
#         [0.138459  , 0.19754791],
#         [0.3096134 , 0.34906447],
#         [0.24255235, 0.3334729 ]],
#
#        [[0.17922541, 0.4329198 ],
#         [0.17337678, 0.6071037 ],
#         [0.1384562 , 0.19754136],
#         [0.3095876 , 0.3490522 ],
#         [0.24253759, 0.33344474]],
#
#        [[0.17922072, 0.43291205],
#         [0.17337236, 0.6070679 ],
#         [0.13845329, 0.1975348 ],
#         [0.30956116, 0.3490401 ],
#         [0.2425228 , 0.33341724]],
#
#        [[0.17921545, 0.43290463],
#         [0.17336796, 0.6070332 ],
#         [0.13845049, 0.19752815],
#         [0.30953556, 0.34902707],
#         [0.24250802, 0.33338937]],
#
#        [[0.17921057, 0.4328966 ],
#         [0.17336376, 0.60699713],
#         [0.13844746, 0.19752169],
#         [0.3095095 , 0.3490147 ],
#         [0.24249345, 0.33336154]],
#
#        [[0.17920509, 0.4328889 ],
#         [0.17335914, 0.6069616 ],
#         [0.13844457, 0.19751485],
#         [0.3094834 , 0.34900233],
#         [0.24247865, 0.33333313]],
#
#        [[0.17920011, 0.4328811 ],
#         [0.17335473, 0.606926  ],
#         [0.13844188, 0.1975082 ],
#         [0.30945697, 0.3489903 ],
#         [0.2424637 , 0.33330554]],
#
#        [[0.17919561, 0.43287402],
#         [0.17335092, 0.6068902 ],
#         [0.13843864, 0.19750154],
#         [0.30943137, 0.3489776 ],
#         [0.2424489 , 0.33327803]],
#
#        [[0.17919023, 0.43286598],
#         [0.17334631, 0.6068555 ],
#         [0.13843565, 0.19749518],
#         [0.3094058 , 0.3489656 ],
#         [0.24243365, 0.33325016]],
#
#        [[0.17918536, 0.43285826],
#         [0.17334199, 0.6068201 ],
#         [0.13843262, 0.19748853],
#         [0.30937967, 0.3489529 ],
#         [0.24241906, 0.33322206]],
#
#        [[0.17918007, 0.43285108],
#         [0.17333749, 0.60678387],
#         [0.13842994, 0.19748206],
#         [0.30935323, 0.34894   ],
#         [0.2424041 , 0.33319423]],
#
#        [[0.1791751 , 0.4328434 ],
#         [0.17333317, 0.6067481 ],
#         [0.13842693, 0.19747512],
#         [0.30932707, 0.34892774],
#         [0.24238914, 0.33316696]],
#
#        [[0.17916961, 0.43283555],
#         [0.17332877, 0.606713  ],
#         [0.13842413, 0.19746886],
#         [0.30930144, 0.34891537],
#         [0.24237473, 0.33313876]],
#
#        [[0.17916462, 0.4328278 ],
#         [0.17332426, 0.6066772 ],
#         [0.13842133, 0.19746211],
#         [0.30927607, 0.34890318],
#         [0.24235976, 0.333111  ]],
#
#        [[0.17915973, 0.4328199 ],
#         [0.17331985, 0.6066418 ],
#         [0.1384183 , 0.19745556],
#         [0.30924967, 0.34889066],
#         [0.24234498, 0.33308315]],
#
#        [[0.17915446, 0.4328127 ],
#         [0.17331573, 0.60660666],
#         [0.1384156 , 0.1974489 ],
#         [0.3092237 , 0.34887826],
#         [0.24232954, 0.33305556]],
#
#        [[0.17914978, 0.43280482],
#         [0.17331162, 0.6065713 ],
#         [0.1384124 , 0.19744234],
#         [0.3091974 , 0.348866  ],
#         [0.24231559, 0.33302778]],
#
#        [[0.1791444 , 0.43279716],
#         [0.17330772, 0.6065354 ],
#         [0.13840948, 0.19743578],
#         [0.3091716 , 0.34885356],
#         [0.24230044, 0.33300018]]], dtype=float32)

# %%
import matplotlib.patches as mpatches

fig = plt.figure(figsize=(6, 6))
plt.plot(flipped_x, flipped_y, 'ro', label = 'train')
plt.ylim(-1, 2)
for i in range(sampled_predictions.shape[1]):
     plt.plot(x_test, sampled_predictions[:, i], 'g.', alpha=0.3, label = 'predicted')
patches = [
    mpatches.Patch(color='green', label='Training'),
    mpatches.Patch(color='red', label='Predicted')
]
    
plt.legend(handles=patches)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-bc2dd89d8292> in <module>
#       2
#       3 fig = plt.figure(figsize=(6, 6))
# ----> 4 plt.plot(flipped_x, flipped_y, 'ro', label = 'train')
#       5 plt.ylim(-1, 2)
#       6 for i in range(sampled_predictions.shape[1]):
#
# NameError: name 'flipped_x' is not defined

# %%
def sample_predictions_mdn(pi_vals, mu_vals, var_vals, samples = 1):
    n, k = pi_vals.shape
    # print('shape: ', n, k, l)
    # place holder to store the y value for each sample of each row
    out = np.zeros((n, samples, dim_out))
    for i in range(n):
        for j in range(samples):
            # for each sample, use pi/probs to sample the index
            # that will be used to pick up the mu and var values
            idx = np.random.choice(range(k), p = pi_vals[i])
            for li in range(l):
                # Draw random sample from gaussian distribution
                out[i, j, :] = np.random.normal(mu_vals[i, idx, :], np.sqrt(var_vals[i, idx, :]))
    return out    

sampled_predictions = sample_predictions_mdn(pi_vals, mu_vals, var_vals, 1)

# %%
sampled_predictions.shape
# Out:
# (20000, 1, 2)

# %%
ax = plt.axes(projection = '3d')
#x, y, z, z_test = create_spiral(n = 3000, noise_range = 0.2)

#x, y, z, n = create_spiral(n = 3000, noise_range = 0.2)

# Data for three-dimensional scattered points
#zdata = 15 * np.random.random(100)
#xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
#ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
for i in range(1):
    ax.scatter3D(z_test, sampled_predictions[:, i, 1], sampled_predictions[:, i, 0], c = z_test[:, 0], alpha = 0.1) #cmap = 'Greens', alpha = 0.2);

# %%
z_test = np.linspace(-1, 1, 3000 * 2).reshape(-1, 1).astype(np.float32)

# %%
@tf.function
def train_step(model, optimizer, train_x, train_y):
    # GradientTape: Trace operations to compute gradients
    with tf.GradientTape() as tape:
        pi_, mu_, var_ = model(train_x, training = True)
        # calculate loss
        loss = mdn_loss(train_y, pi_, mu_, var_)
    # compute and apply gradients
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss

# %%
losses = []
EPOCHS = 5000
print_every = int(0.01 * EPOCHS)

# Define model and optimizer
#model = tf.keras.models.Model(input, [pi, mu, var])
#optimizer = tf.keras.optimizers.Adam()
#model, optimizer = get_mdn()

# Start training
print('Print every {} epochs'.format(print_every))
for i in range(EPOCHS):
    for train_x, train_y in dataset:
        loss = train_step(mdn, optimizer, train_x, train_y)
        losses.append(loss)
        print('loss: ', loss)
    if i % print_every == 0:
        print('Epoch {}/{}: loss {}'.format(i, EPOCHS, losses[-1]))
# Out:
# Print every 50 epochs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-54b4904a3dea> in <module>
#      11 print('Print every {} epochs'.format(print_every))
#      12 for i in range(EPOCHS):
# ---> 13     for train_x, train_y in dataset:
#      14         loss = train_step(mdn, optimizer, train_x, train_y)
#      15         losses.append(loss)
#
# NameError: name 'dataset' is not defined

# %%
# Let's plot the training loss
plt.plot(range(len(losses)), losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training loss')
plt.show()

# %%
def approx_conditional_mode(pi, var, mu):
    """Approx conditional mode
    Because the conditional mode for MDN does not have simple analytical
    solution, an alternative is to take mean of most probable component 
    at each value of x (PRML, page 277)
    """
    n, k = pi.shape
    out = np.zeros((n, l))
    # Get the index of max pi value for each row
    max_component = tf.argmax(pi, axis=1)
    for i in range(n):
        # The mean value for this index will be used
        mc = max_component[i].numpy()
        for j in range(l):
            out[i, j] = mu[i, mc * (l + j)]
    return out


# Get predictions
pi_vals, mu_vals, var_vals = mdn.predict(x_test)
pi_vals.shape, mu_vals.shape, var_vals.shape

# Get mean of max(mixing coefficient) of each row
preds = approx_conditional_mode(pi_vals, var_vals, mu_vals)

# Plot along with training data
fig = plt.figure(figsize = (8, 8))
plt.plot(flipped_x, flipped_y, 'ro')
plt.plot(x_test, preds, 'g.')
# plt.plot(flipped_x, preds2, 'b.')
plt.show()

# %%
def sample_predictions(pi_vals, mu_vals, var_vals, samples = 10):
    n, k = pi_vals.shape
    # print('shape: ', n, k, l)
    # place holder to store the y value for each sample of each row
    out = np.zeros((n, samples, l))
    for i in range(n):
        for j in range(samples):
            # for each sample, use pi/probs to sample the index
            # that will be used to pick up the mu and var values
            idx = np.random.choice(range(k), p = pi_vals[i])
            for li in range(l):
                # Draw random sample from gaussian distribution
                out[i,j,li] = np.random.normal(mu_vals[i, idx*(li+l)], np.sqrt(var_vals[i, idx]))
    return out    

sampled_predictions = sample_predictions(pi_vals, mu_vals, var_vals, 10)

# %%
# Plot the predictions along with the flipped data 
import matplotlib.patches as mpatches

fig = plt.figure(figsize=(6, 6))
plt.plot(flipped_x, flipped_y, 'ro', label = 'train')
plt.ylim(-1, 2)
for i in range(sampled_predictions.shape[1]):
     plt.plot(x_test, sampled_predictions[:, i], 'g.', alpha=0.3, label = 'predicted')
patches = [
    mpatches.Patch(color='green', label='Training'),
    mpatches.Patch(color='red', label='Predicted')
]
    
plt.legend(handles=patches)
plt.show()

# %%
import tensorflow_probability as tfp

# %%
tfd = tfp.distributions
tfpl = tfp.layers
tfk = tf.keras
tfkl = tf.keras.layers

# Load data -- graph of a [cardioid](https://en.wikipedia.org/wiki/Cardioid).
n = 2000
t = tfd.Uniform(low=-np.pi, high=np.pi).sample([n, 1])
r = 2 * (1 - tf.cos(t))
x = r * tf.sin(t) + tfd.Normal(loc=0., scale=0.1).sample([n, 1])
y = r * tf.cos(t) + tfd.Normal(loc=0., scale=0.1).sample([n, 1])

# Model the distribution of y given x with a Mixture Density Network.
event_shape = [1]
num_components = 5
params_size = tfpl.MixtureSameFamily.params_size(
    num_components,
    component_params_size=tfpl.IndependentNormal.params_size(event_shape))

model = tfk.Sequential([
  tfkl.Dense(12, activation='relu'),
  tfkl.Dense(params_size, activation=None),
  tfpl.MixtureSameFamily(num_components, tfpl.IndependentNormal(event_shape)),
])

# Fit.
batch_size = 100
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.02),
              loss = lambda y, model: - model.log_prob(y))
model.fit(x, y,
          batch_size=batch_size,
          epochs=20,
          steps_per_epoch=n // batch_size)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 0s 1ms/step - loss: 1.8713
# Epoch 2/20
# 20/20 [==============================] - 0s 1ms/step - loss: 1.3899
# Epoch 3/20
# 20/20 [==============================] - 0s 977us/step - loss: 1.2258
# Epoch 4/20
# 20/20 [==============================] - 0s 1ms/step - loss: 1.1057
# Epoch 5/20
# 20/20 [==============================] - 0s 1ms/step - loss: 0.9613
# Epoch 6/20
# 20/20 [==============================] - 0s 990us/step - loss: 0.7517
# Epoch 7/20
# 20/20 [==============================] - 0s 993us/step - loss: 0.6245
# Epoch 8/20
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5706
# Epoch 9/20
# 20/20 [==============================] - 0s 990us/step - loss: 0.5484
# Epoch 10/20
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4783
# Epoch 11/20
# 20/20 [==============================] - 0s 953us/step - loss: 0.4853
# Epoch 12/20
# 20/20 [==============================] - 0s 922us/step - loss: 0.4566
# Epoch 13/20
# 20/20 [==============================] - 0s 944us/step - loss: 0.4333
# Epoch 14/20
# 20/20 [==============================] - 0s 982us/step - loss: 0.4336
# Epoch 15/20
# 20/20 [==============================] - 0s 979us/step - loss: 0.4348
# Epoch 16/20
# 20/20 [==============================] - 0s 984us/step - loss: 0.4072
# Epoch 17/20
# 20/20 [==============================] - 0s 995us/step - loss: 0.3970
# Epoch 18/20
# 20/20 [==============================] - 0s 922us/step - loss: 0.4017
# Epoch 19/20
# 20/20 [==============================] - 0s 927us/step - loss: 0.3434
# Epoch 20/20
# 20/20 [==============================] - 0s 968us/step - loss: 0.3472

# %%
tfpl.IndependentNormal.params_size(event_shape)
# Out:
# 2

# %%
params_size
# Out:
# 15

# %%
plt.plot(x,y, '.')

# %%
y_pred = model.predict(x)

# %%
plt.plot(x, y_pred, '.', alpha = 0.3)
plt.plot(x, y, '.', color = 'red', alpha = 0.3)

# %%
y_pred2 = model.predict(x)

# %%
np.array_equal(y_pred, y_pred2)
# Out:
# False

# %%
y_pred[:10]
# Out:
# array([[-2.0429015 ],
#        [-3.494053  ],
#        [-2.696699  ],
#        [-4.0112586 ],
#        [-2.001936  ],
#        [-2.249207  ],
#        [-3.199544  ],
#        [-0.16593647],
#        [ 0.6335046 ],
#        [ 0.47450647]], dtype=float32)

# %%
y_pred2[:10]
# Out:
# array([[-0.529323  ],
#        [-3.559599  ],
#        [-0.9752273 ],
#        [-3.7772913 ],
#        [-2.8422587 ],
#        [-1.5286007 ],
#        [-0.5320331 ],
#        [-3.2237933 ],
#        [ 0.4908444 ],
#        [ 0.29399678]], dtype=float32)

# %%
y_dist = model(x)

# %%
type(y_dist)
# Out:
# tensorflow_probability.python.util.deferred_tensor.MixtureSameFamily

# %%
y_mean = y_dist.mean()

# %%
plt.plot(x, y_mean, '.', alpha = 0.3)
plt.plot(x, y, '.', color = 'red', alpha = 0.3)

# %%
y_dist.sample()
# Out:
# <tf.Tensor: shape=(2000, 1), dtype=float32, numpy=
# array([[-0.84646493],
#        [-3.4917426 ],
#        [-3.255796  ],
#        ...,
#        [ 0.33154538],
#        [-3.1928048 ],
#        [ 0.63538903]], dtype=float32)>

# %%
plt.plot(x, y, '.', alpha = 0.3)
plt.plot(x, y_dist.sample(), '.', color = 'red', alpha = 0.3)

# %%
dir(model)
# Out:
# ['_TF_MODULE_IGNORED_PROPERTIES',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_activity_regularizer',
#  '_add_inbound_node',
#  '_add_trackable',
#  '_add_variable_with_custom_getter',
#  '_assert_compile_was_called',
#  '_assert_weights_created',
#  '_attribute_sentinel',
#  '_auto_track_sub_layers',
#  '_autocast',
#  '_base_init',
#  '_build_input_shape',
#  '_call_accepts_kwargs',
#  '_call_arg_was_passed',
#  '_call_fn_args',
#  '_call_full_argspec',
#  '_callable_losses',
#  '_check_call_args',
#  '_checkpoint_dependencies',
#  '_clear_losses',
#  '_collect_input_masks',
#  '_compile_was_called',
#  '_compiled_trainable_state',
#  '_compute_dtype',
#  '_compute_output_and_mask_jointly',
#  '_compute_tensor_usage_count',
#  '_conform_to_reference_input',
#  '_dedup_weights',
#  '_deferred_dependencies',
#  '_distribution_strategy',
#  '_dtype',
#  '_dtype_defaulted_to_floatx',
#  '_dtype_policy',
#  '_dynamic',
#  '_eager_add_metric',
#  '_eager_losses',
#  '_expects_mask_arg',
#  '_expects_training_arg',
#  '_flatten',
#  '_flatten_to_reference_inputs',
#  '_gather_children_attribute',
#  '_gather_layers',
#  '_gather_saveables_for_checkpoint',
#  '_gather_unique_layers',
#  '_get_call_arg_value',
#  '_get_callback_model',
#  '_get_compile_args',
#  '_get_distribution_strategy',
#  '_get_existing_metric',
#  '_get_node_attribute_at_index',
#  '_get_optimizer',
#  '_get_save_spec',
#  '_get_trainable_state',
#  '_graph',
#  '_graph_network_add_loss',
#  '_graph_network_add_metric',
#  '_handle_activity_regularization',
#  '_handle_deferred_dependencies',
#  '_handle_deferred_layer_dependencies',
#  '_handle_weight_regularization',
#  '_in_multi_worker_mode',
#  '_inbound_nodes',
#  '_init_call_fn_args',
#  '_init_graph_network',
#  '_init_set_name',
#  '_init_subclassed_network',
#  '_initial_weights',
#  '_input_spec',
#  '_insert_layers',
#  '_is_compiled',
#  '_is_graph_network',
#  '_is_layer',
#  '_keras_api_names',
#  '_keras_api_names_v1',
#  '_layer_call_argspecs',
#  '_layer_checkpoint_dependencies',
#  '_layers',
#  '_list_extra_dependencies_for_serialization',
#  '_list_functions_for_serialization',
#  '_lookup_dependency',
#  '_losses',
#  '_maybe_build',
#  '_maybe_cast_inputs',
#  '_maybe_create_attribute',
#  '_maybe_initialize_trackable',
#  '_maybe_load_initial_epoch_from_ckpt',
#  '_metrics',
#  '_metrics_lock',
#  '_name',
#  '_name_based_attribute_restore',
#  '_name_based_restores',
#  '_name_scope',
#  '_no_dependency',
#  '_non_trainable_weights',
#  '_obj_reference_counts',
#  '_obj_reference_counts_dict',
#  '_object_identifier',
#  '_outbound_nodes',
#  '_preload_simple_restoration',
#  '_reset_compile_cache',
#  '_restore_from_checkpoint_position',
#  '_reuse',
#  '_run_eagerly',
#  '_run_internal_graph',
#  '_saved_model_inputs_spec',
#  '_scope',
#  '_self_name_based_restores',
#  '_self_setattr_tracking',
#  '_self_unconditional_checkpoint_dependencies',
#  '_self_unconditional_deferred_dependencies',
#  '_self_unconditional_dependency_names',
#  '_self_update_uid',
#  '_set_connectivity_metadata_',
#  '_set_dtype_policy',
#  '_set_inputs',
#  '_set_mask_metadata',
#  '_set_output_names',
#  '_set_save_spec',
#  '_set_trainable_state',
#  '_setattr_tracking',
#  '_should_compute_mask',
#  '_should_eval',
#  '_single_restoration_from_checkpoint_position',
#  '_stateful',
#  '_supports_ragged_inputs',
#  '_symbolic_add_metric',
#  '_symbolic_call',
#  '_tf_api_names',
#  '_tf_api_names_v1',
#  '_thread_local',
#  '_track_trackable',
#  '_trackable_saved_model_saver',
#  '_trackable_saver',
#  '_tracking_metadata',
#  '_trainable',
#  '_trainable_weights',
#  '_training_state',
#  '_unconditional_checkpoint_dependencies',
#  '_unconditional_dependency_names',
#  '_undeduplicated_weights',
#  '_update_uid',
#  '_updated_config',
#  '_updates',
#  '_validate_compile',
#  '_validate_graph_inputs_and_outputs',
#  '_warn_about_input_casting',
#  'activity_regularizer',
#  'add',
#  'add_loss',
#  'add_metric',
#  'add_update',
#  'add_variable',
#  'add_weight',
#  'apply',
#  'build',
#  'built',
#  'call',
#  'compile',
#  'compiled_loss',
#  'compiled_metrics',
#  'compute_mask',
#  'compute_output_shape',
#  'compute_output_signature',
#  'count_params',
#  'distribute_strategy',
#  'dtype',
#  'dynamic',
#  'evaluate',
#  'evaluate_generator',
#  'fit',
#  'fit_generator',
#  'from_config',
#  'get_config',
#  'get_input_at',
#  'get_input_mask_at',
#  'get_input_shape_at',
#  'get_layer',
#  'get_losses_for',
#  'get_output_at',
#  'get_output_mask_at',
#  'get_output_shape_at',
#  'get_updates_for',
#  'get_weights',
#  'history',
#  'inbound_nodes',
#  'input',
#  'input_mask',
#  'input_names',
#  'input_shape',
#  'input_spec',
#  'inputs',
#  'layers',
#  'load_weights',
#  'loss',
#  'losses',
#  'make_predict_function',
#  'make_test_function',
#  'make_train_function',
#  'metrics',
#  'metrics_names',
#  'name',
#  'name_scope',
#  'non_trainable_variables',
#  'non_trainable_weights',
#  'optimizer',
#  'outbound_nodes',
#  'output',
#  'output_mask',
#  'output_names',
#  'output_shape',
#  'outputs',
#  'pop',
#  'predict',
#  'predict_classes',
#  'predict_function',
#  'predict_generator',
#  'predict_on_batch',
#  'predict_proba',
#  'predict_step',
#  'reset_metrics',
#  'reset_states',
#  'run_eagerly',
#  'save',
#  'save_weights',
#  'set_weights',
#  'state_updates',
#  'stateful',
#  'stop_training',
#  'submodules',
#  'summary',
#  'supports_masking',
#  'test_function',
#  'test_on_batch',
#  'test_step',
#  'to_json',
#  'to_yaml',
#  'train_function',
#  'train_on_batch',
#  'train_step',
#  'trainable',
#  'trainable_variables',
#  'trainable_weights',
#  'updates',
#  'variables',
#  'weights',
#  'with_name_scope']

# %%
model.layers[1].weights[1]
# Out:
# <tf.Variable 'sequential_1/dense_3/bias:0' shape=(15,) dtype=float32, numpy=
# array([ 1.1477426 , -0.05638814, -0.7799785 , -0.8031138 ,  0.0425654 ,
#         0.32770517, -0.41265354,  0.72777444, -0.6302155 ,  0.5256945 ,
#        -0.12009402, -0.23589455,  0.2946376 , -0.8993671 , -0.02037435],
#       dtype=float32)>

# %%
dir(y_dist)
# Out:
# ['_TF_MODULE_IGNORED_PROPERTIES',
#  '__abs__',
#  '__abstractmethods__',
#  '__add__',
#  '__and__',
#  '__array_priority__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_abc_impl',
#  '_add_variable_with_custom_getter',
#  '_allow_nan_stats',
#  '_batch_shape',
#  '_batch_shape_tensor',
#  '_call_cdf',
#  '_call_log_cdf',
#  '_call_log_prob',
#  '_call_log_survival_function',
#  '_call_prob',
#  '_call_quantile',
#  '_call_sample_n',
#  '_call_survival_function',
#  '_checkpoint_dependencies',
#  '_components_distribution',
#  '_concrete_value',
#  '_convert_to_tensor_fn',
#  '_covariance',
#  '_cross_entropy',
#  '_default_event_space_bijector',
#  '_deferred_dependencies',
#  '_disallow_bool_casting',
#  '_disallow_in_graph_mode',
#  '_disallow_iteration',
#  '_disallow_when_autograph_disabled',
#  '_disallow_when_autograph_enabled',
#  '_distributional_transform',
#  '_dtype',
#  '_entropy',
#  '_event_ndims',
#  '_event_shape',
#  '_event_shape_tensor',
#  '_expand_sample_shape_to_vector',
#  '_experimental_default_event_space_bijector',
#  '_flatten',
#  '_gather_saveables_for_checkpoint',
#  '_graph_parents',
#  '_handle_deferred_dependencies',
#  '_initial_parameter_control_dependencies',
#  '_is_scalar_helper',
#  '_keras_mask',
#  '_kl_divergence',
#  '_list_extra_dependencies_for_serialization',
#  '_list_functions_for_serialization',
#  '_log_cdf',
#  '_log_prob',
#  '_log_survival_function',
#  '_lookup_dependency',
#  '_maybe_initialize_trackable',
#  '_mean',
#  '_mixture_distribution',
#  '_mode',
#  '_name',
#  '_name_and_control_scope',
#  '_name_based_attribute_restore',
#  '_name_based_restores',
#  '_name_scope',
#  '_no_dependency',
#  '_object_identifier',
#  '_pad_sample_dims',
#  '_param_shapes',
#  '_parameter_control_dependencies',
#  '_parameters',
#  '_parameters_sanitized',
#  '_params_event_ndims',
#  '_preload_simple_restoration',
#  '_quantile',
#  '_reparameterization_type',
#  '_reparameterize',
#  '_reparameterize_sample',
#  '_restore_from_checkpoint_position',
#  '_sample_control_dependencies',
#  '_sample_n',
#  '_self_name_based_restores',
#  '_self_setattr_tracking',
#  '_self_unconditional_checkpoint_dependencies',
#  '_self_unconditional_deferred_dependencies',
#  '_self_unconditional_dependency_names',
#  '_self_update_uid',
#  '_set_sample_static_shape',
#  '_setattr_tracking',
#  '_single_restoration_from_checkpoint_position',
#  '_stddev',
#  '_survival_function',
#  '_tf_api_names',
#  '_tf_api_names_v1',
#  '_track_trackable',
#  '_tracking_metadata',
#  '_unconditional_checkpoint_dependencies',
#  '_unconditional_dependency_names',
#  '_update_uid',
#  '_validate_args',
#  '_value',
#  '_variance',
#  'allow_nan_stats',
#  'batch_shape',
#  'batch_shape_tensor',
#  'cdf',
#  'components_distribution',
#  'copy',
#  'covariance',
#  'cross_entropy',
#  'dtype',
#  'entropy',
#  'event_shape',
#  'event_shape_tensor',
#  'get_shape',
#  'is_scalar_batch',
#  'is_scalar_event',
#  'kl_divergence',
#  'log_cdf',
#  'log_prob',
#  'log_survival_function',
#  'mean',
#  'mixture_distribution',
#  'mode',
#  'name',
#  'name_scope',
#  'param_shapes',
#  'param_static_shapes',
#  'parameters',
#  'prob',
#  'quantile',
#  'registered_class_list',
#  'reparameterization_type',
#  'sample',
#  'shape',
#  'stddev',
#  'submodules',
#  'survival_function',
#  'trainable_variables',
#  'validate_args',
#  'variables',
#  'variance',
#  'with_name_scope']

# %%
dir(y_dist.components_distribution)
# Out:
# ['_TF_MODULE_IGNORED_PROPERTIES',
#  '__abs__',
#  '__abstractmethods__',
#  '__add__',
#  '__and__',
#  '__array_priority__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_abc_impl',
#  '_add_variable_with_custom_getter',
#  '_allow_nan_stats',
#  '_batch_shape',
#  '_batch_shape_tensor',
#  '_call_cdf',
#  '_call_log_cdf',
#  '_call_log_prob',
#  '_call_log_survival_function',
#  '_call_prob',
#  '_call_quantile',
#  '_call_sample_n',
#  '_call_survival_function',
#  '_checkpoint_dependencies',
#  '_concrete_value',
#  '_convert_to_tensor_fn',
#  '_covariance',
#  '_cross_entropy',
#  '_default_event_space_bijector',
#  '_deferred_dependencies',
#  '_disallow_bool_casting',
#  '_disallow_in_graph_mode',
#  '_disallow_iteration',
#  '_disallow_when_autograph_disabled',
#  '_disallow_when_autograph_enabled',
#  '_distribution',
#  '_dtype',
#  '_entropy',
#  '_event_shape',
#  '_event_shape_tensor',
#  '_expand_sample_shape_to_vector',
#  '_experimental_default_event_space_bijector',
#  '_flatten',
#  '_gather_saveables_for_checkpoint',
#  '_get_reinterpreted_batch_ndims',
#  '_graph_parents',
#  '_handle_deferred_dependencies',
#  '_initial_parameter_control_dependencies',
#  '_is_scalar_helper',
#  '_keras_mask',
#  '_kl_divergence',
#  '_list_extra_dependencies_for_serialization',
#  '_list_functions_for_serialization',
#  '_log_cdf',
#  '_log_prob',
#  '_log_survival_function',
#  '_lookup_dependency',
#  '_maybe_initialize_trackable',
#  '_mean',
#  '_mode',
#  '_name',
#  '_name_and_control_scope',
#  '_name_based_attribute_restore',
#  '_name_based_restores',
#  '_name_scope',
#  '_no_dependency',
#  '_object_identifier',
#  '_param_shapes',
#  '_parameter_control_dependencies',
#  '_parameters',
#  '_parameters_sanitized',
#  '_params_event_ndims',
#  '_preload_simple_restoration',
#  '_quantile',
#  '_reduce',
#  '_reinterpreted_batch_ndims',
#  '_reparameterization_type',
#  '_restore_from_checkpoint_position',
#  '_sample_control_dependencies',
#  '_sample_n',
#  '_self_name_based_restores',
#  '_self_setattr_tracking',
#  '_self_unconditional_checkpoint_dependencies',
#  '_self_unconditional_deferred_dependencies',
#  '_self_unconditional_dependency_names',
#  '_self_update_uid',
#  '_set_sample_static_shape',
#  '_setattr_tracking',
#  '_single_restoration_from_checkpoint_position',
#  '_static_reinterpreted_batch_ndims',
#  '_stddev',
#  '_survival_function',
#  '_tf_api_names',
#  '_tf_api_names_v1',
#  '_track_trackable',
#  '_tracking_metadata',
#  '_unconditional_checkpoint_dependencies',
#  '_unconditional_dependency_names',
#  '_update_uid',
#  '_validate_args',
#  '_value',
#  '_variance',
#  'allow_nan_stats',
#  'batch_shape',
#  'batch_shape_tensor',
#  'cdf',
#  'copy',
#  'covariance',
#  'cross_entropy',
#  'distribution',
#  'dtype',
#  'entropy',
#  'event_shape',
#  'event_shape_tensor',
#  'get_shape',
#  'is_scalar_batch',
#  'is_scalar_event',
#  'kl_divergence',
#  'log_cdf',
#  'log_prob',
#  'log_survival_function',
#  'mean',
#  'mode',
#  'name',
#  'name_scope',
#  'param_shapes',
#  'param_static_shapes',
#  'parameters',
#  'prob',
#  'quantile',
#  'registered_class_list',
#  'reinterpreted_batch_ndims',
#  'reparameterization_type',
#  'sample',
#  'shape',
#  'stddev',
#  'submodules',
#  'survival_function',
#  'trainable_variables',
#  'validate_args',
#  'variables',
#  'variance',
#  'with_name_scope']

# %%
y_dist.components_distribution.parameters
# Out:
# {'distribution': <tfp.distributions.Independent 'sequential_1_mixture_same_family_1_MixtureSameFamily_independent_normal_1_IndependentNormal_Independentsequential_1_mixture_same_family_1_MixtureSameFamily_independent_normal_1_IndependentNormal_Normal' batch_shape=[2000, 5] event_shape=[1] dtype=float32>,
#  'convert_to_tensor_fn': <function tensorflow_probability.python.distributions.distribution.Distribution.sample(self, sample_shape=(), seed=None, name='sample', **kwargs)>}

# %%
y_dist.mixture_distribution
# Out:
# <tfp.distributions.Categorical 'sequential_1_mixture_same_family_1_MixtureSameFamily_Categorical' batch_shape=[2000] event_shape=[] dtype=int32>

# %%
y_dist.parameters
# Out:
# {'distribution': <tfp.distributions.MixtureSameFamily 'sequential_1_mixture_same_family_1_MixtureSameFamily_MixtureSameFamily' batch_shape=[2000] event_shape=[1] dtype=float32>,
#  'convert_to_tensor_fn': <function tensorflow_probability.python.distributions.distribution.Distribution.sample(self, sample_shape=(), seed=None, name='sample', **kwargs)>}
