# %%
# Load packages
import tensorflow as tf
import pandas as pd
from tensorflow import keras
import numpy as np
import pandas as pd
import os
import scipy as scp
import scipy.stats as scps
import pickle
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from datetime import datetime
import time
import scipy.optimize as scp_opt
from scipy.stats import mode
from statsmodels.distributions.empirical_distribution import ECDF

# %%
n = str(1024)
base_folder = '/users/afengler/OneDrive/project_nn_likelihoods/data/timings/elife_param_recovery/'
dir_ = os.listdir(base_folder)

file_list = []
for tmp_dir_ in dir_:
    file_list_tmp = os.listdir(base_folder + tmp_dir_)
    print(file_list_tmp)
    for file_ in file_list_tmp:
        if n in file_:
            file_list.append(pickle.load(open(base_folder + tmp_dir_ + '/' + file_, 'rb')))

my_columns = []
for dir_tmp in dir_:
    if dir_tmp == 'full_ddm2':
        my_columns.append('Full-DDM'.upper())
    elif dir_tmp == 'weibull_cdf2':
        my_columns.append('Weibull'.upper())
    elif dir_tmp == 'angle2':
        my_columns.append('Angle'.upper())
    elif dir_tmp == 'ddm_sdv':
        my_columns.append('ddm-sdv'.upper())
    else:
        my_columns.append(dir_tmp.upper())
        
if n == '1024':
    mlp_timings_1024 = pd.DataFrame(np.array([file_list[i][3] for i in range(len(file_list))]).T, 
                                    columns = my_columns)
if n == '4096':
    mlp_timings_4096 = pd.DataFrame(np.array([file_list[i][3] for i in range(len(file_list))]).T, 
                                    columns = my_columns)
# Out:
# ['elife_slice_post_samp_data_param_recov_unif_reps_1_n_4096_init_mle_1_1.pickle', 'elife_slice_post_samp_data_param_recov_unif_reps_1_n_1024_init_mle_1_1.pickle']
# ['elife_slice_post_samp_data_param_recov_unif_reps_1_n_4096_init_mle_1_1.pickle', 'elife_slice_post_samp_data_param_recov_unif_reps_1_n_1024_init_mle_1_1.pickle']
# ['elife_slice_post_samp_data_param_recov_unif_reps_1_n_4096_init_mle_1_1.pickle', 'elife_slice_post_samp_data_param_recov_unif_reps_1_n_1024_init_mle_1_1.pickle']
# ['elife_slice_post_samp_data_param_recov_unif_reps_1_n_4096_init_mle_1_1.pickle', 'elife_post_samp_data_param_recov_unif_reps_1_n_1024_init_mle_1_1.pickle']
# ['elife_slice_post_samp_data_param_recov_unif_reps_1_n_4096_init_mle_1_1.pickle', 'elife_slice_post_samp_data_param_recov_unif_reps_1_n_1024_init_mle_1_1.pickle']
# ['elife_slice_post_samp_data_param_recov_unif_reps_1_n_4096_init_mle_1_1.pickle', 'elife_slice_post_samp_data_param_recov_unif_reps_1_n_1024_init_mle_1_1.pickle']
# ['elife_slice_post_samp_data_param_recov_unif_reps_1_n_4096_init_mle_1_1.pickle', 'elife_slice_post_samp_data_param_recov_unif_reps_1_n_1024_init_mle_1_1.pickle']

# %%
n = str(1024)
base_folder = '/users/afengler/OneDrive/project_nn_likelihoods/eLIFE_exps/summaries/'
dir_ = os.listdir(base_folder)

file_list_cnn = []
model_names = []
for file_ in dir_:
    if n in file_:
        print(file_)
        tmp_file = file_[11:-14].replace('_', '-').upper()
        tmp_file = tmp_file.replace('2', '')
        tmp_file = tmp_file.replace('-CDF', '')
        print(tmp_file)
        model_names.append(tmp_file)
        file_list_cnn.append(pickle.load(open(base_folder + '/' + file_, 'rb')))
        
timings_list_cnn = [file_list_cnn[i]['timings'] for i in range(len(file_list_cnn))]
timings_list_cnn_clean = np.array([timings_list_cnn[i][np.random.choice(900, size = 500)] for i in range(len(timings_list_cnn))]).T

if n == '1024':
    cnn_timings_1024 = pd.DataFrame(timings_list_cnn_clean, columns = model_names)
if n == '4096':
    cnn_timings_4096 = pd.DataFrame(timings_list_cnn_clean, columns = model_names)
# Out:
# IS_summary_levy_N_1024.pickle
# LEVY
# IS_summary_ornstein_N_1024.pickle
# ORNSTEIN
# IS_summary_lca_4_N_1024.pickle
# LCA-4
# IS_summary_weibull_cdf_N_1024.pickle
# WEIBULL
# IS_summary_lca_3_N_1024.pickle
# LCA-3
# IS_summary_angle_N_1024.pickle
# ANGLE
# IS_summary_ddm_sdv_N_1024.pickle
# DDM-SDV
# IS_summary_ddm_N_1024.pickle
# DDM
# IS_summary_race_model_4_N_1024.pickle
# RACE-MODEL-4
# IS_summary_race_model_3_N_1024.pickle
# RACE-MODEL-3
# IS_summary_full_ddm2_N_1024.pickle
# FULL-DDM

# %%
cnn_timings_1024
# Out:
#            LEVY    ORNSTEIN       LCA-4     WEIBULL        LCA-3       ANGLE  \
# 0    191.960689  111.190432  385.170080  425.148083   349.672885  180.357327
# 1    345.207597  124.289010  656.539043  206.110256   695.256496  371.884152
# 481  152.263811  119.069204    286.213552    190.661254  379.648845
# 482   81.242299   69.210369    366.679732    401.547857  150.052357
# 483  299.202676   70.789339    335.756717    213.119388  247.370985
# 484  204.042408   72.892001    300.902035    359.707216  312.228233
# 485  162.120436   81.196694    504.346890    620.250395  298.837240
# 486  230.543345   67.454975    303.405233    201.221238  236.650932
# 487  123.211837  116.375901    705.507447    424.257347  180.100060
# 488  148.533339   67.679653    608.567838    247.881809  617.537938
# 489  112.815016   69.811204    549.140825    357.065186  326.320030
# 490  272.691040   77.512863    275.949888    415.975368  480.753081
# 491  222.708405   63.443393    357.320058    242.618490  302.456432
# 492  252.125429   81.930723    553.568145    387.319596  495.736852
# 493  154.920129  140.220404    503.008631    451.403819  227.379185
# 494  169.148847  154.349650    359.649326    362.601384  421.390568
# 495  211.028646   80.733148    377.345789    305.228557  326.955215
# 496   77.283638  120.364270    407.239545    601.575150  140.393256
# 497  247.497433  106.153714    268.338264    617.905384  402.870861
# 498   84.222764  130.224808    337.760731    373.935671  404.828263
# 499  130.786051  107.412121    320.784088    187.659295   96.281207
#
# [500 rows x 11 columns]

# %%
def caterpillar_plot(timings = None,
                     machine = 'home',
                     method = 'MLP',
                     sampler = 'slice',
                     n = 1024,
                     save = False,
                     plot_format = 'svg'):
    
    matplotlib.rcParams['text.usetex'] = True
    #matplotlib.rcParams['pdf.fonttype'] = 42
    matplotlib.rcParams['svg.fonttype'] = 'none'
    
    sns.set(style = "white", 
            palette = "muted", 
            color_codes = True,
            font_scale = 2)

    fig, ax = plt.subplots(1, 1, 
                           figsize = (10, 10), 
                           sharex = False, 
                           sharey = False)
    
    my_suptitle = fig.suptitle('Timings in seconds : ' + method.upper() + ', n = ' + str(n), 
                               fontsize = 40)
    
    sns.despine(right = True)
           
    ecdfs = {}
    plot_vals = {} # [0.01, 0.9], [0.01, 0.99], [mean]
    
    for k in timings.keys():
        ecdfs[k] = ECDF(timings[k].values)
        tmp_sorted = sorted(timings[k])
        _p01 =  tmp_sorted[np.sum(ecdfs[k](tmp_sorted) <= 0.01) - 1]
        _p99 = tmp_sorted[np.sum(ecdfs[k](tmp_sorted) <= 0.99) - 1]
        _p1 = tmp_sorted[np.sum(ecdfs[k](tmp_sorted) <= 0.1) - 1]
        _p9 = tmp_sorted[np.sum(ecdfs[k](tmp_sorted) <= 0.9) - 1]
        _pmean = timings[k].mean()
        plot_vals[k] = [[_p01, _p99], [_p1, _p9], _pmean]
        
    x = [plot_vals[k][2] for k in plot_vals.keys()]
    ax.scatter(x, plot_vals.keys(), c = 'black', marker = 's', alpha = .5)
    ax.set_xlim([0, 1000])
    
    for k in plot_vals.keys():
        ax.plot(plot_vals[k][1], [k, k], c = 'grey', zorder = -1, linewidth = 5)
        ax.plot(plot_vals[k][0] , [k, k], c = 'black', zorder = -1)
        #ax.scatter(ground_truths[config[model]['params'].index(k)], k,  c = 'red', marker = "|")
                                 
    if save == True:
        if machine == 'home':
            fig_dir = "/users/afengler/OneDrive/git_repos/nn_likelihoods/figures/" + method + "/timings/"
            if not os.path.isdir(fig_dir):
                os.mkdir(fig_dir)
        
        if plot_format == 'png':
            plt.savefig(fig_dir + '/' + 'timings_' + sampler + '_' + str(n) + '.png', 
                        dpi = 300, 
                        transparent = False,
                        bbox_inches = 'tight',
                        bbox_extra_artists = [my_suptitle])
        if plot_format == 'svg':
            plt.savefig(fig_dir + '/' + 'timings_' + sampler + '_' + str(n) + '.svg',
                            format = 'svg', 
                            transparent = True,
                            bbox_inches = 'tight',
                            bbox_extra_artists = [my_suptitle],
                            frameon = False)
        
        plt.close()
    
    # Show
        return #plt.show(block = False)
    else:
        return plt.show()

# %%
def caterpillar_plot_multidat(timings_dict = None, # list [timings_cnn_1024, timings_cnn_4096, timings_mlp_1024, timings_mlp_4096]
                              machine = 'home',
                              n = 1024,
                              save = False,
                              plot_format = 'svg'):
    
    matplotlib.rcParams['text.usetex'] = True
    #matplotlib.rcParams['pdf.fonttype'] = 42
    matplotlib.rcParams['svg.fonttype'] = 'none'
    
    sns.set(style = "white", 
            palette = "muted", 
            color_codes = True,
            font_scale = 2)

    fig, ax = plt.subplots(1, 1, 
                           figsize = (10, 10), 
                           sharex = False, 
                           sharey = False)
    
    my_suptitle = fig.suptitle('Timings in seconds : ' + method.upper() + ', n = ' + str(n), 
                               fontsize = 40)
    
    sns.despine(right = True)
           
    ecdfs = {}
    plot_vals = {'CNN-1024': {}, 
                 'CNN-4096': {},
                 'MLP-1024': {},
                 'MLP-4096': {}} # [0.01, 0.9], [0.01, 0.99], [mean]
    
    for timing_pd_tmp in timings_dict.keys():
        for k in timings_dict[timing_pd_tmp].keys():
            
            if 'RACE' in k or 'LCA' in k:
                if 'MLP' in timing_pd_tmp:
                    continue

            ecdfs[k] = ECDF(timings_dict[timing_pd_tmp][k].values)
            tmp_sorted = sorted(timings_dict[timing_pd_tmp][k])
            _p01 =  tmp_sorted[np.sum(ecdfs[k](tmp_sorted) <= 0.01) - 1]
            _p99 = tmp_sorted[np.sum(ecdfs[k](tmp_sorted) <= 0.99) - 1]
            _p1 = tmp_sorted[np.sum(ecdfs[k](tmp_sorted) <= 0.1) - 1]
            _p9 = tmp_sorted[np.sum(ecdfs[k](tmp_sorted) <= 0.9) - 1]
            _pmean = timings_dict[timing_pd_tmp][k].mean()
            plot_vals[timing_pd_tmp][k] = [[_p01, _p99], [_p1, _p9], _pmean]
        
    x_cnn = [plot_vals['CNN-1024'][k][2] for k in plot_vals['CNN-1024'].keys()]
    x_mlp = [plot_vals['MLP-1024'][k][2] for k in plot_vals['MLP-1024'].keys()]

    ax.scatter(x_cnn, plot_vals['CNN-1024'].keys(), 
               c = 'black', 
               marker = 's', 
               alpha = .0)
    
    ax.scatter(x_mlp, np.array([i for i in range(len(plot_vals['MLP-1024'].keys()))]) + 0.2, 
               c = 'blue',
               marker = 's',
               alpha = .5,
               label = 'MLP-1024')
    
    ax.scatter(x_mlp, np.array([i for i in range(len(plot_vals['MLP-4096'].keys()))]) + 0.1, 
               c = 'blue',
               marker = 's',
               alpha = 1.,
               label = 'MLP-4096')
    
    ax.scatter(x_cnn, np.array([i for i in range(len(plot_vals['CNN-1024'].keys()))]) - 0.1, 
               c = 'red',
               marker = 's',
               alpha = 1.,
               label = 'CNN-4096')
    
    ax.scatter(x_cnn, np.array([i for i in range(len(plot_vals['CNN-4096'].keys()))]) - 0.2, 
               c = 'red',
               marker = 's',
               alpha = .5,
               label = 'CNN-1024')
    ax.legend()
    ax.set_xlim([0, 1000])
    
    offset_list = [0.2, 0.1, -0.1, -0.2]
    offset_cnt = 0
    for timing_pd_tmp in timings_dict.keys():
        cnt = 0
        for k in plot_vals[timing_pd_tmp].keys():
            if 'CNN' in timing_pd_tmp:
                tmp_color = 'red'
            else:
                tmp_color = 'blue'
            
            ax.plot(plot_vals[timing_pd_tmp][k][0] , 
                    [cnt + offset_list[offset_cnt], cnt + offset_list[offset_cnt]], 
                    c = tmp_color, 
                    zorder = -1, 
                    alpha = 0.5)
            
            ax.plot(plot_vals[timing_pd_tmp][k][1], 
                    [cnt + offset_list[offset_cnt], cnt + offset_list[offset_cnt]], 
                    c = tmp_color, 
                    zorder = -1, 
                    linewidth = 5,
                    alpha = 0.5)



#             ax.plot(plot_vals[k][1], 
#                     [cnt + 0.1, cnt + 0.1], 
#                     c = 'blue', 
#                     zorder = -1, 
#                     linewidth = 5, 
#                     alpha = 1)

#             ax.plot(plot_vals[k][0] , 
#                     [cnt + 0.1, cnt + 0.1],
#                     c = 'blue',
#                     zorder = -1, 
#                     alpha = 1)


#             ax.plot(plot_vals[k][1], 
#                     [cnt - 0.1, cnt - 0.1],
#                     c = 'red', 
#                     zorder = -1, 
#                     linewidth = 5, 
#                     alpha = 1)

#             ax.plot(plot_vals[k][0] , 
#                     [cnt - 0.1, 
#                      cnt - 0.1], 
#                     c = 'red', 
#                     zorder = -1,
#                     alpha = 1)

#             ax.plot(plot_vals[k][1],
#                     [cnt - 0.2, cnt - 0.2], 
#                     c = 'red', 
#                     zorder = -1,
#                     linewidth = 5,
#                     alpha = 0.5)

#             ax.plot(plot_vals[k][0] , 
#                     [cnt - 0.2, cnt - 0.2], 
#                     c = 'red', 
#                     zorder = -1, 
#                     alpha = 0.5)
            cnt += 1
        offset_cnt += 1
                                 
    if save == True:
        if machine == 'home':
            fig_dir = "/users/afengler/OneDrive/git_repos/nn_likelihoods/figures/timings/"
            if not os.path.isdir(fig_dir):
                os.mkdir(fig_dir)
        
        if plot_format == 'png':
            plt.savefig(fig_dir + '/' + 'timing_comparison' +  '.png', 
                        dpi = 300, 
                        transparent = False,
                        bbox_inches = 'tight',
                        bbox_extra_artists = [my_suptitle])
        if plot_format == 'svg':
            plt.savefig(fig_dir + '/' + 'timing_comparison' +  '.png',
                            format = 'svg', 
                            transparent = True,
                            bbox_inches = 'tight',
                            bbox_extra_artists = [my_suptitle],
                            frameon = False)
        
        plt.close()
    
    # Show
        return #plt.show(block = False)
    else:
        return plt.show()

# %%
mlp_timings_1024 = mlp_timings_1024[['DDM', 'DDM-SDV', 'ANGLE', 'ORNSTEIN', 'LEVY', 'WEIBULL', 'FULL-DDM']]

# %%
mlp_timings_4096 = mlp_timings_4096[['DDM', 'DDM-SDV', 'ANGLE', 'ORNSTEIN', 'LEVY', 'WEIBULL', 'FULL-DDM']]

# %%
cnn_timings_1024 = cnn_timings_1024[['DDM', 'DDM-SDV', 'ANGLE', 'ORNSTEIN', 'LEVY', 'WEIBULL', 'FULL-DDM',
                                     'LCA-3', 'LCA-4', 'RACE-MODEL-3', 'RACE-MODEL-4']]

# %%
cnn_timings_4096 = cnn_timings_4096[['DDM', 'DDM-SDV', 'ANGLE', 'ORNSTEIN', 'LEVY', 'WEIBULL', 'FULL-DDM',
                                     'LCA-3', 'LCA-4', 'RACE-MODEL-3', 'RACE-MODEL-4']]

# %%
timings_dict = {'MLP-1024':mlp_timings_1024,
                'MLP-4096':mlp_timings_4096,
                'CNN-1024':cnn_timings_1024,
                'CNN-4096':cnn_timings_4096}

# %%
caterpillar_plot_multidat(timings_dict)

# %%
caterpillar_plot(cnn_timings_1024)

# %%
caterpillar_plot(cnn_timings_4096,
                 n = 4096,
                 method = 'CNN')
