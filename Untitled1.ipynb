# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import load_model
import numpy as np
import os
import pandas as pd
import time
import psutil
import argparse
from datetime import datetime
import pickle
import yaml
from copy import deepcopy

# %%
# Plotting
import matplotlib.pyplot as plt
plt.style.use('default')
# %matplotlib inline

# %%
# Toy problem
def create_book_example(n = 1000):
    X = np.random.uniform(0., 1., size = (n, 1)).astype(np.float32)
    y = X + (0.3 * np.sin(4 * np.pi * X)) + np.random.uniform(- 0.1, 0.1, size = (n, 1)).astype(np.float32)
    
    # test data
    x_test = np.linspace(0, 1, n).reshape(-1, 1).astype(np.float32)
    return X, y, x_test

# %%
def create_spiral(n = 1000, a = 2, noise_range = 0.1, z_range = (0, 1), freq_base = 1):
    z1 = np.random.uniform(z_range[0], z_range[1], size = (n, 1)).astype(np.float32)
    x1 = a * np.cos(freq_base * np.pi * z1) + (noise_range / 2) * np.random.uniform(- 1, 1, size = (n, 1)).astype(np.float32)
    y1 = a * np.sin(freq_base * np.pi * z1) + (noise_range / 2) * np.random.uniform(- 1, 1, size = (n, 1)).astype(np.float32)
    z2 = np.random.uniform(z_range[0], z_range[1], size = (n, 1)).astype(np.float32)
    x2 = 2 * a * np.sin(freq_base * np.pi * z2) + (noise_range / 2) * np.random.uniform(- 1, 1, size = (n, 1)).astype(np.float32)
    y2 = 2 * a * np.cos(freq_base * np.pi * z2) + (noise_range / 2) * np.random.uniform(- 1, 1, size = (n, 1)).astype(np.float32)
    
    x = np.concatenate([x1, x2])
    y = np.concatenate([y1, y2])
    z = np.concatenate([z1, z2])
    
    noise_range_out = np.array([noise_range]*(n * 2))
    z_test = np.linspace(z_range[0], z_range[1], n * 2).reshape(-1, 1).astype(np.float32)
    return (x, y, z, z_test) #, noise_range_out)

# %%
def create_gauss_mix(n = 10000, n_c = 5, xy_range = (-5, 5), z_range = (0 , 1)):
    unif_x = np.random.uniform(xy_range[0], xy_range[1], size = n_c).astype(np.float32)
    unif_y = np.random.uniform(xy_range[0], xy_range[1], size = n_c).astype(np.float32)
    centers = np.stack([unif_x, unif_y]).T
    
    z = np.random.uniform(z_range[0], z_range[1], size = (n, 1)).astype(np.float32)
    xy = np.zeros((n, 2)).astype(np.float32)
    for i in range(n):
        xy[i,:] = np.random.normal(loc = centers[np.random.choice(5), :], scale = 0.4 * z[i] + 0.1)
        #print(np.random.normal(loc = centers[np.random.choice(5), :], scale = z[i] + 0.1))
        
    z_Test = np.linspace(z_range[0], z_range[1], n).reshape(-1, 1).astype(np.float32)
    return (xy, z, z_test)

# %%
xy, z, z_test = create_gauss_mix(n = 10)
# Out:
# [-2.57206547 -1.41495657]
# [ 3.3799969  -3.80441646]
# [-1.39446028 -3.04748837]
# [-1.74257976 -1.09380887]
# [ 4.76819258 -0.37291438]
# [ 3.30258675 -3.05212506]
# [ 2.59970378 -1.12105619]
# [ 2.08579191 -1.15559789]
# [-1.65749688 -3.19795886]
# [ 4.65707637 -0.3135623 ]

# %%
from mpl_toolkits import mplot3d

# %%
ax = plt.axes(projection='3d')
x, y, z, z_test = create_spiral(n = 10000, noise_range = 0.5)
train_labels = np.concatenate([x,y], axis = 1)

#x, y, z, n = create_spiral(n = 3000, noise_range = 0.2)

# Data for three-dimensional scattered points
#zdata = 15 * np.random.random(100)
#xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
#ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(z, x, y, c = z[:, 0], alpha = 0.2) #cmap = 'Greens', alpha = 0.2);

# %%
ax = plt.axes(projection='3d')
xy, z, z_test = create_gauss_mix()

#x, y, z, n = create_spiral(n = 3000, noise_range = 0.2)

# Data for three-dimensional scattered points
#zdata = 15 * np.random.random(100)
#xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
#ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(z, xy[:, 0], xy[:, 1], c = z[:, 0], alpha = 0.2) #cmap = 'Greens', alpha = 0.2);

# %%
xy[0, :]
# Out:
# array([-3.2808457, -3.2808457])

# %%
train_labels.shape
# Out:
# (20000, 2)

# %%
# Plot data (x and y)
X, y, x_test = create_book_example(n = 10000)
plt.plot(X, y,'ro', alpha = 0.04)
plt.show()

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
tf.executing_eagerly()
# Out:
# True

# %%
def get_model(h = 16, lr = 0.001):
    
    input = tf.keras.layers.Input(shape = (1, ))
    x = tf.keras.layers.Dense(h, activation = 'tanh')(input)
    x = tf.keras.layers.Dense(1, activation = None)(x)
    
    model = tf.keras.models.Model(input, x)
    
    model.compile(optimizer = tf.keras.optimizers.Adam(lr = lr), loss = 'mse', metrics = ['acc'])
    return model

# %%
# Load and train the network

model = get_model(h = 50)
epochs = 1000

# %%
history = model.fit(X, y, epochs = epochs, verbose = 0)

# Plot the loss history
plt.plot(range(epochs), history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training')
plt.show()

# %%
# Predict the target values for test data and
# plot along with training data
y_test = model.predict(x_test)
plt.plot(X, y, 'ro', alpha=0.05, label='train')
plt.plot(x_test, y_test, 'bo', alpha=0.3, label='test')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Plot train and test data')
plt.show()

# %%
# print data shape
print(X.shape, y.shape)

# Deepcopy is not required in this case
# (its more of a habit for me)
flipped_x = deepcopy(y)
flipped_y = deepcopy(X)

# load and train the model
#model = get_model(lr=0.09)

# Train the model for large number of epochs
epochs = 1500

#history = model.fit(flipped_x, flipped_y, epochs = epochs, verbose = 0)

# print(history.history['loss'][-1])
# plt.plot(range(epochs), history.history['loss'])
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.title('Training')
# plt.show()
# Out:
# (10000, 1) (10000, 1)

# %%
# epochs 500
x_test_inv = np.linspace(0., 1., 4000).reshape(-1, 1)
y_test_inv = model.predict(x_test_inv)

plt.plot(y, X, 'ro', alpha=0.05)
plt.plot(x_test_inv, y_test_inv, 'b.', alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-489c7e85510d> in <module>
#       1 # epochs 500
#       2 x_test_inv = np.linspace(0., 1., 4000).reshape(-1, 1)
# ----> 3 y_test_inv = model.predict(x_test_inv)
#       4
#       5 plt.plot(y, X, 'ro', alpha=0.05)
#
# NameError: name 'model' is not defined

# %%
# In our toy example, we have single input feature
l = 1

# Number of dimensions in output
dim_out = 2

# Number of gaussians to represent the multimodal distribution
k = 20

# Network
def get_mdn_1d():  # this is the one we need for ddm anyways..
    input = tf.keras.Input(shape = (l,))
    layer = tf.keras.layers.Dense(100, activation = 'tanh', name = 'baselayer')(input)
    #layer = tf.keras.layers.Dense(100, activation = 'tanh', name = 'baselayer2')(layer)
    mu = tf.keras.layers.Dense((l * k), activation = None, name = 'mean_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = - 1, maxval = 1, seed = None))(layer)
    # variance (should be greater than 0 so we exponentiate it)
    var = tf.keras.layers.Dense(k, activation = 'exponential', name = 'dense_var_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = - 10, maxval = 10, seed = None))(layer)
    #var = tf.keras.layers.Lambda(lambda x: tf.math.exp(x), output_shape = (k, ), name = 'variance_layer')(var)
    # mixing coefficient should sum to 1.0
    pi = tf.keras.layers.Dense(k, activation = 'softmax', name = 'pi_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = 0, maxval = 1, seed = None))(layer)
    model = tf.keras.models.Model(input, [pi, mu, var])
    optimizer = tf.keras.optimizers.Adam()
    return (model, optimizer)

# %%
def get_mdn_full_cov():
    input = tf.keras.Input(shape = (l, ))
    layer = tf.keras.layers.Dense(50, activation = 'tanh', name = 'baselayer')(input)
    layer = tf.keras.layers.Dense(100, activation = 'tanh', name = 'baselayer')(layer)
    mu = tf.keras.layers.Dense((l * k), activation = None, name = 'mean_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = -1, maxval = 1, seed = None))(layer)
    pi = tf.keras.layers.Dense(k, acitvation = 'softmax', name = 'pi_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = 0, maxvar = 1, seed = None))(layer)
    model = tf.keras.models.Model(input, [pi, mu, var ])

# %%
def get_mdn_iso():
    input = tf.keras.Input(shape = (l, ))
    layer = tf.keras.layers.Dense(50, activation = 'tanh', name = 'baselayer')(input)
    layer = tf.keras.layers.Dense(100, activation = 'tanh', name = 'baselayer2')(layer)
    mu = tf.keras.layers.Dense((dim_out * k), activation = None, name = 'mean_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = -1, maxval = 1, seed = None))(layer)
    mu = tf.keras.layers.Reshape((k, dim_out), name = 'mean_layer_reshaped')(mu)
    pi = tf.keras.layers.Dense(k, activation = 'softmax', name = 'pi_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = -1, maxval = 1, seed = None))(layer)
    var = tf.keras.layers.Dense((dim_out * k), activation = 'softplus', name = 'dense_var_layer', bias_initializer = tf.keras.initializers.RandomUniform(minval = 5, maxval = 10, seed = None))(layer)
    var = tf.keras.layers.Reshape((k, dim_out), name = 'var_layer_reshaped')(var)
    model = tf.keras.models.Model(input, [pi, mu, var])
    optimizer = tf.keras.optimizers.Adam()
    return (model, optimizer)

# %%
def calc_pdf_iso(y, mu, var):
    """Calculate Component Density"""
    var = var
    inv_var = tf.linalg.diag(1 / var)
    #print(inv_var.shape)
    inv_var_det = tf.expand_dims(tf.expand_dims(tf.sqrt(tf.linalg.det(inv_var)), -1), -1)
    #print(inv_var_det.shape)
    y_proper = tf.expand_dims(y, 1)
    diff = tf.expand_dims(tf.subtract(y_proper, mu), - 1)
    #print(diff.shape)
    diff_transp = tf.transpose(diff, perm = [0, 1, 3, 2])
    print('diff_transp:', diff_transp.shape)
    #print(diff_transp.shape)
    exponent = (- 1 / 2) * tf.matmul(tf.matmul(diff_transp, inv_var), diff)
    #print(exponent.shape)
    denominator = 1 / tf.sqrt(tf.pow(np.pi, dim_out))
    #determinantf = tf.sqrt(tf.linalg.det(inv_var))
    #value = tf.multiply(tf.exp(exponent), inv_var_det)
    
    print(denominator.shape)
    print(inv_var_det.shape)
    print(exponent.shape)
    value = denominator * tf.multiply(tf.exp(exponent), inv_var_det)
    #value = tf.exp(tf.divide(tf.square(tf.subtract(y, mu)), 2 * var)) # Gaussian exp
    #value = (1 / 2 * np.pi * var)) * tf.exp( (- value) / (2 * var))
    
    
    return tf.squeeze(value)

def mdn_loss_iso(y_true, pi, mu, var, omega = 0.0001):
    """MDN Loss Function"""
    out = calc_pdf_iso(y_true, mu, var)
    print('out shape: ',out.shape)
    print('pi shape:', pi.shape)
    out = tf.multiply(out, pi)
    print('out after multiply with pi:', out.shape)
    # print(out)
    out = tf.reduce_sum(out, 1, keepdims = True)
    inv_var_red = tf.reduce_sum(1 / var, (1, 2), keepdims = True)
    out = - tf.math.log(out + 1e-10) #+ (omega * inv_var_red)
    return tf.reduce_mean(out)

# %%
mdn_iso, optimizer = get_mdn_iso()

# %%
ma = np.ones((6000, 50, 2))
mb = np.ones((6000, 2))

# %%
mc = mb.reshape((6000, 1, 2))

# %%
(mc - ma).shape
# Out:
# (6000, 50, 2)

# %%
mdn, optimizer = get_mdn()

# %%
mdn_iso.summary()
# Out:
# Model: "model_25"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_26 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# baselayer (Dense)               (None, 50)           100         input_26[0][0]
# __________________________________________________________________________________________________
# baselayer2 (Dense)              (None, 100)          5100        baselayer[0][0]
# __________________________________________________________________________________________________
# mean_layer (Dense)              (None, 40)           4040        baselayer2[0][0]
# __________________________________________________________________________________________________
# dense_var_layer (Dense)         (None, 40)           4040        baselayer2[0][0]
# __________________________________________________________________________________________________
# pi_layer (Dense)                (None, 20)           2020        baselayer2[0][0]
# __________________________________________________________________________________________________
# mean_layer_reshaped (Reshape)   (None, 20, 2)        0           mean_layer[0][0]
# __________________________________________________________________________________________________
# var_layer_reshaped (Reshape)    (None, 20, 2)        0           dense_var_layer[0][0]
# ==================================================================================================
# Total params: 15,300
# Trainable params: 15,300
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def calc_pdf(y, mu, var):
    """Calculate Component Density"""
    value = tf.square(tf.subtract(y, mu)) 
    value = (1 / tf.sqrt(2 * np.pi * var)) * tf.exp( (- value) / (2 * var))
    return value

def mdn_loss(y_true, pi, mu, var):
    """MDN Loss Function"""
    out = calc_pdf(y_true, mu, var)
    out = tf.multiply(out, pi)
    # print(out)
    out = tf.reduce_sum(out, 1, keepdims = True)
    out = - tf.math.log(out + 1e-10)
    return tf.reduce_mean(out)

# %%
mdn_loss(np.array([3.0]), np.array([0.3, 0.3, 0.3]), np.array([0.0, 0.1, 0.2]), np.array([1.0, 2.2, 3.3])).numpy()
# Out:
# tf.Tensor([0.00132955 0.01193233 0.02008562], shape=(3,), dtype=float64)
# 4.986388754226722

# %%
# Use Dataset API to load numpy data (load, shuffle, set batch size)
N = flipped_x.shape[0]
dataset = tf.data.Dataset \
    .from_tensor_slices((flipped_x, flipped_y)) \
    .shuffle(N).batch(N)

# %%
# USE DATASET API TO LOAD NUMPY DATA (SPIRAL)
N = train_labels.shape[0]
dataset = tf.data.Dataset \
          .from_tensor_slices((z, train_labels)) \
          .shuffle(N).batch(256)

# %%
# USE DATASET API TO LOAD NUMPY DATA (SPIRAL)
N = xy.shape[0]
dataset = tf.data.Dataset \
          .from_tensor_slices((z, xy)) \
          .shuffle(N).batch(512)

# %%
# Train step ISO
@tf.function
def train_step(model, optimizer, train_x, train_y):
    # GradientTape: Trace operations to compute gradients
    with tf.GradientTape() as tape:
        pi_, mu_, var_ = model(train_x, training = True)
        # calculate loss
        loss = mdn_loss_iso(train_y, pi_, mu_, var_)
    # compute and apply gradients
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss

# %%
# Train iso
losses = []
EPOCHS = 100
print_every = 1 #int(EPOCHS)

# Define model and optimizer
#model = tf.keras.models.Model(input, [pi, mu, var])
#optimizer = tf.keras.optimizers.Adam()
#model, optimizer = get_mdn()

# Start training
print('Print every {} epochs'.format(print_every))
for i in range(EPOCHS):
    for train_x, train_y in dataset:
        loss = train_step(mdn_iso, optimizer, train_x, train_y)
        losses.append(loss)
    if i % print_every == 0:
        print('Epoch {}/{}: loss {}'.format(i, EPOCHS, losses[-1]))
# Out:
# Print every 1 epochs
# diff_transp: (256, 20, 1, 2)
# ()
# (256, 20, 1, 1)
# (256, 20, 1, 1)
# out shape:  (256, 20)
# pi shape: (256, 20)
# out after multiply with pi: (256, 20)
# diff_transp: (256, 20, 1, 2)
# ()
# (256, 20, 1, 1)
# (256, 20, 1, 1)
# out shape:  (256, 20)
# pi shape: (256, 20)
# out after multiply with pi: (256, 20)
# diff_transp: (32, 20, 1, 2)
# ()
# (32, 20, 1, 1)
# (32, 20, 1, 1)
# out shape:  (32, 20)
# pi shape: (32, 20)
# out after multiply with pi: (32, 20)
# Epoch 0/100: loss 2.7520174980163574
# Epoch 1/100: loss 1.5626147985458374
# Epoch 2/100: loss 0.7124494314193726
# Epoch 3/100: loss -0.4799448549747467
# Epoch 4/100: loss -0.4077361226081848
# Epoch 5/100: loss -0.46229374408721924
# Epoch 6/100: loss -0.7017822265625
# Epoch 7/100: loss -0.7423650026321411
# Epoch 8/100: loss -0.7319684028625488
# Epoch 9/100: loss -0.7420315742492676
# Epoch 10/100: loss -0.8850692510604858
# Epoch 11/100: loss -1.0154762268066406
# Epoch 12/100: loss -0.9034422039985657
# Epoch 13/100: loss -0.8099510669708252
# Epoch 14/100: loss -0.8520815968513489
# Epoch 15/100: loss -0.5985636711120605
# Epoch 16/100: loss -1.0303641557693481
# Epoch 17/100: loss -0.997156023979187
# Epoch 18/100: loss -0.8907831907272339
# Epoch 19/100: loss -0.936963677406311
# Epoch 20/100: loss -1.0086404085159302
# Epoch 21/100: loss -0.8686222434043884
# Epoch 22/100: loss -1.0795187950134277
# Epoch 23/100: loss -1.1649010181427002
# Epoch 24/100: loss -0.9385563135147095
# Epoch 25/100: loss -0.9674901366233826
# Epoch 26/100: loss -0.8337554931640625
# Epoch 27/100: loss -1.0958709716796875
# Epoch 28/100: loss -0.9397614002227783
# Epoch 29/100: loss -0.9549269676208496
# Epoch 30/100: loss -0.8739063739776611
# Epoch 31/100: loss -1.1749701499938965
# Epoch 32/100: loss -0.9628597497940063
# Epoch 33/100: loss -1.0354708433151245
# Epoch 34/100: loss -0.9480366110801697
# Epoch 35/100: loss -0.9854342937469482
# Epoch 36/100: loss -0.9231749773025513
# Epoch 37/100: loss -1.2673041820526123
# Epoch 38/100: loss -0.9265059232711792
# Epoch 39/100: loss -0.8220045566558838
# Epoch 40/100: loss -0.9304525256156921
# Epoch 41/100: loss -0.9973791837692261
# Epoch 42/100: loss -0.9166556596755981
# Epoch 43/100: loss -1.0226659774780273
# Epoch 44/100: loss -0.9895648956298828
# Epoch 45/100: loss -0.9327123165130615
# Epoch 46/100: loss -0.9905184507369995
# Epoch 47/100: loss -0.9944124221801758
# Epoch 48/100: loss -0.9587388038635254
# Epoch 49/100: loss -0.9451505541801453
# Epoch 50/100: loss -0.860448956489563
# Epoch 51/100: loss -0.892195999622345
# Epoch 52/100: loss -1.0820635557174683
# Epoch 53/100: loss -0.9049036502838135
# Epoch 54/100: loss -1.0021617412567139
# Epoch 55/100: loss -1.0256731510162354
# Epoch 56/100: loss -0.9721789956092834
# Epoch 57/100: loss -0.9288768768310547
# Epoch 58/100: loss -1.1295182704925537
# Epoch 59/100: loss -0.9899325966835022
# Epoch 60/100: loss -0.9499713182449341
# Epoch 61/100: loss -1.0024899244308472
# Epoch 62/100: loss -1.0339499711990356
# Epoch 63/100: loss -0.9548629522323608
# Epoch 64/100: loss -0.9933642148971558
# Epoch 65/100: loss -1.083777666091919
# Epoch 66/100: loss -1.1233603954315186
# Epoch 67/100: loss -0.9718411564826965
# Epoch 68/100: loss -1.0204676389694214
# Epoch 69/100: loss -1.07326340675354
# Epoch 70/100: loss -1.1595574617385864
# Epoch 71/100: loss -0.9943357110023499
# Epoch 72/100: loss -1.047569751739502
# Epoch 73/100: loss -1.1471565961837769
# Epoch 74/100: loss -0.927796483039856
# Epoch 75/100: loss -1.0002496242523193
# Epoch 76/100: loss -0.830971896648407
# Epoch 77/100: loss -0.6867333054542542
# Epoch 78/100: loss -1.0444204807281494
# Epoch 79/100: loss -1.068145751953125
# Epoch 80/100: loss -0.9931377172470093
# Epoch 81/100: loss -1.040534257888794
# Epoch 82/100: loss -0.8577530384063721
# Epoch 83/100: loss -0.8920696973800659
# Epoch 84/100: loss -1.275108814239502
# Epoch 85/100: loss -0.849357545375824
# Epoch 86/100: loss -0.8466814160346985
# Epoch 87/100: loss -0.9303889870643616
# Epoch 88/100: loss -0.9753525257110596
# Epoch 89/100: loss -0.8884226083755493
# Epoch 90/100: loss -0.9472343921661377
# Epoch 91/100: loss -0.981769859790802
# Epoch 92/100: loss -0.8211612701416016
# Epoch 93/100: loss -0.8993070125579834
# Epoch 94/100: loss -1.094763159751892
# Epoch 95/100: loss -1.1583322286605835
# Epoch 96/100: loss -1.0412977933883667
# Epoch 97/100: loss -0.8403545022010803
# Epoch 98/100: loss -1.1240320205688477
# Epoch 99/100: loss -0.7333933115005493

# %%
# ISO PREDICTIONS
# def approx_conditional_mode(pi, var, mu):
#     """Approx conditional mode
#     Because the conditional mode for MDN does not have simple analytical
#     solution, an alternative is to take mean of most probable component 
#     at each value of x (PRML, page 277)
#     """
#     n, k = pi.shape
#     out = np.zeros((n, l))
#     # Get the index of max pi value for each row
#     max_component = tf.argmax(pi, axis=1)
#     for i in range(n):
#         # The mean value for this index will be used
#         mc = max_component[i].numpy()
#         for j in range(l):
#             out[i, j] = mu[i, mc * (l + j)]
#     return out


# Get predictions
pi_vals, mu_vals, var_vals = mdn_iso.predict(z_test)
print(pi_vals.shape, mu_vals.shape, var_vals.shape)

# Get mean of max(mixing coefficient) of each row
#preds = approx_conditional_mode(pi_vals, var_vals, mu_vals)

# Plot along with training data
# fig = plt.figure(figsize = (8, 8))
# plt.plot(flipped_x, flipped_y, 'ro')
# plt.plot(x_test, preds, 'g.')
# # plt.plot(flipped_x, preds2, 'b.')
# plt.show()
# Out:
# (20000, 20) (20000, 20, 2) (20000, 20, 2)

# %%
#pi_vals[:100, :]

# %%
mu_vals[2000, :]
# Out:
# array([[ 1.8618708 ,  1.5204408 ],
#        [ 1.8410625 ,  2.8580246 ],
#        [ 1.3956093 ,  1.1645193 ],
#        [ 4.645563  ,  4.2473593 ],
#        [ 1.3107303 ,  2.1820562 ],
#        [ 3.079596  ,  2.8132157 ],
#        [ 0.5307162 ,  2.7929232 ],
#        [ 1.28687   ,  1.254755  ],
#        [ 9.480485  ,  2.1933131 ],
#        [ 1.8988831 ,  0.60250115],
#        [ 1.2256467 ,  3.7904449 ],
#        [ 1.0448207 ,  2.2511337 ],
#        [-0.2666616 ,  3.029168  ],
#        [ 2.298317  ,  1.8711545 ],
#        [ 1.7122772 ,  2.1284952 ],
#        [ 1.4893585 ,  1.5382438 ],
#        [ 0.95644474,  0.04798955],
#        [ 0.9860925 ,  2.0925136 ],
#        [ 0.43652073,  2.2159467 ],
#        [ 1.491436  ,  1.2796987 ]], dtype=float32)

# %%
#var_vals[1900:2000, :]

# %%
import matplotlib.patches as mpatches

fig = plt.figure(figsize=(6, 6))
plt.plot(flipped_x, flipped_y, 'ro', label = 'train')
plt.ylim(-1, 2)
for i in range(sampled_predictions.shape[1]):
     plt.plot(x_test, sampled_predictions[:, i], 'g.', alpha=0.3, label = 'predicted')
patches = [
    mpatches.Patch(color='green', label='Training'),
    mpatches.Patch(color='red', label='Predicted')
]
    
plt.legend(handles=patches)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-bc2dd89d8292> in <module>
#       2
#       3 fig = plt.figure(figsize=(6, 6))
# ----> 4 plt.plot(flipped_x, flipped_y, 'ro', label = 'train')
#       5 plt.ylim(-1, 2)
#       6 for i in range(sampled_predictions.shape[1]):
#
# NameError: name 'flipped_x' is not defined

# %%
def sample_predictions_mdn(pi_vals, mu_vals, var_vals, samples = 1):
    n, k = pi_vals.shape
    # print('shape: ', n, k, l)
    # place holder to store the y value for each sample of each row
    out = np.zeros((n, samples, dim_out))
    for i in range(n):
        for j in range(samples):
            # for each sample, use pi/probs to sample the index
            # that will be used to pick up the mu and var values
            idx = np.random.choice(range(k), p = pi_vals[i])
            for li in range(l):
                # Draw random sample from gaussian distribution
                out[i, j, :] = np.random.normal(mu_vals[i, idx, :], np.sqrt(var_vals[i, idx, :]))
    return out    

sampled_predictions = sample_predictions_mdn(pi_vals, mu_vals, var_vals, 1)

# %%
sampled_predictions.shape
# Out:
# (20000, 1, 2)

# %%
ax = plt.axes(projection = '3d')
x_det, y_det, z_det, z_test_det = create_spiral(n = 10000, noise_range = 0.01)

#x, y, z, z_test = create_spiral(n = 3000, noise_range = 0.2)

#x, y, z, n = create_spiral(n = 3000, noise_range = 0.2)

# Data for three-dimensional scattered points
#zdata = 15 * np.random.random(100)
#xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
#ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
for i in range(1):
    ax.scatter3D(z_test, sampled_predictions[:, i, 0], sampled_predictions[:, i, 1], c = z_test[:, 0], alpha = 0.02) #cmap = 'Greens', alpha = 0.2);
    ax.scatter3D(z_det, x_det, y_det, c = 'black') #c = z[:, 0], alpha = 1) # , cmap = 'Greens') #, alpha = 0.2);

# %%
z_test = np.linspace(-1, 1, 3000 * 2).reshape(-1, 1).astype(np.float32)

# %%
@tf.function
def train_step(model, optimizer, train_x, train_y):
    # GradientTape: Trace operations to compute gradients
    with tf.GradientTape() as tape:
        pi_, mu_, var_ = model(train_x, training = True)
        # calculate loss
        loss = mdn_loss(train_y, pi_, mu_, var_)
    # compute and apply gradients
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss

# %%
losses = []
EPOCHS = 5000
print_every = int(0.01 * EPOCHS)

# Define model and optimizer
#model = tf.keras.models.Model(input, [pi, mu, var])
#optimizer = tf.keras.optimizers.Adam()
#model, optimizer = get_mdn()

# Start training
print('Print every {} epochs'.format(print_every))
for i in range(EPOCHS):
    for train_x, train_y in dataset:
        loss = train_step(mdn, optimizer, train_x, train_y)
        losses.append(loss)
        print('loss: ', loss)
    if i % print_every == 0:
        print('Epoch {}/{}: loss {}'.format(i, EPOCHS, losses[-1]))
# Out:
# Print every 50 epochs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-54b4904a3dea> in <module>
#      11 print('Print every {} epochs'.format(print_every))
#      12 for i in range(EPOCHS):
# ---> 13     for train_x, train_y in dataset:
#      14         loss = train_step(mdn, optimizer, train_x, train_y)
#      15         losses.append(loss)
#
# NameError: name 'dataset' is not defined

# %%
# Let's plot the training loss
plt.plot(range(len(losses)), losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training loss')
plt.show()

# %%
def approx_conditional_mode(pi, var, mu):
    """Approx conditional mode
    Because the conditional mode for MDN does not have simple analytical
    solution, an alternative is to take mean of most probable component 
    at each value of x (PRML, page 277)
    """
    n, k = pi.shape
    out = np.zeros((n, l))
    # Get the index of max pi value for each row
    max_component = tf.argmax(pi, axis=1)
    for i in range(n):
        # The mean value for this index will be used
        mc = max_component[i].numpy()
        for j in range(l):
            out[i, j] = mu[i, mc * (l + j)]
    return out


# Get predictions
pi_vals, mu_vals, var_vals = mdn.predict(x_test)
pi_vals.shape, mu_vals.shape, var_vals.shape

# Get mean of max(mixing coefficient) of each row
preds = approx_conditional_mode(pi_vals, var_vals, mu_vals)

# Plot along with training data
fig = plt.figure(figsize = (8, 8))
plt.plot(flipped_x, flipped_y, 'ro')
plt.plot(x_test, preds, 'g.')
# plt.plot(flipped_x, preds2, 'b.')
plt.show()

# %%
def sample_predictions(pi_vals, mu_vals, var_vals, samples = 10):
    n, k = pi_vals.shape
    # print('shape: ', n, k, l)
    # place holder to store the y value for each sample of each row
    out = np.zeros((n, samples, l))
    for i in range(n):
        for j in range(samples):
            # for each sample, use pi/probs to sample the index
            # that will be used to pick up the mu and var values
            idx = np.random.choice(range(k), p = pi_vals[i])
            for li in range(l):
                # Draw random sample from gaussian distribution
                out[i,j,li] = np.random.normal(mu_vals[i, idx*(li+l)], np.sqrt(var_vals[i, idx]))
    return out    

sampled_predictions = sample_predictions(pi_vals, mu_vals, var_vals, 10)

# %%
# Plot the predictions along with the flipped data 
import matplotlib.patches as mpatches

fig = plt.figure(figsize=(6, 6))
plt.plot(flipped_x, flipped_y, 'ro', label = 'train')
plt.ylim(-1, 2)
for i in range(sampled_predictions.shape[1]):
     plt.plot(x_test, sampled_predictions[:, i], 'g.', alpha=0.3, label = 'predicted')
patches = [
    mpatches.Patch(color='green', label='Training'),
    mpatches.Patch(color='red', label='Predicted')
]
    
plt.legend(handles=patches)
plt.show()

# %%
import tensorflow_probability as tfp

# %%
tfd = tfp.distributions
tfpl = tfp.layers
tfk = tf.keras
tfkl = tf.keras.layers

# Load data -- graph of a [cardioid](https://en.wikipedia.org/wiki/Cardioid).
n = 2000
t = tfd.Uniform(low=-np.pi, high=np.pi).sample([n, 1])
r = 2 * (1 - tf.cos(t))
x = r * tf.sin(t) + tfd.Normal(loc=0., scale=0.1).sample([n, 1])
y = r * tf.cos(t) + tfd.Normal(loc=0., scale=0.1).sample([n, 1])

# Model the distribution of y given x with a Mixture Density Network.
event_shape = [1]
num_components = 5
params_size = tfpl.MixtureSameFamily.params_size(
    num_components,
    component_params_size=tfpl.IndependentNormal.params_size(event_shape))

model = tfk.Sequential([
  tfkl.Dense(12, activation='relu'),
  tfkl.Dense(params_size, activation=None),
  tfpl.MixtureSameFamily(num_components, tfpl.IndependentNormal(event_shape)),
])

# Fit.
batch_size = 100
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.02),
              loss = lambda y, model: - model.log_prob(y))
model.fit(x, y,
          batch_size=batch_size,
          epochs=20,
          steps_per_epoch=n // batch_size)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 0s 1ms/step - loss: 1.8713
# Epoch 2/20
# 20/20 [==============================] - 0s 1ms/step - loss: 1.3899
# Epoch 3/20
# 20/20 [==============================] - 0s 977us/step - loss: 1.2258
# Epoch 4/20
# 20/20 [==============================] - 0s 1ms/step - loss: 1.1057
# Epoch 5/20
# 20/20 [==============================] - 0s 1ms/step - loss: 0.9613
# Epoch 6/20
# 20/20 [==============================] - 0s 990us/step - loss: 0.7517
# Epoch 7/20
# 20/20 [==============================] - 0s 993us/step - loss: 0.6245
# Epoch 8/20
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5706
# Epoch 9/20
# 20/20 [==============================] - 0s 990us/step - loss: 0.5484
# Epoch 10/20
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4783
# Epoch 11/20
# 20/20 [==============================] - 0s 953us/step - loss: 0.4853
# Epoch 12/20
# 20/20 [==============================] - 0s 922us/step - loss: 0.4566
# Epoch 13/20
# 20/20 [==============================] - 0s 944us/step - loss: 0.4333
# Epoch 14/20
# 20/20 [==============================] - 0s 982us/step - loss: 0.4336
# Epoch 15/20
# 20/20 [==============================] - 0s 979us/step - loss: 0.4348
# Epoch 16/20
# 20/20 [==============================] - 0s 984us/step - loss: 0.4072
# Epoch 17/20
# 20/20 [==============================] - 0s 995us/step - loss: 0.3970
# Epoch 18/20
# 20/20 [==============================] - 0s 922us/step - loss: 0.4017
# Epoch 19/20
# 20/20 [==============================] - 0s 927us/step - loss: 0.3434
# Epoch 20/20
# 20/20 [==============================] - 0s 968us/step - loss: 0.3472

# %%
tfpl.IndependentNormal.params_size(event_shape)
# Out:
# 2

# %%
params_size
# Out:
# 15

# %%
plt.plot(x,y, '.')

# %%
y_pred = model.predict(x)

# %%
plt.plot(x, y_pred, '.', alpha = 0.3)
plt.plot(x, y, '.', color = 'red', alpha = 0.3)

# %%
y_pred2 = model.predict(x)

# %%
np.array_equal(y_pred, y_pred2)
# Out:
# False

# %%
y_pred[:10]
# Out:
# array([[-2.0429015 ],
#        [-3.494053  ],
#        [-2.696699  ],
#        [-4.0112586 ],
#        [-2.001936  ],
#        [-2.249207  ],
#        [-3.199544  ],
#        [-0.16593647],
#        [ 0.6335046 ],
#        [ 0.47450647]], dtype=float32)

# %%
y_pred2[:10]
# Out:
# array([[-0.529323  ],
#        [-3.559599  ],
#        [-0.9752273 ],
#        [-3.7772913 ],
#        [-2.8422587 ],
#        [-1.5286007 ],
#        [-0.5320331 ],
#        [-3.2237933 ],
#        [ 0.4908444 ],
#        [ 0.29399678]], dtype=float32)

# %%
y_dist = model(x)

# %%
type(y_dist)
# Out:
# tensorflow_probability.python.util.deferred_tensor.MixtureSameFamily

# %%
y_mean = y_dist.mean()

# %%
plt.plot(x, y_mean, '.', alpha = 0.3)
plt.plot(x, y, '.', color = 'red', alpha = 0.3)

# %%
y_dist.sample()
# Out:
# <tf.Tensor: shape=(2000, 1), dtype=float32, numpy=
# array([[-0.84646493],
#        [-3.4917426 ],
#        [-3.255796  ],
#        ...,
#        [ 0.33154538],
#        [-3.1928048 ],
#        [ 0.63538903]], dtype=float32)>

# %%
plt.plot(x, y, '.', alpha = 0.3)
plt.plot(x, y_dist.sample(), '.', color = 'red', alpha = 0.3)

# %%
dir(model)
# Out:
# ['_TF_MODULE_IGNORED_PROPERTIES',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_activity_regularizer',
#  '_add_inbound_node',
#  '_add_trackable',
#  '_add_variable_with_custom_getter',
#  '_assert_compile_was_called',
#  '_assert_weights_created',
#  '_attribute_sentinel',
#  '_auto_track_sub_layers',
#  '_autocast',
#  '_base_init',
#  '_build_input_shape',
#  '_call_accepts_kwargs',
#  '_call_arg_was_passed',
#  '_call_fn_args',
#  '_call_full_argspec',
#  '_callable_losses',
#  '_check_call_args',
#  '_checkpoint_dependencies',
#  '_clear_losses',
#  '_collect_input_masks',
#  '_compile_was_called',
#  '_compiled_trainable_state',
#  '_compute_dtype',
#  '_compute_output_and_mask_jointly',
#  '_compute_tensor_usage_count',
#  '_conform_to_reference_input',
#  '_dedup_weights',
#  '_deferred_dependencies',
#  '_distribution_strategy',
#  '_dtype',
#  '_dtype_defaulted_to_floatx',
#  '_dtype_policy',
#  '_dynamic',
#  '_eager_add_metric',
#  '_eager_losses',
#  '_expects_mask_arg',
#  '_expects_training_arg',
#  '_flatten',
#  '_flatten_to_reference_inputs',
#  '_gather_children_attribute',
#  '_gather_layers',
#  '_gather_saveables_for_checkpoint',
#  '_gather_unique_layers',
#  '_get_call_arg_value',
#  '_get_callback_model',
#  '_get_compile_args',
#  '_get_distribution_strategy',
#  '_get_existing_metric',
#  '_get_node_attribute_at_index',
#  '_get_optimizer',
#  '_get_save_spec',
#  '_get_trainable_state',
#  '_graph',
#  '_graph_network_add_loss',
#  '_graph_network_add_metric',
#  '_handle_activity_regularization',
#  '_handle_deferred_dependencies',
#  '_handle_deferred_layer_dependencies',
#  '_handle_weight_regularization',
#  '_in_multi_worker_mode',
#  '_inbound_nodes',
#  '_init_call_fn_args',
#  '_init_graph_network',
#  '_init_set_name',
#  '_init_subclassed_network',
#  '_initial_weights',
#  '_input_spec',
#  '_insert_layers',
#  '_is_compiled',
#  '_is_graph_network',
#  '_is_layer',
#  '_keras_api_names',
#  '_keras_api_names_v1',
#  '_layer_call_argspecs',
#  '_layer_checkpoint_dependencies',
#  '_layers',
#  '_list_extra_dependencies_for_serialization',
#  '_list_functions_for_serialization',
#  '_lookup_dependency',
#  '_losses',
#  '_maybe_build',
#  '_maybe_cast_inputs',
#  '_maybe_create_attribute',
#  '_maybe_initialize_trackable',
#  '_maybe_load_initial_epoch_from_ckpt',
#  '_metrics',
#  '_metrics_lock',
#  '_name',
#  '_name_based_attribute_restore',
#  '_name_based_restores',
#  '_name_scope',
#  '_no_dependency',
#  '_non_trainable_weights',
#  '_obj_reference_counts',
#  '_obj_reference_counts_dict',
#  '_object_identifier',
#  '_outbound_nodes',
#  '_preload_simple_restoration',
#  '_reset_compile_cache',
#  '_restore_from_checkpoint_position',
#  '_reuse',
#  '_run_eagerly',
#  '_run_internal_graph',
#  '_saved_model_inputs_spec',
#  '_scope',
#  '_self_name_based_restores',
#  '_self_setattr_tracking',
#  '_self_unconditional_checkpoint_dependencies',
#  '_self_unconditional_deferred_dependencies',
#  '_self_unconditional_dependency_names',
#  '_self_update_uid',
#  '_set_connectivity_metadata_',
#  '_set_dtype_policy',
#  '_set_inputs',
#  '_set_mask_metadata',
#  '_set_output_names',
#  '_set_save_spec',
#  '_set_trainable_state',
#  '_setattr_tracking',
#  '_should_compute_mask',
#  '_should_eval',
#  '_single_restoration_from_checkpoint_position',
#  '_stateful',
#  '_supports_ragged_inputs',
#  '_symbolic_add_metric',
#  '_symbolic_call',
#  '_tf_api_names',
#  '_tf_api_names_v1',
#  '_thread_local',
#  '_track_trackable',
#  '_trackable_saved_model_saver',
#  '_trackable_saver',
#  '_tracking_metadata',
#  '_trainable',
#  '_trainable_weights',
#  '_training_state',
#  '_unconditional_checkpoint_dependencies',
#  '_unconditional_dependency_names',
#  '_undeduplicated_weights',
#  '_update_uid',
#  '_updated_config',
#  '_updates',
#  '_validate_compile',
#  '_validate_graph_inputs_and_outputs',
#  '_warn_about_input_casting',
#  'activity_regularizer',
#  'add',
#  'add_loss',
#  'add_metric',
#  'add_update',
#  'add_variable',
#  'add_weight',
#  'apply',
#  'build',
#  'built',
#  'call',
#  'compile',
#  'compiled_loss',
#  'compiled_metrics',
#  'compute_mask',
#  'compute_output_shape',
#  'compute_output_signature',
#  'count_params',
#  'distribute_strategy',
#  'dtype',
#  'dynamic',
#  'evaluate',
#  'evaluate_generator',
#  'fit',
#  'fit_generator',
#  'from_config',
#  'get_config',
#  'get_input_at',
#  'get_input_mask_at',
#  'get_input_shape_at',
#  'get_layer',
#  'get_losses_for',
#  'get_output_at',
#  'get_output_mask_at',
#  'get_output_shape_at',
#  'get_updates_for',
#  'get_weights',
#  'history',
#  'inbound_nodes',
#  'input',
#  'input_mask',
#  'input_names',
#  'input_shape',
#  'input_spec',
#  'inputs',
#  'layers',
#  'load_weights',
#  'loss',
#  'losses',
#  'make_predict_function',
#  'make_test_function',
#  'make_train_function',
#  'metrics',
#  'metrics_names',
#  'name',
#  'name_scope',
#  'non_trainable_variables',
#  'non_trainable_weights',
#  'optimizer',
#  'outbound_nodes',
#  'output',
#  'output_mask',
#  'output_names',
#  'output_shape',
#  'outputs',
#  'pop',
#  'predict',
#  'predict_classes',
#  'predict_function',
#  'predict_generator',
#  'predict_on_batch',
#  'predict_proba',
#  'predict_step',
#  'reset_metrics',
#  'reset_states',
#  'run_eagerly',
#  'save',
#  'save_weights',
#  'set_weights',
#  'state_updates',
#  'stateful',
#  'stop_training',
#  'submodules',
#  'summary',
#  'supports_masking',
#  'test_function',
#  'test_on_batch',
#  'test_step',
#  'to_json',
#  'to_yaml',
#  'train_function',
#  'train_on_batch',
#  'train_step',
#  'trainable',
#  'trainable_variables',
#  'trainable_weights',
#  'updates',
#  'variables',
#  'weights',
#  'with_name_scope']

# %%
model.layers[1].weights[1]
# Out:
# <tf.Variable 'sequential_1/dense_3/bias:0' shape=(15,) dtype=float32, numpy=
# array([ 1.1477426 , -0.05638814, -0.7799785 , -0.8031138 ,  0.0425654 ,
#         0.32770517, -0.41265354,  0.72777444, -0.6302155 ,  0.5256945 ,
#        -0.12009402, -0.23589455,  0.2946376 , -0.8993671 , -0.02037435],
#       dtype=float32)>

# %%
dir(y_dist)
# Out:
# ['_TF_MODULE_IGNORED_PROPERTIES',
#  '__abs__',
#  '__abstractmethods__',
#  '__add__',
#  '__and__',
#  '__array_priority__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_abc_impl',
#  '_add_variable_with_custom_getter',
#  '_allow_nan_stats',
#  '_batch_shape',
#  '_batch_shape_tensor',
#  '_call_cdf',
#  '_call_log_cdf',
#  '_call_log_prob',
#  '_call_log_survival_function',
#  '_call_prob',
#  '_call_quantile',
#  '_call_sample_n',
#  '_call_survival_function',
#  '_checkpoint_dependencies',
#  '_components_distribution',
#  '_concrete_value',
#  '_convert_to_tensor_fn',
#  '_covariance',
#  '_cross_entropy',
#  '_default_event_space_bijector',
#  '_deferred_dependencies',
#  '_disallow_bool_casting',
#  '_disallow_in_graph_mode',
#  '_disallow_iteration',
#  '_disallow_when_autograph_disabled',
#  '_disallow_when_autograph_enabled',
#  '_distributional_transform',
#  '_dtype',
#  '_entropy',
#  '_event_ndims',
#  '_event_shape',
#  '_event_shape_tensor',
#  '_expand_sample_shape_to_vector',
#  '_experimental_default_event_space_bijector',
#  '_flatten',
#  '_gather_saveables_for_checkpoint',
#  '_graph_parents',
#  '_handle_deferred_dependencies',
#  '_initial_parameter_control_dependencies',
#  '_is_scalar_helper',
#  '_keras_mask',
#  '_kl_divergence',
#  '_list_extra_dependencies_for_serialization',
#  '_list_functions_for_serialization',
#  '_log_cdf',
#  '_log_prob',
#  '_log_survival_function',
#  '_lookup_dependency',
#  '_maybe_initialize_trackable',
#  '_mean',
#  '_mixture_distribution',
#  '_mode',
#  '_name',
#  '_name_and_control_scope',
#  '_name_based_attribute_restore',
#  '_name_based_restores',
#  '_name_scope',
#  '_no_dependency',
#  '_object_identifier',
#  '_pad_sample_dims',
#  '_param_shapes',
#  '_parameter_control_dependencies',
#  '_parameters',
#  '_parameters_sanitized',
#  '_params_event_ndims',
#  '_preload_simple_restoration',
#  '_quantile',
#  '_reparameterization_type',
#  '_reparameterize',
#  '_reparameterize_sample',
#  '_restore_from_checkpoint_position',
#  '_sample_control_dependencies',
#  '_sample_n',
#  '_self_name_based_restores',
#  '_self_setattr_tracking',
#  '_self_unconditional_checkpoint_dependencies',
#  '_self_unconditional_deferred_dependencies',
#  '_self_unconditional_dependency_names',
#  '_self_update_uid',
#  '_set_sample_static_shape',
#  '_setattr_tracking',
#  '_single_restoration_from_checkpoint_position',
#  '_stddev',
#  '_survival_function',
#  '_tf_api_names',
#  '_tf_api_names_v1',
#  '_track_trackable',
#  '_tracking_metadata',
#  '_unconditional_checkpoint_dependencies',
#  '_unconditional_dependency_names',
#  '_update_uid',
#  '_validate_args',
#  '_value',
#  '_variance',
#  'allow_nan_stats',
#  'batch_shape',
#  'batch_shape_tensor',
#  'cdf',
#  'components_distribution',
#  'copy',
#  'covariance',
#  'cross_entropy',
#  'dtype',
#  'entropy',
#  'event_shape',
#  'event_shape_tensor',
#  'get_shape',
#  'is_scalar_batch',
#  'is_scalar_event',
#  'kl_divergence',
#  'log_cdf',
#  'log_prob',
#  'log_survival_function',
#  'mean',
#  'mixture_distribution',
#  'mode',
#  'name',
#  'name_scope',
#  'param_shapes',
#  'param_static_shapes',
#  'parameters',
#  'prob',
#  'quantile',
#  'registered_class_list',
#  'reparameterization_type',
#  'sample',
#  'shape',
#  'stddev',
#  'submodules',
#  'survival_function',
#  'trainable_variables',
#  'validate_args',
#  'variables',
#  'variance',
#  'with_name_scope']

# %%
dir(y_dist.components_distribution)
# Out:
# ['_TF_MODULE_IGNORED_PROPERTIES',
#  '__abs__',
#  '__abstractmethods__',
#  '__add__',
#  '__and__',
#  '__array_priority__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_abc_impl',
#  '_add_variable_with_custom_getter',
#  '_allow_nan_stats',
#  '_batch_shape',
#  '_batch_shape_tensor',
#  '_call_cdf',
#  '_call_log_cdf',
#  '_call_log_prob',
#  '_call_log_survival_function',
#  '_call_prob',
#  '_call_quantile',
#  '_call_sample_n',
#  '_call_survival_function',
#  '_checkpoint_dependencies',
#  '_concrete_value',
#  '_convert_to_tensor_fn',
#  '_covariance',
#  '_cross_entropy',
#  '_default_event_space_bijector',
#  '_deferred_dependencies',
#  '_disallow_bool_casting',
#  '_disallow_in_graph_mode',
#  '_disallow_iteration',
#  '_disallow_when_autograph_disabled',
#  '_disallow_when_autograph_enabled',
#  '_distribution',
#  '_dtype',
#  '_entropy',
#  '_event_shape',
#  '_event_shape_tensor',
#  '_expand_sample_shape_to_vector',
#  '_experimental_default_event_space_bijector',
#  '_flatten',
#  '_gather_saveables_for_checkpoint',
#  '_get_reinterpreted_batch_ndims',
#  '_graph_parents',
#  '_handle_deferred_dependencies',
#  '_initial_parameter_control_dependencies',
#  '_is_scalar_helper',
#  '_keras_mask',
#  '_kl_divergence',
#  '_list_extra_dependencies_for_serialization',
#  '_list_functions_for_serialization',
#  '_log_cdf',
#  '_log_prob',
#  '_log_survival_function',
#  '_lookup_dependency',
#  '_maybe_initialize_trackable',
#  '_mean',
#  '_mode',
#  '_name',
#  '_name_and_control_scope',
#  '_name_based_attribute_restore',
#  '_name_based_restores',
#  '_name_scope',
#  '_no_dependency',
#  '_object_identifier',
#  '_param_shapes',
#  '_parameter_control_dependencies',
#  '_parameters',
#  '_parameters_sanitized',
#  '_params_event_ndims',
#  '_preload_simple_restoration',
#  '_quantile',
#  '_reduce',
#  '_reinterpreted_batch_ndims',
#  '_reparameterization_type',
#  '_restore_from_checkpoint_position',
#  '_sample_control_dependencies',
#  '_sample_n',
#  '_self_name_based_restores',
#  '_self_setattr_tracking',
#  '_self_unconditional_checkpoint_dependencies',
#  '_self_unconditional_deferred_dependencies',
#  '_self_unconditional_dependency_names',
#  '_self_update_uid',
#  '_set_sample_static_shape',
#  '_setattr_tracking',
#  '_single_restoration_from_checkpoint_position',
#  '_static_reinterpreted_batch_ndims',
#  '_stddev',
#  '_survival_function',
#  '_tf_api_names',
#  '_tf_api_names_v1',
#  '_track_trackable',
#  '_tracking_metadata',
#  '_unconditional_checkpoint_dependencies',
#  '_unconditional_dependency_names',
#  '_update_uid',
#  '_validate_args',
#  '_value',
#  '_variance',
#  'allow_nan_stats',
#  'batch_shape',
#  'batch_shape_tensor',
#  'cdf',
#  'copy',
#  'covariance',
#  'cross_entropy',
#  'distribution',
#  'dtype',
#  'entropy',
#  'event_shape',
#  'event_shape_tensor',
#  'get_shape',
#  'is_scalar_batch',
#  'is_scalar_event',
#  'kl_divergence',
#  'log_cdf',
#  'log_prob',
#  'log_survival_function',
#  'mean',
#  'mode',
#  'name',
#  'name_scope',
#  'param_shapes',
#  'param_static_shapes',
#  'parameters',
#  'prob',
#  'quantile',
#  'registered_class_list',
#  'reinterpreted_batch_ndims',
#  'reparameterization_type',
#  'sample',
#  'shape',
#  'stddev',
#  'submodules',
#  'survival_function',
#  'trainable_variables',
#  'validate_args',
#  'variables',
#  'variance',
#  'with_name_scope']

# %%
y_dist.components_distribution.parameters
# Out:
# {'distribution': <tfp.distributions.Independent 'sequential_1_mixture_same_family_1_MixtureSameFamily_independent_normal_1_IndependentNormal_Independentsequential_1_mixture_same_family_1_MixtureSameFamily_independent_normal_1_IndependentNormal_Normal' batch_shape=[2000, 5] event_shape=[1] dtype=float32>,
#  'convert_to_tensor_fn': <function tensorflow_probability.python.distributions.distribution.Distribution.sample(self, sample_shape=(), seed=None, name='sample', **kwargs)>}

# %%
y_dist.mixture_distribution
# Out:
# <tfp.distributions.Categorical 'sequential_1_mixture_same_family_1_MixtureSameFamily_Categorical' batch_shape=[2000] event_shape=[] dtype=int32>

# %%
y_dist.parameters
# Out:
# {'distribution': <tfp.distributions.MixtureSameFamily 'sequential_1_mixture_same_family_1_MixtureSameFamily_MixtureSameFamily' batch_shape=[2000] event_shape=[1] dtype=float32>,
#  'convert_to_tensor_fn': <function tensorflow_probability.python.distributions.distribution.Distribution.sample(self, sample_shape=(), seed=None, name='sample', **kwargs)>}

# %%
a = ()

# %%
len(a)
# Out:
# 0

# %%
a = ['a', 'b', 'c']
b = list(np.random.choice(a, replace = False, size = 3))

# %%
b
# Out:
# ['c', 'b', 'a']
